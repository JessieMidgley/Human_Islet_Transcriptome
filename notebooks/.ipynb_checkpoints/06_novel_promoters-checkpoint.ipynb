# %% [markdown]
# # Finding unannotated TSSs

# %%
import pandas as pd
from tqdm import tqdm
from collections import defaultdict
import pyranges as pr
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from collections import defaultdict
from matplotlib import font_manager
import numpy as np
import csv
import pickle
# Out:
# /users/jferrer/jmidgley/annotation_project/lib64/python3.9/site-packages/sorted_nearest/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
pd.set_option('display.max_columns', None)

# %%
def split_attributes(df, *attribute_type):
    """split attribute of a gtf into separate columns"""
    try: 
        l_attributes = df.strip(';').split('; ')
        attribute_position = [i for i, x in enumerate(l_attributes) if x.startswith(attribute_type)]
        attribute = l_attributes[attribute_position[0]].split(' ')[1].strip('"')
        return attribute
    except Exception:
        return np.nan

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

font_path = "ARIAL.TTF"  
font_manager.fontManager.addfont(font_path)

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
font = {'family' : 'arial',
       'weight' : 'normal',
       'size'   : 10}

mpl.rc('font', **font)
mpl.rc('lines', lw=1, c='k')
sns.set_context("notebook", font_scale=1, rc={"axes.linewidth": 1,
                                              "lines.linewidth": 1, 
                                              "font.size": 10,
                                              "axes.titlesize": 10,
                                              "axes.labelsize": 10,
                                              "legend.fontsize": 10,
                                              "xtick.labelsize": 8,
                                              "ytick.labelsize": 8})

# %%
combined_df = pd.read_csv( 'jessies_gffcompare_with_TSS_name.tsv', sep='\t')
#combined_df = pd.read_csv( 'jessies_gffcompare_v2.0.tsv', sep='\t')
combined_df.head()
# Out:
# /tmp/18566350/ipykernel_3177472/2825330557.py:1: DtypeWarning: Columns (3,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_df = pd.read_csv( 'jessies_gffcompare_with_TSS_name.tsv', sep='\t')
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 1          lncRNA          lncRNA  ENSG00000228606
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 4          lncRNA          lncRNA       FTMG005195
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 1  chr1:160261726-160261763_Peak_5604  Permissive      0.358414    -1.480300
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 4  chr1:233327323-233327461_Peak_7654  Permissive      0.616169    -0.698603
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 1      0.743874         0.481821          0.743874            1.000000
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 4      2.291033         0.268948          2.093885            0.913948
#
#      TSS_type    TSS_start      TSS_end  distance_to_closest_TSS  \
# 0   minor TSS   61077221.0   61077380.0                      6.0
# 1  unique TSS  160261726.0  160261763.0                      0.0
# 2    main TSS  239386576.0  239386587.0                      8.0
# 3  unique TSS   23217498.0   23217499.0                      3.0
# 4    main TSS  233327323.0  233327461.0                      3.0
#
#       closest_ref_id TSS distance category TSS_name
# 0  ENST00000699964.1               <=100bp  P3111_A
# 1  ENST00000442130.1               <=100bp  P5604_A
# 2  ENST00000676153.1               <=100bp  P7900_A
# 3  ENST00000374619.2               <=100bp  P1212_A
# 4  ENST00000771586.1               <=100bp  P7654_A

# %%
# Extract peak start and end positions
combined_df[["TSS_start", "TSS_end"]] = (combined_df["peak_name"].str.extract(r":(\d+)-(\d+)", expand=True)).astype("Int64")

combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 1          lncRNA          lncRNA  ENSG00000228606
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 4          lncRNA          lncRNA       FTMG005195
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 1  chr1:160261726-160261763_Peak_5604  Permissive      0.358414    -1.480300
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 4  chr1:233327323-233327461_Peak_7654  Permissive      0.616169    -0.698603
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 1      0.743874         0.481821          0.743874            1.000000
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 4      2.291033         0.268948          2.093885            0.913948
#
#      TSS_type  TSS_start    TSS_end
# 0   minor TSS   61077221   61077380
# 1  unique TSS  160261726  160261763
# 2    main TSS  239386576  239386587
# 3  unique TSS   23217498   23217499
# 4    main TSS  233327323  233327461

# %%
# Load gencode v47 transcripts
gencode_v47_transcripts = pd.read_csv("gencode.v47.transcript.tsv", sep="\t", dtype=str)
gencode_v47_transcripts["start"] = gencode_v47_transcripts["start"].astype(int)
gencode_v47_transcripts["end"] = gencode_v47_transcripts["end"].astype(int)

gencode_v47_transcripts = gencode_v47_transcripts.rename(columns={"seqname": "chr"})

gencode_v47_transcripts.head()
# Out:
#     chr  source     feature  start    end score strand frame  \
# 0  chr1  HAVANA  transcript  11121  14413     .      +     .
# 1  chr1  HAVANA  transcript  11125  14405     .      +     .
# 2  chr1  HAVANA  transcript  11410  14413     .      +     .
# 3  chr1  HAVANA  transcript  11411  14413     .      +     .
# 4  chr1  HAVANA  transcript  11426  14409     .      +     .
#
#              gene_id      transcript_id gene_type gene_name transcript_type  \
# 0  ENSG00000290825.2  ENST00000832824.1    lncRNA  DDX11L16          lncRNA
# 1  ENSG00000290825.2  ENST00000832825.1    lncRNA  DDX11L16          lncRNA
# 2  ENSG00000290825.2  ENST00000832826.1    lncRNA  DDX11L16          lncRNA
# 3  ENSG00000290825.2  ENST00000832827.1    lncRNA  DDX11L16          lncRNA
# 4  ENSG00000290825.2  ENST00000832828.1    lncRNA  DDX11L16          lncRNA
#
#   transcript_name level     tag transcript_support_level havana_transcript  \
# 0    DDX11L16-260     2  TAGENE                      NaN               NaN
# 1    DDX11L16-261     2  TAGENE                      NaN               NaN
# 2    DDX11L16-262     2  TAGENE                      NaN               NaN
# 3    DDX11L16-263     2  TAGENE                      NaN               NaN
# 4    DDX11L16-264     2  TAGENE                      NaN               NaN
#
#   hgnc_id  ont havana_gene protein_id ccdsid
# 0     NaN  NaN         NaN        NaN    NaN
# 1     NaN  NaN         NaN        NaN    NaN
# 2     NaN  NaN         NaN        NaN    NaN
# 3     NaN  NaN         NaN        NaN    NaN
# 4     NaN  NaN         NaN        NaN    NaN

# %% [markdown]
# ## Plot distance to closest GENCODE TSS

# %%
# For each TSS find the closest GENCODE tx start
transcript_groups = {
    (chr, strand): df for (chr, strand), df in gencode_v47_transcripts.groupby(["chr", "strand"])
}

def compute_closest_distance_and_transcript(row):
    key = (row["chr"], row["Strand"])
    matches = transcript_groups.get(key, None)

    if matches is None or matches.empty or pd.isna(row["TSS_start"]) or pd.isna(row["TSS_end"]):
        return pd.Series([pd.NA, pd.NA])

    tss_midpoint = (row["TSS_start"] + row["TSS_end"]) // 2
    
    if row["Strand"] == "+":
        distances = np.minimum(np.minimum((matches["start"] - row["TSS_start"]).abs(), (matches["start"] - row["TSS_end"]).abs()), (matches["start"] - tss_midpoint).abs())
    elif row["Strand"] == "-":
        distances = np.minimum(np.minimum((matches["end"] - row["TSS_start"]).abs(), (matches["end"] - row["TSS_end"]).abs()), (matches["end"] - tss_midpoint).abs())
    else:
        return pd.Series([pd.NA, pd.NA])

    min_idx = distances.idxmin()
    min_distance = distances.loc[min_idx]
    closest_transcript = matches.loc[min_idx, "transcript_id"]

    return pd.Series([min_distance, closest_transcript])


tqdm.pandas()

combined_df[["distance_to_closest_TSS", "closest_ref_id"]] = combined_df.progress_apply(compute_closest_distance_and_transcript, axis=1)
combined_df["distance_to_closest_TSS"] = combined_df["distance_to_closest_TSS"].astype("Int64")
# Out:
# 100%|██████████| 376342/376342 [02:48<00:00, 2227.87it/s]

# %%
f = lambda x: "<=100bp" if x <= 100 else ">100bp"
combined_df['TSS distance category'] = combined_df['distance_to_closest_TSS'].apply(f)

# %%
# Create TSS name based on annotation status
combined_df["TSS_name"] = (
    "P" 
    + combined_df["peak_name"].str.extract(r"Peak_(\d+)", expand=False)
    + np.where(
        combined_df["TSS distance category"] == "<=100bp",
        "_A",
        "_U"
    )
)
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 1          lncRNA          lncRNA  ENSG00000228606
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 4          lncRNA          lncRNA       FTMG005195
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 1  chr1:160261726-160261763_Peak_5604  Permissive      0.358414    -1.480300
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 4  chr1:233327323-233327461_Peak_7654  Permissive      0.616169    -0.698603
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 1      0.743874         0.481821          0.743874            1.000000
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 4      2.291033         0.268948          2.093885            0.913948
#
#      TSS_type  TSS_start    TSS_end  distance_to_closest_TSS  \
# 0   minor TSS   61077221   61077380                        6
# 1  unique TSS  160261726  160261763                        0
# 2    main TSS  239386576  239386587                        8
# 3  unique TSS   23217498   23217499                        3
# 4    main TSS  233327323  233327461                        3
#
#       closest_ref_id TSS distance category TSS_name
# 0  ENST00000699964.1               <=100bp  P3111_A
# 1  ENST00000442130.1               <=100bp  P5604_A
# 2  ENST00000676153.1               <=100bp  P7900_A
# 3  ENST00000374619.2               <=100bp  P1212_A
# 4  ENST00000771586.1               <=100bp  P7654_A

# %%
#combined_df.to_csv('jessies_gffcompare_with_TSS_name.tsv', sep='\t', index=False)

# %%
# Nr of unannotated TSSs 
combined_df[combined_df["distance_to_closest_TSS"] > 100]["peak_name"].nunique()
# Out:
# 13001

# %%
# Nr of tx from protein coding genes assigned to unannotated TSS
combined_df[(combined_df["distance_to_closest_TSS"] > 100) & (combined_df["gene_category"] == "protein_coding")]["transcript_id"].nunique()
# Out:
# 32358

# %%
# Nr of unannotated TSS in protein coding genes
combined_df[(combined_df["distance_to_closest_TSS"] > 100) & (combined_df["gene_category"] == "protein_coding")]["peak_name"].nunique()
# Out:
# 10589

# %%
# Nr of *very* unannotated TSSs 
combined_df[combined_df["distance_to_closest_TSS"] > 100_000]["peak_name"].nunique()
# Out:
# 140

# %%
# Nr of tx from protein coding genes assigned to *very* unannotated TSS
combined_df[(combined_df["distance_to_closest_TSS"] > 100_000) & (combined_df["gene_category"] == "protein_coding")]["transcript_id"].nunique()
# Out:
# 231

# %%
# Nr of *very* unannotated TSS in protein coding genes
combined_df[(combined_df["distance_to_closest_TSS"] > 100_000) & (combined_df["gene_category"] == "protein_coding")]["peak_name"].nunique()
# Out:
# 60

# %%
combined_df[(combined_df["distance_to_closest_TSS"] > 100_000) & (combined_df["gene_category"] == "protein_coding")]["Gene name"].nunique()
# Out:
# 38

# %%
combined_df[(combined_df["distance_to_closest_TSS"] > 100_000) & (combined_df["gene_category"] == "protein_coding")]["Gene name"].unique()
# Out:
# array(['SLC44A5', 'LRMDA', 'TTN', 'PCSK2', 'ROBO2', 'SLC4A4', 'PTPRN2',
#        'CTNNA3', 'LUZP2', 'KIRREL3', 'TRHDE', 'GPC6', 'RAD51B', 'SNX29',
#        'PIEZO2', 'ZNF407', 'NCKAP5', 'RBMS1', 'LRRTM4', 'PTPRT',
#        'TBC1D22A', 'TBC1D5', 'FHIT', 'GALNTL6', 'SPOCK1', 'EYS', 'SUGCT',
#        'KCND2', 'SLCO5A1', 'SGCZ', 'MMP16', 'SMC2', 'GNAQ', 'SLC4A10',
#        'NLGN1', 'PDSS2', 'KCNJ6', 'TNIK'], dtype=object)

# %%
combined_df[(combined_df["TSS_type"] == "main TSS") & (combined_df["distance_to_closest_TSS"] > 100_000)]
# Out:
#             transcript_id    chr  \
# 65889         PBT00039413   chr1
# 65890         PBT00039414   chr1
# 65892         PBT00039419   chr1
# 66645        STRT00053255   chr1
# 66729        STRT00056861   chr1
# 66986        STRT00067280   chr1
# 67084        STRT00070690   chr1
# 67374        STRT00080647   chr1
# 68045        STRT00105481   chr1
# 68633        STRT00127950   chr1
# 69035        STRT00141840   chr1
# 69513        STRT00160136   chr1
# 69771        STRT00168678   chr1
# 70038        STRT00176708   chr1
# 70139        STRT00187848   chr1
# 77597   MICT00000082266.1  chr12
# 78185        STRT00465989  chr12
# 78223        STRT00467407  chr12
# 78359        STRT00473560  chr12
# 78521        STRT00480194  chr12
# 78590        STRT00482961  chr12
# 78777        STRT00489460  chr12
# 79074        STRT00500298  chr12
# 79106        STRT00501304  chr12
# 79154        STRT00503810  chr12
# 79289        STRT00508899  chr12
# 79369        STRT00512013  chr12
# 98301        STRT01241581   chr2
# 101656        PBT00284297  chr22
# 101657        PBT00284300  chr22
# 101836       STRT01374175  chr22
# 101887       STRT01377434  chr22
# 102118       STRT01386461  chr22
# 102206       STRT01389079  chr22
# 102424       STRT01395958  chr22
# 102532       STRT01399604  chr22
# 102572       STRT01401301  chr22
# 102656       STRT01403941  chr22
# 102728       STRT01406043  chr22
# 102756       STRT01407700  chr22
# 121616       STRT02028539   chr8
# 122328       STRT02061078   chr8
# 122774       STRT02076292   chr8
# 122870       STRT02079250   chr8
# 230643        PBT00256971   chr2
# 330052       STRT01125479   chr2
# 330149       STRT01185983   chr2
# 330169       STRT01192034   chr2
# 330175       STRT01194973   chr2
# 330267       STRT01242140   chr2
# 330271       STRT01242551   chr2
# 330283       STRT01246644   chr2
# 330359       STRT01271620   chr2
# 330374       STRT01274374   chr2
# 330891       STRT00177472  chr21
#
#                                                     exons matched_to  \
# 65889   [(75202142, 75203833), (75211468, 75211552), (...        NaN
# 65890   [(75202142, 75203833), (75211468, 75211552), (...        NaN
# 65892   [(75212209, 75213793), (75213919, 75213989), (...        NaN
# 66645   [(75202182, 75211552), (75213705, 75213793), (...        NaN
# 66729   [(75202228, 75203833), (75211468, 75211552), (...        NaN
# 66986   [(75322072, 75322143), (75339582, 75339630), (...        NaN
# 67084   [(75203666, 75203833), (75211468, 75211552), (...        NaN
# 67374   [(75202227, 75211552), (75213705, 75213793), (...        NaN
# 68045   [(75202188, 75203833), (75211468, 75211552), (...        NaN
# 68633   [(75206609, 75206719), (75211468, 75211552), (...        NaN
# 69035   [(75202008, 75211552), (75213705, 75213793), (...        NaN
# 69513   [(75202181, 75211552), (75213705, 75213793), (...        NaN
# 69771   [(75321314, 75321433), (75339582, 75339630), (...        NaN
# 70038   [(75251216, 75251294), (75274958, 75275042), (...        NaN
# 70139   [(75217882, 75217960), (75218490, 75218752), (...        NaN
# 77597   [(72432480, 72432566), (72469758, 72469912), (...        NaN
# 78185   [(72432477, 72432566), (72469758, 72469912), (...        NaN
# 78223   [(72432494, 72432566), (72469758, 72469912), (...        NaN
# 78359   [(72432481, 72432566), (72469758, 72469912), (...        NaN
['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 101657  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 101836  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 101887  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102118  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102206  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102424  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102532         ['ENST00000380995.5', 'ENST00000337137.9']
# 102572  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102656  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102728  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 102756  ['ENST00000406733.1', 'ENST00000355704.7', 'EN...
# 121616         ['ENST00000382080.6', 'ENST00000421524.6']
# 122328                              ['ENST00000655061.1']
# 122774                              ['ENST00000655061.1']
# 122870                              ['ENST00000655061.1']
# 230643         ['ENST00000409884.6', 'ENST00000409911.5']
# 330052                                                NaN
# 330149                                                NaN
# 330169                                                NaN
# 330175                                                NaN
# 330267                                                NaN
# 330271                                                NaN
# 330283                                                NaN
# 330359                                                NaN
# 330374                                                NaN
# 330891                                                NaN
#
#                                                  category  \
# 65889   Transcripts with annotated exons and non-overl...
# 65890   Transcripts with annotated exons and non-overl...
# 65892   Transcripts with annotated exons and non-overl...
# 66645   Transcripts with annotated exons and non-overl...
# 66729   Transcripts with annotated exons and non-overl...
# 66986   Transcripts with annotated exons and non-overl...
# 67084   Transcripts with annotated exons and non-overl...
# 67374   Transcripts with annotated exons and non-overl...
# 68045   Transcripts with annotated exons and non-overl...
# 68633   Transcripts with annotated exons and non-overl...
# 69035   Transcripts with annotated exons and non-overl...
# 69513   Transcripts with annotated exons and non-overl...
# 69771   Transcripts with annotated exons and non-overl...
# 70038   Transcripts with annotated exons and non-overl...
# 70139   Transcripts with annotated exons and non-overl...
# 77597   Transcripts with annotated exons and non-overl...
# 78185   Transcripts with annotated exons and non-overl...
# 78223   Transcripts with annotated exons and non-overl...
# 78359   Transcripts with annotated exons and non-overl...
# 78521   Transcripts with annotated exons and non-overl...
# 78590   Transcripts with annotated exons and non-overl...
# 78777   Transcripts with annotated exons and non-overl...
# 79074   Transcripts with annotated exons and non-overl...
# 79106   Transcripts with annotated exons and non-overl...
# 79154   Transcripts with annotated exons and non-overl...
# 79289   Transcripts with annotated exons and non-overl...
# 79369   Transcripts with annotated exons and non-overl...
# 98301   Transcripts with annotated exons and non-overl...
# 101656  Transcripts with annotated exons and non-overl...
# 101657  Transcripts with annotated exons and non-overl...
# 101836  Transcripts with annotated exons and non-overl...
# 101887  Transcripts with annotated exons and non-overl...
# 102118  Transcripts with annotated exons and non-overl...
# 102206  Transcripts with annotated exons and non-overl...
# 102424  Transcripts with annotated exons and non-overl...
# 102532  Transcripts with annotated exons and non-overl...
# 102572  Transcripts with annotated exons and non-overl...
# 102656  Transcripts with annotated exons and non-overl...
# 102728  Transcripts with annotated exons and non-overl...
# 102756  Transcripts with annotated exons and non-overl...
# 121616  Transcripts with annotated exons and non-overl...
# 122328  Transcripts with annotated exons and non-overl...
# 122774  Transcripts with annotated exons and non-overl...
# 122870  Transcripts with annotated exons and non-overl...
# 230643  Transcripts with annotated exons and only over...
# 330052  Fully unannotated transcripts with overlapping...
# 330149  Fully unannotated transcripts with overlapping...
# 330169  Fully unannotated transcripts with overlapping...
# 330175  Fully unannotated transcripts with overlapping...
# 330267  Fully unannotated transcripts with overlapping...
# 330271  Fully unannotated transcripts with overlapping...
# 330283  Fully unannotated transcripts with overlapping...
# 330359  Fully unannotated transcripts with overlapping...
# 330374  Fully unannotated transcripts with overlapping...
# 330891  Fully unannotated transcripts with overlapping...
#
#                                         unannotated_exons   best_match_ref_id  \
# 65889                              [(75376084, 75376211)]   ENST00000370859.8
# 65890                              [(75376169, 75376297)]   ENST00000370859.8
# 65892        [(75212209, 75213793), (75376169, 75376211)]   ENST00000370855.5
# 66645        [(75202182, 75211552), (75376169, 75376211)]   ENST00000370855.5
# 66729        [(75300598, 75300685), (75376084, 75376211)]   ENST00000370859.8
# 66986        [(75322072, 75322143), (75376084, 75376191)]   ENST00000469525.1
# 67084        [(75203666, 75203833), (75376084, 75376305)]   ENST00000370855.5
# 67374   [(75202227, 75211552), (75300598, 75300685), (...   ENST00000370855.5
# 68045        [(75300598, 75300685), (75376169, 75376194)]   ENST00000370859.8
# 68633   [(75206609, 75206719), (75214605, 75214721), (...   ENST00000370855.5
# 69035        [(75202008, 75211552), (75376084, 75376265)]   ENST00000370855.5
# 69513   [(75202181, 75211552), (75218490, 75218595), (...   ENST00000370855.5
# 69771        [(75321314, 75321433), (75375816, 75376205)]   ENST00000469525.1
# 70038        [(75251216, 75251294), (75375816, 75376283)]   ENST00000469525.1
# 70139        [(75217882, 75217960), (75375816, 75376281)]   ENST00000370855.5
# 77597        [(72432480, 72432566), (72663052, 72671164)]  ENST00000261180.10
# 78185        [(72432477, 72432566), (72499498, 72499739)]   ENST00000548156.1
# 78223        [(72432494, 72432566), (72621644, 72621977)]  ENST00000261180.10
# 78359        [(72432481, 72432566), (72663052, 72663351)]  ENST00000261180.10
# 78521        [(72432470, 72432566), (72652322, 72652474)]  ENST00000261180.10
# 78590   [(72432523, 72432566), (72435391, 72435488), (...  ENST00000261180.10
# 78777        [(72432469, 72432566), (72542291, 72542348)]  ENST00000261180.10
# 79074   [(72432522, 72432566), (72663052, 72663170), (...  ENST00000261180.10
# 79106        [(72432511, 72432566), (72575487, 72575834)]  ENST00000261180.10
# 79154   [(72432491, 72432566), (72473155, 72473180), (...  ENST00000261180.10
# 79289        [(72432490, 72432566), (72653645, 72653682)]  ENST00000261180.10
# 79369        [(72432480, 72432566), (72621108, 72622123)]  ENST00000261180.10
# 98301   [(76815326, 76815457), (76997330, 76997480), (...   ENST00000409911.5
# 101656                             [(47053770, 47054382)]   ENST00000406733.1
# 101657  [(47053952, 47054382), (47173498, 47176062), (...   ENST00000406733.1
# 101836       [(47054078, 47054382), (47189667, 47190869)]   ENST00000406733.1
# 101887       [(47053770, 47054382), (47170720, 47170820)]   ENST00000406733.1
# 102118  [(47054051, 47054382), (47189667, 47189864), (...   ENST00000406733.1
# 102206       [(47053952, 47054382), (47167561, 47167669)]   ENST00000406733.1
# 102424  [(47053952, 47054382), (47207495, 47207731), (...   ENST00000406733.1
# 102532       [(47053844, 47055896), (47111234, 47111603)]   ENST00000337137.9
# 102572  [(47053724, 47055277), (47207495, 47207731), (...   ENST00000406733.1
# 102656                             [(47053844, 47055896)]   ENST00000337137.9
# 102728  [(47054051, 47054382), (47189667, 47189864), (...   ENST00000406733.1
# 102756  [(47053770, 47054382), (47207495, 47207731), (...   ENST00000406733.1
# 121616       [(14085326, 14090637), (14130785, 14130934)]   ENST00000421524.6
# 122328  [(35672887, 35673175), (35679851, 35679971), (...   ENST00000655061.1
# 122774  [(35672958, 35673175), (35679851, 35679971), (...   ENST00000655061.1
# 122870  [(35672851, 35673175), (35679851, 35680132), (...   ENST00000655061.1
# 230643                             [(77210588, 77210904)]   ENST00000409911.5
# 330052                                                NaN                 NaN
# 330149                                                NaN                 NaN
# 330169                                                NaN                 NaN
# 330175                                                NaN                 NaN
# 330267                                                NaN                 NaN
# 330271                                                NaN                 NaN
# 330283                                                NaN                 NaN
# 330359                                                NaN                 NaN
# 330374                                                NaN                 NaN
# 330891                                                NaN                 NaN
#
#        largest_overlap_gencode_id Strand  \
# 65889                         NaN      -
# 65890                         NaN      -
# 65892                         NaN      -
# 66645                         NaN      -
# 66729                         NaN      -
# 66986                         NaN      -
# 67084                         NaN      -
# 67374                         NaN      -
# 68045                         NaN      -
# 68633                         NaN      -
# 69035                         NaN      -
# 69513                         NaN      -
# 69771                         NaN      -
# 70038                         NaN      -
# 70139                         NaN      -
# 77597                         NaN      +
# 78185                         NaN      +
# 78223                         NaN      +
# 78359                         NaN      +
# 78521                         NaN      +
# 78590                         NaN      +
# 78777                         NaN      +
# 79074                         NaN      +
# 79106                         NaN      +
# 79154                         NaN      +
# 79289                         NaN      +
# 79369                         NaN      +
# 98301                         NaN      -
# 101656                        NaN      +
# 101657                        NaN      +
# 101836                        NaN      +
# 101887                        NaN      +
# 102118                        NaN      +
# 102206                        NaN      +
# 102424                        NaN      +
# 102532                        NaN      +
# 102572                        NaN      +
# 102656                        NaN      +
# 102728                        NaN      +
# 102756                        NaN      +
# 121616                        NaN      -
# 122328                        NaN      -
# 122774                        NaN      -
# 122870                        NaN      -
# 230643                        NaN      -
# 330052          ENST00000409884.6      -
# 330149          ENST00000409884.6      -
# 330169          ENST00000409884.6      -
# 330175          ENST00000409884.6      -
# 330267          ENST00000409884.6      -
# 330271          ENST00000409884.6      -
# 330283          ENST00000409884.6      -
# 330359          ENST00000409884.6      -
# 330374          ENST00000409884.6      -
# 330891          ENST00000815441.1      +
#
#                                       summarized_category              ref_id  \
# 65889   Unannotated transcripts with annotated and una...   ENST00000370859.8
# 65890   Unannotated transcripts with annotated and una...   ENST00000370859.8
# 65892   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 66645   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 66729   Unannotated transcripts with annotated and una...   ENST00000370859.8
# 66986   Unannotated transcripts with annotated and una...   ENST00000469525.1
# 67084   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 67374   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 68045   Unannotated transcripts with annotated and una...   ENST00000370859.8
# 68633   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 69035   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 69513   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 69771   Unannotated transcripts with annotated and una...   ENST00000469525.1
# 70038   Unannotated transcripts with annotated and una...   ENST00000469525.1
# 70139   Unannotated transcripts with annotated and una...   ENST00000370855.5
# 77597   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 78185   Unannotated transcripts with annotated and una...   ENST00000548156.1
# 78223   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 78359   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 78521   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 78590   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 78777   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 79074   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 79106   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 79154   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 79289   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 79369   Unannotated transcripts with annotated and una...  ENST00000261180.10
# 98301   Unannotated transcripts with annotated and una...   ENST00000409911.5
# 101656  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 101657  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 101836  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 101887  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102118  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102206  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102424  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102532  Unannotated transcripts with annotated and una...   ENST00000337137.9
# 102572  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102656  Unannotated transcripts with annotated and una...   ENST00000337137.9
# 102728  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 102756  Unannotated transcripts with annotated and una...   ENST00000406733.1
# 121616  Unannotated transcripts with annotated and una...   ENST00000421524.6
# 122328  Unannotated transcripts with annotated and una...   ENST00000655061.1
# 122774  Unannotated transcripts with annotated and una...   ENST00000655061.1
# 122870  Unannotated transcripts with annotated and una...   ENST00000655061.1
# 230643  Unannotated transcripts with annotated and una...   ENST00000409911.5
# 330052  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330149  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330169  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330175  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330267  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330271  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330283  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330359  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330374  Unannotated transcripts without any annotated ...   ENST00000409884.6
# 330891  Unannotated transcripts without any annotated ...   ENST00000815441.1
#
#         stripped_ref_id   Gene stable ID        Gene name       Gene type  \
# 65889   ENST00000370859  ENSG00000137968          SLC44A5  protein_coding
# 65890   ENST00000370859  ENSG00000137968          SLC44A5  protein_coding
# 65892   ENST00000370855  ENSG00000137968          SLC44A5  protein_coding
# 66645   ENST00000370855  ENSG00000137968          SLC44A5  protein_coding
# 66729   ENST00000370859  ENSG00000137968          SLC44A5  protein_coding
# 66986   ENST00000469525  ENSG00000137968          SLC44A5  protein_coding
# 67084   ENST00000370855  ENSG00000137968          SLC44A5  protein_coding
# 330052                >100bp  P42668_U
# 330149                >100bp  P42668_U
# 330169                >100bp  P42668_U
# 330175                >100bp  P42668_U
# 330267                >100bp  P42668_U
# 330271                >100bp  P42668_U
# 330283                >100bp  P42668_U
# 330359                >100bp  P42668_U
# 330374                >100bp  P42668_U
# 330891                >100bp   P4412_U

# %%
combined_df[(combined_df["Gene name"] == "PTPRN2")]
# Out:
#             transcript_id   chr  \
# 33697   ENST00000389413.3  chr7
# 33698   ENST00000389416.4  chr7
# 33699   ENST00000389418.4  chr7
# 33846   ENST00000409483.1  chr7
# 61072         PBT00394109  chr7
# 61073         PBT00394110  chr7
# 61074         PBT00394112  chr7
# 61075         PBT00394114  chr7
# 61076         PBT00394115  chr7
# 61077         PBT00394116  chr7
# 61078         PBT00394122  chr7
# 61079         PBT00394123  chr7
# 61080         PBT00394124  chr7
# 61081         PBT00394132  chr7
# 61082         PBT00394135  chr7
# 61083         PBT00394137  chr7
# 61212        STRT01924154  chr7
# 61359        STRT01947374  chr7
# 61766        STRT02011057  chr7
# 61783        STRT02012967  chr7
# 117522  ENCT00000419510.1  chr7
# 117523  ENCT00000419511.1  chr7
# 118096        PBT00394128  chr7
# 118097        PBT00394129  chr7
# 118098        PBT00394130  chr7
# 118099        PBT00394158  chr7
# 118100        PBT00394159  chr7
# 118279       STRT01912172  chr7
# 118613       STRT01927381  chr7
# 118817       STRT01934424  chr7
# 119203       STRT01947662  chr7
# 119258       STRT01950113  chr7
# 119391       STRT01953684  chr7
# 120086       STRT01978437  chr7
# 120691       STRT01998260  chr7
# 120977       STRT02016187  chr7
# 294548        PBT00394107  chr7
# 294549        PBT00394108  chr7
# 294550        PBT00394111  chr7
# 294551        PBT00394119  chr7
# 294552        PBT00394126  chr7
# 294553        PBT00394127  chr7
# 294554        PBT00394145  chr7
# 294555        PBT00394152  chr7
# 294556        PBT00394157  chr7
# 295033       STRT01912173  chr7
# 295312       STRT01917832  chr7
# 295355       STRT01918692  chr7
# 295855       STRT01927382  chr7
# 296175       STRT01934423  chr7
# 296256       STRT01935884  chr7
# 297190       STRT01956085  chr7
# 298144       STRT01977136  chr7
# 298736       STRT01984033  chr7
# 301060       STRT02014936  chr7
# 301240       STRT02016445  chr7
# 371554        PBT00394117  chr7
# 371555        PBT00394120  chr7
# 371556        PBT00394121  chr7
#
#                                                     exons  \
# 33697   [(157539056, 157540785), (157548946, 157549019...
# 33698   [(157539058, 157540785), (157548946, 157549019...
# 33699   [(157539057, 157540785), (157548946, 157549019...
# 33846   [(157539056, 157540785), (157548946, 157549019...
# 61072   [(157539057, 157540785), (157548946, 157549019...
# 61073   [(157539057, 157540785), (157548946, 157549019...
# 61074   [(157539057, 157540785), (157548946, 157549019...
# 61075   [(157539057, 157540785), (157548946, 157549019...
# 61076   [(157539057, 157540785), (157548946, 157549019...
# 61077   [(157539057, 157540785), (157548946, 157549019...
# 61078   [(157539057, 157540785), (157548946, 157549019...
# 61079   [(157539057, 157540785), (157548946, 157549019...
# 61080   [(157539057, 157540785), (157548946, 157549019...
['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 371554  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 371555  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 371556  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
#
#                                                  category  \
# 33697                       GENCODE-annotated transcripts
# 33698                       GENCODE-annotated transcripts
# 33699                       GENCODE-annotated transcripts
# 33846                       GENCODE-annotated transcripts
# 61072   Unannotated transcripts fully contained within...
# 61073   Unannotated transcripts fully contained within...
# 61074   Unannotated transcripts fully contained within...
# 61075   Unannotated transcripts fully contained within...
# 61076   Unannotated transcripts fully contained within...
# 61077   Unannotated transcripts fully contained within...
# 61078   Unannotated transcripts fully contained within...
# 61079   Unannotated transcripts fully contained within...
# 61080   Unannotated transcripts fully contained within...
# 61081   Unannotated transcripts fully contained within...
# 61082   Unannotated transcripts fully contained within...
# 61083   Unannotated transcripts fully contained within...
# 61212   Unannotated transcripts fully contained within...
# 61359   Unannotated transcripts fully contained within...
# 61766   Unannotated transcripts fully contained within...
# 61783   Unannotated transcripts fully contained within...
# 117522  Transcripts with annotated exons and non-overl...
# 117523  Transcripts with annotated exons and non-overl...
# 118096  Transcripts with annotated exons and non-overl...
# 118097  Transcripts with annotated exons and non-overl...
# 118098  Transcripts with annotated exons and non-overl...
# 118099  Transcripts with annotated exons and non-overl...
# 118100  Transcripts with annotated exons and non-overl...
# 118279  Transcripts with annotated exons and non-overl...
# 118613  Transcripts with annotated exons and non-overl...
# 118817  Transcripts with annotated exons and non-overl...
# 119203  Transcripts with annotated exons and non-overl...
# 119258  Transcripts with annotated exons and non-overl...
# 119391  Transcripts with annotated exons and non-overl...
# 120086  Transcripts with annotated exons and non-overl...
# 120691  Transcripts with annotated exons and non-overl...
# 120977  Transcripts with annotated exons and non-overl...
# 294548  Transcripts with annotated exons and only over...
# 294549  Transcripts with annotated exons and only over...
# 294550  Transcripts with annotated exons and only over...
# 294551  Transcripts with annotated exons and only over...
# 294552  Transcripts with annotated exons and only over...
# 294553  Transcripts with annotated exons and only over...
# 294554  Transcripts with annotated exons and only over...
# 294555  Transcripts with annotated exons and only over...
# 294556  Transcripts with annotated exons and only over...
# 295033  Transcripts with annotated exons and only over...
# 295312  Transcripts with annotated exons and only over...
# 295355  Transcripts with annotated exons and only over...
# 295855  Transcripts with annotated exons and only over...
# 296175  Transcripts with annotated exons and only over...
# 296256  Transcripts with annotated exons and only over...
# 297190  Transcripts with annotated exons and only over...
# 298144  Transcripts with annotated exons and only over...
# 298736  Transcripts with annotated exons and only over...
# 301060  Transcripts with annotated exons and only over...
# 301240  Transcripts with annotated exons and only over...
# 371554  Unannotated transcripts composed entirely of a...
# 371555  Unannotated transcripts composed entirely of a...
# 371556  Unannotated transcripts composed entirely of a...
#
#                                         unannotated_exons  best_match_ref_id  \
# 33697                                                 NaN                NaN
# 33698                                                 NaN                NaN
# 33699                                                 NaN                NaN
# 33846                                                 NaN                NaN
# 61072                                                 NaN                NaN
# 61073                                                 NaN                NaN
# 61074                                                 NaN                NaN
# 61075                                                 NaN                NaN
# 61076                                                 NaN                NaN
# 61077                                                 NaN                NaN
# 61078                                                 NaN                NaN
# 61079                                                 NaN                NaN
# 61080                                                 NaN                NaN
# 61081                                                 NaN                NaN
# 61359                         NaN      -
# 61766                         NaN      -
# 61783                         NaN      -
# 117522                        NaN      -
# 117523                        NaN      -
# 118096                        NaN      -
# 118097                        NaN      -
# 118098                        NaN      -
# 118099                        NaN      -
# 118100                        NaN      -
# 118279                        NaN      -
# 118613                        NaN      -
# 118817                        NaN      -
# 119203                        NaN      -
# 119258                        NaN      -
# 119391                        NaN      -
# 120086                        NaN      -
# 120691                        NaN      -
# 120977                        NaN      -
# 294548                        NaN      -
# 294549                        NaN      -
# 294550                        NaN      -
# 294551                        NaN      -
# 294552                        NaN      -
# 294553                        NaN      -
# 294554                        NaN      -
# 294555                        NaN      -
# 294556                        NaN      -
# 295033                        NaN      -
# 295312                        NaN      -
# 295355                        NaN      -
# 295855                        NaN      -
# 296175                        NaN      -
# 296256                        NaN      -
# 297190                        NaN      -
# 298144                        NaN      -
# 298736                        NaN      -
# 301060                        NaN      -
# 301240                        NaN      -
# 371554                        NaN      -
# 371555                        NaN      -
# 371556                        NaN      -
#
#                                       summarized_category             ref_id  \
# 33697                       GENCODE-annotated transcripts  ENST00000389413.7
# 33698                       GENCODE-annotated transcripts  ENST00000389416.8
# 33699                       GENCODE-annotated transcripts  ENST00000389418.9
# 33846                       GENCODE-annotated transcripts  ENST00000409483.5
# 61072    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61073    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61074    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61075    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61076    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61077    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61078    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61079    Unannotated transcripts with all exons annotated  ENST00000389418.9
# 61080    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61081    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61082    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61083    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61212    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61359    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61766    Unannotated transcripts with all exons annotated  ENST00000409483.5
# 61783    Unannotated transcripts with all exons annotated  ENST00000389418.9
# 117522  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 117523  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118096  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118097  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118098  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118099  Unannotated transcripts with annotated and una...  ENST00000389418.9
# 118100  Unannotated transcripts with annotated and una...  ENST00000389413.7
# 118279  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118613  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118817  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 119203  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 119258  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 119391  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 120086  Unannotated transcripts with annotated and una...  ENST00000389418.9
# 120691  Unannotated transcripts with annotated and una...  ENST00000389413.7
# 120977  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294548  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294549  Unannotated transcripts with annotated and una...  ENST00000389418.9
# 294550  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294551  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294552  Unannotated transcripts with annotated and una...  ENST00000648371.1
# 294553  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294554  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294555  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 294556  Unannotated transcripts with annotated and una...  ENST00000389418.9
# 295033  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 295312  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 295355  Unannotated transcripts with annotated and una...  ENST00000389413.7
# 295855  Unannotated transcripts with annotated and una...  ENST00000389413.7
# 296175  Unannotated transcripts with annotated and una...  ENST00000389418.9
# 296256  Unannotated transcripts with annotated and una...  ENST00000389416.8
#
# 294549  158587826.0                      3.0  ENST00000389418.9
# 294550  158134221.0                 289880.0  ENST00000775382.1
# 294551  158587826.0                      3.0  ENST00000389418.9
# 294552  157569032.0                   5390.0  ENST00000385225.1
# 294553  157576678.0                   2239.0  ENST00000385225.1
# 294554  157656452.0                  34942.0  ENST00000648371.1
# 294555  158489785.0                  16925.0  ENST00000757553.1
# 294556  158587826.0                      3.0  ENST00000389418.9
# 295033  158587568.0                    143.0  ENST00000389416.8
# 295312  158587568.0                    143.0  ENST00000389416.8
# 295355  158587826.0                      3.0  ENST00000389418.9
# 295855  158587826.0                      3.0  ENST00000389418.9
# 296175  158587568.0                    143.0  ENST00000389416.8
# 296256  158587568.0                    143.0  ENST00000389416.8
# 297190  158587826.0                      3.0  ENST00000389418.9
# 298144  158587826.0                      3.0  ENST00000389418.9
# 298736  158587826.0                      3.0  ENST00000389418.9
# 301060  158587826.0                      3.0  ENST00000389418.9
# 301240  158587826.0                      3.0  ENST00000389418.9
# 371554  158587826.0                      3.0  ENST00000389418.9
# 371555  158587826.0                      3.0  ENST00000389418.9
# 371556  158587826.0                      3.0  ENST00000389418.9
#
#        TSS distance category  TSS_name
# 33697                <=100bp  P71789_A
# 33698                <=100bp  P71789_A
# 33699                <=100bp  P71789_A
# 33846                <=100bp  P71789_A
# 61072                 >100bp  P71743_U
# 61073                 >100bp  P71768_U
# 61074                 >100bp  P71771_U
# 61075                 >100bp  P71772_U
# 61076                 >100bp  P71773_U
# 61077                <=100bp  P71789_A
# 61078                <=100bp  P71789_A
# 61079                <=100bp  P71789_A
# 61080                <=100bp  P71789_A
# 61081                <=100bp  P71789_A
# 61082                 >100bp  P71773_U
# 61083                <=100bp  P71789_A
# 61212                <=100bp  P71789_A
# 61359                <=100bp  P71789_A
# 61766                <=100bp  P71789_A
# 61783                <=100bp  P71789_A
# 117522                >100bp  P71743_U
# 117523                >100bp  P71747_U
# 118096                >100bp  P71759_U
# 118097                >100bp  P71763_U
# 118098                >100bp  P71770_U
# 118099               <=100bp  P71789_A
# 118100               <=100bp  P71789_A
# 118279                >100bp  P71777_U
# 118613               <=100bp  P71789_A
# 118817               <=100bp  P71789_A
# 119203               <=100bp  P71789_A
# 119258                >100bp  P71788_U
# 119391               <=100bp  P71789_A
# 120086               <=100bp  P71789_A
# 120691               <=100bp  P71789_A
# 120977               <=100bp  P71789_A
# 294548               <=100bp  P71789_A
# 294549               <=100bp  P71789_A
# 294550                >100bp  P71769_U
# 294551               <=100bp  P71789_A
# 294552                >100bp  P71743_U
# 294553                >100bp  P71744_U
# 294554                >100bp  P71746_U
# 294555                >100bp  P71786_U
# 294556               <=100bp  P71789_A
# 295033                >100bp  P71788_U
# 295312                >100bp  P71788_U
# 295355               <=100bp  P71789_A
# 295855               <=100bp  P71789_A
# 296175                >100bp  P71788_U
# 296256                >100bp  P71788_U
# 297190               <=100bp  P71789_A
# 298144               <=100bp  P71789_A
# 298736               <=100bp  P71789_A
# 301060               <=100bp  P71789_A
# 301240               <=100bp  P71789_A
# 371554               <=100bp  P71789_A
# 371555               <=100bp  P71789_A
# 371556               <=100bp  P71789_A

# %%
combined_df[(combined_df["Gene name"] == "PTPRN2") & (combined_df["distance_to_closest_TSS"] > 100_000)]
# Out:
#        transcript_id   chr                                              exons  \
# 61073    PBT00394110  chr7  [(157539057, 157540785), (157548946, 157549019...
# 61074    PBT00394112  chr7  [(157539057, 157540785), (157548946, 157549019...
# 61075    PBT00394114  chr7  [(157539057, 157540785), (157548946, 157549019...
# 61076    PBT00394115  chr7  [(157539057, 157540785), (157548946, 157549019...
# 61082    PBT00394135  chr7  [(157539059, 157540785), (157548946, 157549019...
# 118096   PBT00394128  chr7  [(157539058, 157540785), (157548946, 157549019...
# 118097   PBT00394129  chr7  [(157539058, 157540785), (157548946, 157549019...
# 118098   PBT00394130  chr7  [(157539058, 157540785), (157548946, 157549019...
# 294550   PBT00394111  chr7  [(157539057, 157540785), (157548946, 157549019...
#
#                                                matched_to  \
# 61073   [(157539056, 157540785), (157548946, 157549019...
# 61074   [(157539061, 157540785), (157548946, 157549019...
# 61075   [(157539061, 157540785), (157548946, 157549019...
# 61076   [(157539061, 157540785), (157548946, 157549019...
# 61082   [(157539061, 157540785), (157548946, 157549019...
# 118096                                                NaN
# 118097                                                NaN
# 118098                                                NaN
# 294550                                                NaN
#
#                                            matched_ref_id  \
# 61073                                   ENST00000389413.7
# 61074                                   ENST00000389416.8
# 61075                                   ENST00000389416.8
# 61076                                   ENST00000389416.8
# 61082                                   ENST00000389416.8
# 118096  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 118097  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 118098  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
# 294550  ['ENST00000389416.8', 'ENST00000389418.9', 'EN...
#
#                                                  category  \
# 61073   Unannotated transcripts fully contained within...
# 61074   Unannotated transcripts fully contained within...
# 61075   Unannotated transcripts fully contained within...
# 61076   Unannotated transcripts fully contained within...
# 61082   Unannotated transcripts fully contained within...
# 118096  Transcripts with annotated exons and non-overl...
# 118097  Transcripts with annotated exons and non-overl...
# 118098  Transcripts with annotated exons and non-overl...
# 294550  Transcripts with annotated exons and only over...
#
#                unannotated_exons  best_match_ref_id  \
# 61073                        NaN                NaN
# 61074                        NaN                NaN
# 61075                        NaN                NaN
# 61076                        NaN                NaN
# 61082                        NaN                NaN
# 118096  [(158001484, 158001661)]  ENST00000389416.8
# 118097  [(158028013, 158028523)]  ENST00000389416.8
# 118098  [(158137736, 158137950)]  ENST00000389416.8
# 294550  [(158133677, 158134221)]  ENST00000389416.8
#
#        largest_overlap_gencode_id Strand  \
# 61073                         NaN      -
# 61074                         NaN      -
# 61075                         NaN      -
# 61076                         NaN      -
# 61082                         NaN      -
# 118096                        NaN      -
# 118097                        NaN      -
# 118098                        NaN      -
# 294550                        NaN      -
#
#                                       summarized_category             ref_id  \
# 61073    Unannotated transcripts with all exons annotated  ENST00000389413.7
# 61074    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61075    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61076    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 61082    Unannotated transcripts with all exons annotated  ENST00000389416.8
# 118096  Unannotated transcripts with annotated and una...  ENST00000389416.8
# 118097  Unannotated transcripts with annotated and una...  ENST00000389416.8
#
combined_df[(combined_df["Gene name"] == "PTPRN2") & (combined_df["distance_to_closest_TSS"] > 100_000)]["peak_name"].nunique()
# Out:
# 8

# %%
combined_df[combined_df["transcript_id"] == "PBT00394155"]
# Out:
#        transcript_id   chr                     exons matched_to  \
# 339407   PBT00394155  chr7  [(158021837, 158028547)]        NaN
#
#        matched_ref_id                                           category  \
# 339407            NaN  Fully unannotated transcripts without any over...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 339407               NaN               NaN                        NaN      -
#
#                                       summarized_category ref_id  \
# 339407  Unannotated transcripts without any annotated ...    NaN
#
#        stripped_ref_id Gene stable ID   Gene name Gene type gene_category  \
# 339407             NaN     Peak_71763  Peak_71763       NaN      unmapped
#
#        og_gene_id                            peak_name peak_type  \
# 339407  PBG049883  chr7:158028503-158028546_Peak_71763    Robust
#
#         mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 339407      0.174883    -2.515541      0.174883              1.0
#
#         TSS_TPM_per_gene  Relative TSS usage    TSS_type    TSS_start  \
# 339407          0.174883                 1.0  unique TSS  158028503.0
#
#             TSS_end  distance_to_closest_TSS     closest_ref_id  \
# 339407  158028546.0                 226230.0  ENST00000737417.1
#
#        TSS distance category  TSS_name
# 339407                >100bp  P71763_U

# %% [markdown]
# ### Only looking at unannotated UPSTREAM TSSs

# %%
gencode_tss
# Out:
#                   gene_id strand    TSS
# 0       ENSG00000290825.2      +  11121
# 1       ENSG00000290825.2      +  11125
# 2       ENSG00000290825.2      +  11410
# 3       ENSG00000290825.2      +  11411
# 4       ENSG00000290825.2      +  11426
# ...                   ...    ...    ...
# 385654  ENSG00000198695.2      -  14673
# 385655  ENSG00000210194.1      -  14742
# 385656  ENSG00000198727.2      +  14747
# 385657  ENSG00000210195.2      +  15888
# 385658  ENSG00000210196.2      -  16023
#
# [385659 rows x 3 columns]

# %%
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 1          lncRNA          lncRNA  ENSG00000228606
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 4          lncRNA          lncRNA       FTMG005195
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 1  chr1:160261726-160261763_Peak_5604  Permissive      0.358414    -1.480300
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 4  chr1:233327323-233327461_Peak_7654  Permissive      0.616169    -0.698603
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 1      0.743874         0.481821          0.743874            1.000000
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 4      2.291033         0.268948          2.093885            0.913948
#
#      TSS_type    TSS_start      TSS_end  distance_to_closest_TSS  \
# 0   minor TSS   61077221.0   61077380.0                      6.0
# 1  unique TSS  160261726.0  160261763.0                      0.0
# 2    main TSS  239386576.0  239386587.0                      8.0
# 3  unique TSS   23217498.0   23217499.0                      3.0
# 4    main TSS  233327323.0  233327461.0                      3.0
#
#       closest_ref_id TSS distance category TSS_name        start          end  \
# 0  ENST00000699964.1               <=100bp  P3111_A   61077326.0   61079231.0
# 1  ENST00000442130.1               <=100bp  P5604_A  160261682.0  160281935.0
# 2  ENST00000676153.1               <=100bp  P7900_A  239386568.0  239915450.0
# 3  ENST00000374619.2               <=100bp  P1212_A   23191895.0   23217502.0
# 4  ENST00000771586.1               <=100bp  P7654_A  233319834.0  233327455.0
#
#    far_upstream
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
gencode_v47_transcripts.head()
# Out:
#     chr  source     feature  start    end score strand frame  \
# 0  chr1  HAVANA  transcript  11121  14413     .      +     .
# 1  chr1  HAVANA  transcript  11125  14405     .      +     .
# 2  chr1  HAVANA  transcript  11410  14413     .      +     .
# 3  chr1  HAVANA  transcript  11411  14413     .      +     .
# 4  chr1  HAVANA  transcript  11426  14409     .      +     .
#
#              gene_id      transcript_id gene_type gene_name transcript_type  \
# 0  ENSG00000290825.2  ENST00000832824.1    lncRNA  DDX11L16          lncRNA
# 1  ENSG00000290825.2  ENST00000832825.1    lncRNA  DDX11L16          lncRNA
# 2  ENSG00000290825.2  ENST00000832826.1    lncRNA  DDX11L16          lncRNA
# 3  ENSG00000290825.2  ENST00000832827.1    lncRNA  DDX11L16          lncRNA
# 4  ENSG00000290825.2  ENST00000832828.1    lncRNA  DDX11L16          lncRNA
#
#   transcript_name level     tag transcript_support_level havana_transcript  \
# 0    DDX11L16-260     2  TAGENE                      NaN               NaN
# 1    DDX11L16-261     2  TAGENE                      NaN               NaN
# 2    DDX11L16-262     2  TAGENE                      NaN               NaN
# 3    DDX11L16-263     2  TAGENE                      NaN               NaN
# 4    DDX11L16-264     2  TAGENE                      NaN               NaN
#
#   hgnc_id  ont havana_gene protein_id ccdsid
# 0     NaN  NaN         NaN        NaN    NaN
# 1     NaN  NaN         NaN        NaN    NaN
# 2     NaN  NaN         NaN        NaN    NaN
# 3     NaN  NaN         NaN        NaN    NaN
# 4     NaN  NaN         NaN        NaN    NaN

# %%
# Threshold in base pairs
UPSTREAM_THRESHOLD = 100_000

# First, get the list of annotated TSS per gene
# Use the "start" for '+' strand, "end" for '-' strand
gencode_tss = gencode_v47_transcripts.copy()
gencode_tss["TSS"] = np.where(gencode_tss["strand"] == "+", gencode_tss["start"], gencode_tss["end"])
gencode_tss = gencode_tss[["gene_name", "strand", "TSS"]]

# Merge combined_df with gencode TSS of the same gene and strand
merged = combined_df.merge(
    gencode_tss,
    on=["gene_id", "Strand"],
    how="left",
    suffixes=("", "_gencode")
)

# Compute distance from each novel TSS to all annotated TSSs in the same gene
merged["distance_to_annotated_TSS"] = np.where(
    merged["Strand"] == "+",
    merged["TSS_gencode"] - merged["TSS_start"],
    merged["TSS_start"] - merged["TSS_gencode"]
)

# Keep only upstream distances
merged["upstream_distance"] = merged["distance_to_annotated_TSS"].where(merged["distance_to_annotated_TSS"] > 0, 0)

# Keep TSSs >100 kb upstream of any annotated TSS
# Group by novel TSS and gene to find max upstream distance
upstream_df = (
    merged.groupby(["TSS_start", "TSS_end", "gene_id", "Strand"])["upstream_distance"]
    .max()
    .reset_index()
)
unannotated_far_upstream_TSS = upstream_df[upstream_df["upstream_distance"] > UPSTREAM_THRESHOLD].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/18566350/ipykernel_3177472/3322415218.py in ?()
# ---> 11 # Threshold in base pairs
#      12 UPSTREAM_THRESHOLD = 100_000
#      13
#      14 # First, get the list of annotated TSS per gene
#
# ~/annotation_project/lib64/python3.9/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~/annotation_project/lib64/python3.9/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/annotation_project/lib64/python3.9/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/annotation_project/lib64/python3.9/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# ~/annotation_project/lib64/python3.9/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'gene_id'

# %%
unannotated_far_upstream_TSS = combined_df[combined_df["far_upstream"]].copy()

# %%
unannotated_far_upstream_TSS[unannotated_far_upstream_TSS["Gene name"] == "SYT16"]
# Out:
# Empty DataFrame
# Columns: [transcript_id, chr, exons, matched_to, matched_ref_id, category, unannotated_exons, best_match_ref_id, largest_overlap_gencode_id, Strand, summarized_category, ref_id, stripped_ref_id, Gene stable ID, Gene name, Gene type, gene_category, og_gene_id, peak_name, peak_type, mean_TPM_ref, log2_tx_exp, gene_exp_ref, relative_tx_exp, TSS_TPM_per_gene, Relative TSS usage, TSS_type, TSS_start, TSS_end, distance_to_closest_TSS, closest_ref_id, TSS distance category, TSS_name, start, end, far_upstream]
# Index: []

# %%
combined_df[combined_df["Gene name"] == "SYT16"]
# Out:
#             transcript_id    chr  \
# 82078         PBT00131765  chr14
# 82079         PBT00131766  chr14
# 82080         PBT00131767  chr14
# 82081         PBT00131769  chr14
# 82082         PBT00131770  chr14
# 82083         PBT00131771  chr14
# 82224        STRT00610923  chr14
# 82314        STRT00616169  chr14
# 82327        STRT00616988  chr14
# 82328        STRT00616989  chr14
# 82368        STRT00618618  chr14
# 82439        STRT00621499  chr14
# 82446        STRT00621777  chr14
# 82458        STRT00622240  chr14
# 82475        STRT00622725  chr14
# 82658        STRT00630377  chr14
# 82691        STRT00631684  chr14
# 82715        STRT00633209  chr14
# 82775        STRT00634743  chr14
# 82830        STRT00636109  chr14
# 82978        STRT00641356  chr14
# 83006        STRT00642149  chr14
# 83121        STRT00646277  chr14
# 83122        STRT00646279  chr14
# 83182        STRT00648002  chr14
# 83207        STRT00649690  chr14
# 83208        STRT00649691  chr14
# 83209        STRT00649692  chr14
# 83239        STRT00650571  chr14
# 83249        STRT00650986  chr14
# 83250        STRT00650987  chr14
# 83269        STRT00651470  chr14
# 83285        STRT00651770  chr14
# 83361        STRT00653899  chr14
# 83383        STRT00654436  chr14
# 83460        STRT00656558  chr14
# 83468        STRT00656980  chr14
# 83545        STRT00659335  chr14
# 83560        STRT00663261  chr14
# 83744        STRT00670730  chr14
# 83772        STRT00671343  chr14
# 83773        STRT00671344  chr14
# 181721  FTMT25500036294.1  chr14
# 181919  MICT00000105632.1  chr14
# 181920  MICT00000105633.1  chr14
# 187086       STRT00669217  chr14
# 326567        PBT00131759  chr14
# 326807       STRT00667431  chr14
#
#                                                     exons matched_to  \
# 82078   [(61884880, 61885249), (61897253, 61897355), (...        NaN
# 82079   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 82080   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 82081   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 82082   [(61884903, 61885249), (61970132, 61970311), (...        NaN
# 82083   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82224   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82314   [(61884814, 61884983), (61885077, 61885249), (...        NaN
# 82327   [(61884843, 61885249), (61897253, 61897355), (...        NaN
# 82328   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82368   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82439   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82446   [(61812742, 61812810), (61885077, 61885249), (...        NaN
# 82458   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82475   [(61884914, 61884983), (61885077, 61885249), (...        NaN
# 82658   [(61884795, 61884983), (61885077, 61885249), (...        NaN
# 82691   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82715   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82775   [(61885175, 61885249), (61897253, 61897355), (...        NaN
# 82830   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82978   [(61884900, 61884983), (61885077, 61885249), (...        NaN
# 83006   [(61884894, 61884983), (61885077, 61885249), (...        NaN
# 83121   [(61884842, 61885249), (61908655, 61908734), (...        NaN
# 83122   [(61884841, 61885249), (61897253, 61897355), (...        NaN
# 83182   [(61884903, 61885249), (61908655, 61908734), (...        NaN
# 83207   [(61885175, 61885249), (61897253, 61897355), (...        NaN
# 83208   [(61884898, 61885249), (61908655, 61908734), (...        NaN
# 83209   [(61884813, 61885249), (61908655, 61908734), (...        NaN
# 83239   [(61812712, 61812810), (61885077, 61885249), (...        NaN
# 83249   [(61884903, 61884983), (61885077, 61885249), (...        NaN
# 83250   [(61884903, 61885249), (61970132, 61970311), (...        NaN
# 83269   [(61884829, 61885249), (61970132, 61970311), (...        NaN
# 83285   [(61884793, 61885249), (61908655, 61908734), (...        NaN
# 83361   [(61885175, 61885249), (61970132, 61985633), (...        NaN
# 83383   [(61884795, 61884983), (61885077, 61885249), (...        NaN
# 83460   [(61884843, 61885249), (61970132, 61970311), (...        NaN
# 83468   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 83545   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 83560   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 83744   [(61884903, 61884983), (61885077, 61885249), (...        NaN
# 83772   [(61884841, 61885249), (61970132, 61970311), (...        NaN
# 83773   [(61884841, 61885249), (61897253, 61897355), (...        NaN
# 181721  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 181919  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 181920  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 187086  [(61812760, 61812810), (61970132, 61970311), (...        NaN
# 326567       [(61884858, 61885249), (61970132, 61973542)]        NaN
# 326807  [(61884840, 61884983), (61885077, 61885249), (...        NaN
#
#                                            matched_ref_id  \
# 82078                               ['ENST00000554436.1']
# 82079   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 82080   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82081   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82082   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 82083   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82224   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82314   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82327                               ['ENST00000554436.1']
# 82328   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82368   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82439   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 82446   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82458   ['ENST00000554138.1', 'ENST00000683842.1', 'EN...
# 82475   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82658   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82691   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 82715   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 82775                               ['ENST00000554436.1']
# 82830   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 82978   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83006   ['ENST00000554138.1', 'ENST00000683842.1', 'EN...
# 83121   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83122   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83182   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83207                               ['ENST00000554436.1']
# 83208   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83209   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83239   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83249   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83250   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83269   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83285   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83361   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83383   ['ENST00000554138.1', 'ENST00000683842.1', 'EN...
# 83460   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83468   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83545   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 83560   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83744   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83772   ['ENST00000555409.1', 'ENST00000554138.1', 'EN...
# 83773   ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 181721  ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 181919  ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 181920  ['ENST00000555409.1', 'ENST00000553426.2', 'EN...
# 187086  ['ENST00000683842.1', 'ENST00000554436.1', 'EN...
# 326567                                                NaN
# 326807                                                NaN
#
#                                                  category  \
# 82078   Transcripts with annotated exons and non-overl...
# 82079   Transcripts with annotated exons and non-overl...
# 82080   Transcripts with annotated exons and non-overl...
# 82081   Transcripts with annotated exons and non-overl...
# 82082   Transcripts with annotated exons and non-overl...
# 82083   Transcripts with annotated exons and non-overl...
# 82224   Transcripts with annotated exons and non-overl...
# 82314   Transcripts with annotated exons and non-overl...
# 82327   Transcripts with annotated exons and non-overl...
# 82328   Transcripts with annotated exons and non-overl...
# 82368   Transcripts with annotated exons and non-overl...
# 82439   Transcripts with annotated exons and non-overl...
# 82446   Transcripts with annotated exons and non-overl...
# 82458   Transcripts with annotated exons and non-overl...
# 82475   Transcripts with annotated exons and non-overl...
# 82658   Transcripts with annotated exons and non-overl...
# 82691   Transcripts with annotated exons and non-overl...
# 82715   Transcripts with annotated exons and non-overl...
# 82775   Transcripts with annotated exons and non-overl...
# 82830   Transcripts with annotated exons and non-overl...
# 82978   Transcripts with annotated exons and non-overl...
# 83006   Transcripts with annotated exons and non-overl...
# 83121   Transcripts with annotated exons and non-overl...
# 83122   Transcripts with annotated exons and non-overl...
# 83182   Transcripts with annotated exons and non-overl...
# 83207   Transcripts with annotated exons and non-overl...
# 83208   Transcripts with annotated exons and non-overl...
# 83209   Transcripts with annotated exons and non-overl...
# 83239   Transcripts with annotated exons and non-overl...
# 83249   Transcripts with annotated exons and non-overl...
# 83250   Transcripts with annotated exons and non-overl...
# 83269   Transcripts with annotated exons and non-overl...
# 83285   Transcripts with annotated exons and non-overl...
# 83361   Transcripts with annotated exons and non-overl...
# 83383   Transcripts with annotated exons and non-overl...
# 83460   Transcripts with annotated exons and non-overl...
# 83468   Transcripts with annotated exons and non-overl...
# 83545   Transcripts with annotated exons and non-overl...
# 83560   Transcripts with annotated exons and non-overl...
# 83744   Transcripts with annotated exons and non-overl...
# 83772   Transcripts with annotated exons and non-overl...
# 83773   Transcripts with annotated exons and non-overl...
# 181721  Transcripts with annotated exons and only over...
# 181919  Transcripts with annotated exons and only over...
# 181920  Transcripts with annotated exons and only over...
# 187086  Transcripts with annotated exons and only over...
# 326567  Fully unannotated transcripts with overlapping...
# 326807  Fully unannotated transcripts with overlapping...
#
#                                         unannotated_exons  best_match_ref_id  \
# 82078        [(61884880, 61885249), (61903911, 61907364)]  ENST00000554436.1
# 82079        [(61884880, 61885249), (62075135, 62075604)]  ENST00000683842.1
# 82080        [(61884880, 61885249), (62084196, 62086479)]  ENST00000683842.1
# 82081                              [(61884880, 61885249)]  ENST00000683842.1
# 82082        [(61884903, 61885249), (62075135, 62075605)]  ENST00000636133.1
# 82083        [(61885175, 61885249), (62084196, 62086705)]  ENST00000683842.1
# 82224        [(61885175, 61885249), (62100563, 62101078)]  ENST00000683842.1
# 82314        [(61884814, 61884983), (61885077, 61885249)]  ENST00000683842.1
# 82327        [(61884843, 61885249), (61907437, 61907735)]  ENST00000554436.1
# 82328        [(61885175, 61885249), (62100563, 62107102)]  ENST00000683842.1
# 82368                              [(61885175, 61885249)]  ENST00000683842.1
# 82439        [(61885175, 61885249), (62076329, 62076481)]  ENST00000636133.1
# 82446                              [(61885077, 61885249)]  ENST00000683842.1
# 82458        [(61885175, 61885249), (61973792, 61973864)]  ENST00000554436.1
# 82475   [(61884914, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 82658   [(61884795, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 82691   [(61885175, 61885249), (62100394, 62100707), (...  ENST00000683842.1
# 82715        [(61885175, 61885249), (62076329, 62076356)]  ENST00000683842.1
# 82775   [(61885175, 61885249), (61902304, 61902417), (...  ENST00000554436.1
# 82830        [(61885175, 61885249), (62079340, 62079417)]  ENST00000683842.1
# 82978   [(61884900, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 83006   [(61884894, 61884983), (61885077, 61885249), (...  ENST00000554436.1
# 83121   [(61884842, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83122        [(61884841, 61885249), (61908655, 61908734)]  ENST00000683842.1
# 83182   [(61884903, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83207        [(61885175, 61885249), (61970132, 61983478)]  ENST00000554436.1
# 83208   [(61884898, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83209        [(61884813, 61885249), (61908655, 61908734)]  ENST00000683842.1
# 83239                              [(61885077, 61885249)]  ENST00000683842.1
# 83249   [(61884903, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 83250   [(61884903, 61885249), (61985542, 61985633), (...  ENST00000683842.1
# 83269   [(61884829, 61885249), (61995953, 61996542), (...  ENST00000636133.1
# 83285   [(61884793, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83361   [(61885175, 61885249), (61970132, 61985633), (...  ENST00000683842.1
# 83383   [(61884795, 61884983), (61885077, 61885249), (...  ENST00000554436.1
# 83460   [(61884843, 61885249), (61985542, 61985633), (...  ENST00000683842.1
# 83468        [(61885175, 61885249), (62075135, 62075753)]  ENST00000683842.1
# 83545        [(61884880, 61885249), (62100394, 62117588)]  ENST00000683842.1
# 83560   [(61885175, 61885249), (62074575, 62074693), (...  ENST00000636133.1
# 83744   [(61884903, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 83772        [(61884841, 61885249), (62080834, 62081326)]  ENST00000636133.1
# 83773                              [(61884841, 61885249)]  ENST00000683842.1
# 181721                             [(62100394, 62101078)]  ENST00000683842.1
# 181919                             [(62100394, 62103421)]  ENST00000683842.1
# 181920                             [(62100394, 62103421)]  ENST00000683842.1
# 187086                             [(61995953, 61997649)]  ENST00000636133.1
# 326567                                                NaN                NaN
# 326807                                                NaN                NaN
#
#        largest_overlap_gencode_id Strand  \
# 82078                         NaN      +
# 82079                         NaN      +
# 82080                         NaN      +
# 82081                         NaN      +
# 82082                         NaN      +
# 82083                         NaN      +
# 82224                         NaN      +
# 82314                         NaN      +
# 82327                         NaN      +
# 82328                         NaN      +
# 82368                         NaN      +
# 82439                         NaN      +
# 82446                         NaN      +
# 82458                         NaN      +
# 82475                         NaN      +
# 82658                         NaN      +
# 82691                         NaN      +
# 82715                         NaN      +
# 82775                         NaN      +
# 82830                         NaN      +
# 82978                         NaN      +
# 83006                         NaN      +
# 83121                         NaN      +
# 83122                         NaN      +
# 83182                         NaN      +
# 83207                         NaN      +
# 83208                         NaN      +
# 83209                         NaN      +
# 83239                         NaN      +
# 83249                         NaN      +
# 83250                         NaN      +
# 83269                         NaN      +
# 83285                         NaN      +
# 83361                         NaN      +
# 83383                         NaN      +
# 83460                         NaN      +
# 83468                         NaN      +
# 83545                         NaN      +
# 83560                         NaN      +
# 83744                         NaN      +
# 83772                         NaN      +
# 83773                         NaN      +
# 181721                        NaN      +
# 181919                        NaN      +
# 181920                        NaN      +
# 187086                        NaN      +
# 326567          ENST00000554138.1      +
# 326807          ENST00000554138.1      +
#
#                                       summarized_category             ref_id  \
# 82078   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 82079   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82080   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82081   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82082   Unannotated transcripts with annotated and una...  ENST00000636133.1
# 82083   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82224   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82314   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82327   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 82328   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82368   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82439   Unannotated transcripts with annotated and una...  ENST00000636133.1
# 82446   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82458   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 82475   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82658   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82691   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82715   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82775   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 82830   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 82978   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83006   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 83121   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83122   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83182   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83207   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 83208   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83209   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83239   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83249   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83250   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83269   Unannotated transcripts with annotated and una...  ENST00000636133.1
# 83285   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83361   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83383   Unannotated transcripts with annotated and una...  ENST00000554436.1
# 83460   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83468   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83545   Unannotated transcripts with annotated and una...  ENST00000683842.1
# 83560   Unannotated transcripts with annotated and una...  ENST00000636133.1
# 83744   Unannotated transcripts with annotated and una...  ENST00000683842.1
#
 >100bp  P23082_U  61812703.0  62112550.0         False
# 83006                 >100bp  P23082_U  61864880.0  61970313.0         False
# 83121                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83122                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83182                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83207                 >100bp  P23083_U  61864880.0  61970313.0         False
# 83208                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83209                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83239                <=100bp  P23080_A  61812703.0  62112550.0         False
# 83249                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83250                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83269                 >100bp  P23082_U  61812721.0  62075391.0         False
# 83285                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83361                 >100bp  P23083_U  61812703.0  62112550.0         False
# 83383                 >100bp  P23082_U  61864880.0  61970313.0         False
# 83460                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83468                 >100bp  P23083_U  61812703.0  62112550.0         False
# 83545                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83560                 >100bp  P23083_U  61812721.0  62075391.0         False
# 83744                 >100bp  P23082_U  61812703.0  62112550.0         False
# 83772                 >100bp  P23082_U  61812721.0  62075391.0         False
# 83773                 >100bp  P23082_U  61812703.0  62112550.0         False
# 181721               <=100bp  P23080_A  61812703.0  62112550.0         False
# 181919               <=100bp  P23080_A  61812703.0  62112550.0         False
# 181920               <=100bp  P23080_A  61812703.0  62112550.0         False
# 187086               <=100bp  P23080_A  61812721.0  62075391.0         False
# 326567                >100bp  P23082_U  61811974.0  61970319.0         False
# 326807                >100bp  P23082_U  61811974.0  61970319.0         False

# %%
# combined_df.to_csv('jessies_gffcompare.tsv', sep='\t', index=False)

# %%
combined_df["gene_category"].value_counts()
# Out:
# gene_category
# protein_coding     330781
# lncRNA              40992
# unmapped             3291
# other_noncoding      1278
# Name: count, dtype: int64

# %%
protein_coding_tss = combined_df[(combined_df["gene_category"] == "protein_coding") & (combined_df["distance_to_closest_TSS"].notna())]

# %%
protein_coding_tss["peak_name"].nunique()
# Out:
# 33277

# %%
# Nr of unannotated TSSs 
protein_coding_tss[protein_coding_tss["distance_to_closest_TSS"] > 100]["peak_name"].nunique()
# Out:
# 10589

# %%
10589/33277 * 100
# Out:
# 31.820777113321512

# %%
# Nr of annotated TSSs 
protein_coding_tss[protein_coding_tss["distance_to_closest_TSS"] <= 100]["peak_name"].nunique()
# Out:
# 22688

# %%
bin_edges = [0, 10, 100, 1_000, 10_000, 100_000, float("inf")]
bin_labels = ["0–10bp", "10–100bp", "100bp–1kb", "1–10kb", "10–100kb", ">100kb"]

protein_coding_tss["bin"] = pd.cut(protein_coding_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
counts = protein_coding_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
counts
# Out:
# /tmp/18326996/ipykernel_1285801/1667805242.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   protein_coding_tss["bin"] = pd.cut(protein_coding_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
# /tmp/18326996/ipykernel_1285801/1667805242.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = protein_coding_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
# peak_type  Permissive  Robust
# bin
# 0–10bp           5158   11832
# 10–100bp         3398    2300
# 100bp–1kb        4731     939
# 1–10kb           2980     406
# 10–100kb         1315     158
# >100kb             46      14

# %%
counts.values.sum()
# Out:
# np.int64(33277)

# %%
counts["Permissive"].iloc[-4:].sum()
# Out:
# np.int64(9072)

# %%
counts["Robust"].iloc[-4:].sum()
# Out:
# np.int64(1517)

# %%
colours =  ["#377eb8", "#e41a1c"]
counts.plot(kind="bar", stacked=True, figsize=(3.2, 3), width=1, color = colours)
plt.xlabel("Distance to closest\nsame-strand GENCODE TSS", fontsize=11)
plt.ylabel("TSSs mapping to\nprotein-coding transcripts", fontsize=11)
plt.xticks(rotation=45)
plt.legend(title=None , frameon=False, fontsize=11)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

n_bars   = len(counts.index)
n_stacks = len(counts.columns)

for i in (0, 1):               
    for k in range(n_stacks):    
        ax.patches[i + k*n_bars].set_alpha(0.4)

totals = counts.sum(axis=1)
for i, total in enumerate(totals):
    ax.text(
        i,                
        total + 200,            
        f"{total:,}",        
        ha='center', 
        va='bottom', 
        fontsize=8
    )

plt.tight_layout()
plt.show()

# %%
non_coding_tss = combined_df[(combined_df["gene_category"].isin(["lncRNA"])) & (combined_df["distance_to_closest_TSS"].notna())]

# %%
non_coding_tss["bin"] = pd.cut(non_coding_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
counts = non_coding_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
counts
# Out:
# /tmp/18110612/ipykernel_1287073/1069495795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_coding_tss["bin"] = pd.cut(non_coding_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
# /tmp/18110612/ipykernel_1287073/1069495795.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = non_coding_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
# peak_type  Permissive  Robust
# bin
# 0–10bp           2504    1457
# 10–100bp          761     256
# 100bp–1kb         613     106
# 1–10kb            252      42
# 10–100kb          148      31
# >100kb              8       6

# %%
counts["Permissive"].iloc[-4:].sum()
# Out:
# np.int64(1021)

# %%
counts["Robust"].iloc[-4:].sum()
# Out:
# np.int64(185)

# %%
counts.values.sum()
# Out:
# np.int64(6184)

# %%
counts.sum(axis=1)
# Out:
# bin
# 0–10bp       3961
# 10–100bp     1017
# 100bp–1kb     719
# 1–10kb        294
# 10–100kb      179
# >100kb         14
# dtype: int64

# %%
719 + 294 + 179 + 14
# Out:
# 1206

# %%
1206/6184 *100
# Out:
# 19.501940491591203

# %%
counts.plot(kind="bar", stacked=True, figsize=(3, 3), width=1.0)
plt.xlabel("Distance to closest\nsame-strand GENCODE TSS")
plt.ylabel("TSSs mapping to\nlncRNA transcripts")
plt.xticks(rotation=45)
plt.legend(title=None , frameon=False)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for i in (0, 1):               
    for k in range(n_stacks):    
        ax.patches[i + k*n_bars].set_alpha(0.4)

plt.tight_layout()
plt.show()

# %%
unmapped_tss = combined_df[(combined_df["gene_category"] == "unmapped") & (combined_df["distance_to_closest_TSS"].notna())]

# %%
unmapped_tss["bin"] = pd.cut(unmapped_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
counts = unmapped_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
counts
# Out:
# /tmp/18081056/ipykernel_3839151/3122500490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unmapped_tss["bin"] = pd.cut(unmapped_tss["distance_to_closest_TSS"], bins=bin_edges, labels=bin_labels, right=True, include_lowest=True)
# /tmp/18081056/ipykernel_3839151/3122500490.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = unmapped_tss.groupby(["bin", "peak_type"])["peak_name"].nunique().unstack(fill_value=0)
# peak_type  Permissive  Robust
# bin
# 0–10bp              2       9
# 10–100bp            8       2
# 100bp–1kb         127      25
# 1–10kb            451      53
# 10–100kb          834      99
# >100kb             74      15

# %%
counts.values.sum()
# Out:
# np.int64(1699)

# %%
counts.sum(axis=1)
# Out:
# bin
# 0–10bp        11
# 10–100bp      10
# 100bp–1kb    152
# 1–10kb       504
# 10–100kb     933
# >100kb        89
# dtype: int64

# %%
152 + 504 + 933 + 89
# Out:
# 1678

# %%
1678/1699 *100
# Out:
# 98.76397881106533

# %%
counts.plot(kind="bar", stacked=True, figsize=(3, 3), width=1.0)
plt.xlabel("Distance to closest\nsame-strand GENCODE TSS")
plt.ylabel("TSSs mapping to\nnon-overlapping transcripts")
plt.xticks(rotation=45)
plt.legend(title=None , frameon=False)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for i in (0, 1):               
    for k in range(n_stacks):    
        ax.patches[i + k*n_bars].set_alpha(0.4)

plt.tight_layout()
plt.show()

# %%
unmapped_tss[unmapped_tss["bin"] == "0–10bp"]
# Out:
#             transcript_id    chr  \
# 337315        PBT00110342  chr12
# 337426       STRT00587807  chr13
# 337614       STRT00733824  chr15
# 338133  ENCT00000252665.1   chr2
# 338363       STRT01277299   chr2
# 338396        PBT00270027  chr20
# 338936       STRT01635746   chr4
# 339244        PBT00372680   chr6
# 339434       STRT01937802   chr7
# 339482       STRT01980882   chr7
# 339675       STRT02104540   chr8
#
#                                                    exons matched_to  \
# 337315                          [(113218324, 113220995)]        NaN
# 337426      [(36916643, 36916820), (36919883, 36919995)]        NaN
# 337614                            [(39259879, 39273835)]        NaN
# 338133  [(206071295, 206079186), (206079322, 206085855)]        NaN
# 338363      [(70238661, 70238884), (70248663, 70248720)]        NaN
# 338396                            [(35090397, 35092605)]        NaN
# 338936                                [(133267, 144502)]        NaN
# 339244  [(159725618, 159726796), (159727383, 159727430)]        NaN
# 339434                          [(142760282, 142760368)]        NaN
# 339482                          [(129611923, 129612741)]        NaN
# 339675      [(28890362, 28890380), (28907872, 28908227)]        NaN
#
#        matched_ref_id                                           category  \
# 337315            NaN  Fully unannotated transcripts without any over...
# 337426            NaN  Fully unannotated transcripts without any over...
# 337614            NaN  Fully unannotated transcripts without any over...
# 338133            NaN  Fully unannotated transcripts without any over...
# 338363            NaN  Fully unannotated transcripts without any over...
# 338396            NaN  Fully unannotated transcripts without any over...
# 338936            NaN  Fully unannotated transcripts without any over...
# 339244            NaN  Fully unannotated transcripts without any over...
# 339434            NaN  Fully unannotated transcripts without any over...
# 339482            NaN  Fully unannotated transcripts without any over...
# 339675            NaN  Fully unannotated transcripts without any over...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 337315               NaN               NaN                        NaN      -
# 337426               NaN               NaN                        NaN      -
# 337614               NaN               NaN                        NaN      -
# 338133               NaN               NaN                        NaN      -
# 338363               NaN               NaN                        NaN      -
# 338396               NaN               NaN                        NaN      -
# 338936               NaN               NaN                        NaN      +
# 339244               NaN               NaN                        NaN      -
# 339434               NaN               NaN                        NaN      +
# 339482               NaN               NaN                        NaN      +
# 339675               NaN               NaN                        NaN      +
#
#                                       summarized_category ref_id  \
# 337315  Unannotated transcripts without any annotated ...    NaN
# 337426  Unannotated transcripts without any annotated ...    NaN
# 337614  Unannotated transcripts without any annotated ...    NaN
# 338133  Unannotated transcripts without any annotated ...    NaN
# 338363  Unannotated transcripts without any annotated ...    NaN
# 338396  Unannotated transcripts without any annotated ...    NaN
# 338936  Unannotated transcripts without any annotated ...    NaN
# 339244  Unannotated transcripts without any annotated ...    NaN
# 339434  Unannotated transcripts without any annotated ...    NaN
# 339482  Unannotated transcripts without any annotated ...    NaN
# 339675  Unannotated transcripts without any annotated ...    NaN
#
#        stripped_ref_id Gene stable ID   Gene name Gene type gene_category  \
# 337315             NaN     Peak_19590  Peak_19590       NaN      unmapped
# 337426             NaN     Peak_20790  Peak_20790       NaN      unmapped
# 337614             NaN     Peak_25046  Peak_25046       NaN      unmapped
# 338133             NaN     Peak_45209  Peak_45209       NaN      unmapped
# 338363             NaN     Peak_42417  Peak_42417       NaN      unmapped
# 338396             NaN     Peak_47440  Peak_47440       NaN      unmapped
# 338936             NaN     Peak_56054  Peak_56054       NaN      unmapped
# 339244             NaN     Peak_67277  Peak_67277       NaN      unmapped
# 339434             NaN     Peak_71207  Peak_71207       NaN      unmapped
# 339482             NaN     Peak_70727  Peak_70727       NaN      unmapped
# 339675             NaN     Peak_72502  Peak_72502       NaN      unmapped
#
#              og_gene_id                             peak_name   peak_type  \
# 337315        PBG013473  chr12:113221026-113221098_Peak_19590      Robust
# 337426       STRG065316    chr13:36920034-36920243_Peak_20790      Robust
# 337614       STRG083194    chr15:39273858-39273906_Peak_25046  Permissive
# 338133       FTMG031640   chr2:206085773-206086301_Peak_45209      Robust
# 338363  ENSG00000116001     chr2:70248572-70248698_Peak_42417      Robust
# 338396        PBG033051    chr20:35092618-35092807_Peak_47440      Robust
# 338936  ENSG00000250312         chr4:124482-124512_Peak_56054      Robust
# 339244        PBG046995   chr6:159727349-159727408_Peak_67277  Permissive
# 339434  ENSG00000250606   chr7:142760267-142760402_Peak_71207      Robust
# 339482       STRG227139   chr7:129611715-129611884_Peak_70727      Robust
# 339675  ENSG00000147421     chr8:28890389-28890494_Peak_72502      Robust
#
#         mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 337315      0.037685    -4.729876      0.037685              1.0
# 337426      0.242646    -2.043075      0.242646              1.0
# 337614      0.328954    -1.604043      0.328954              1.0
# 338133      0.227246    -2.137673      0.227246              1.0
# 338363      0.442263    -1.177022      0.442263              1.0
# 338396      0.168396    -2.570072      0.168396              1.0
# 338936      0.248522    -2.008556      0.248522              1.0
# 339244      1.228492     0.296889      1.228492              1.0
# 339434      1.572898     0.653425      1.572898              1.0
# 339482      0.688670    -0.538114      0.688670              1.0
# 339675      0.394582    -1.341603      0.394582              1.0
#
#         TSS_TPM_per_gene  Relative TSS usage    TSS_type  TSS_start  \
# 337315          0.037685                 1.0  unique TSS  113221026
# 337426          0.242646                 1.0  unique TSS   36920034
# 337614          0.328954                 1.0  unique TSS   39273858
# 338133          0.227246                 1.0  unique TSS  206085773
# 338363          0.442263                 1.0  unique TSS   70248572
# 338396          0.168396                 1.0  unique TSS   35092618
# 338936          0.248522                 1.0  unique TSS     124482
# 339244          1.228492                 1.0  unique TSS  159727349
# 339434          1.572898                 1.0  unique TSS  142760267
# 339482          0.688670                 1.0  unique TSS  129611715
# 339675          0.394582                 1.0  unique TSS   28890389
#
#           TSS_end  distance_to_closest_TSS     closest_ref_id  \
# 337315  113221098                        1  ENST00000546692.1
# 337426   36920243                        5  ENST00000379826.5
# 337614   39273906                        1  ENST00000561058.5
# 338133  206086301                        2  ENST00000414320.1
# 338363   70248698                        5  ENST00000496452.5
# 338396   35092807                        0  ENST00000252015.3
# 338936     124512                        4  ENST00000510175.6
# 339244  159727408                        4  ENST00000401980.3
# 339434  142760402                        4  ENST00000632998.1
# 339482  129611884                        5  ENST00000393232.6
# 339675   28890494                        6  ENST00000519662.5
#
#        TSS distance category  TSS_name     bin
# 337315               <=100bp  P19590_A  0–10bp
# 337426               <=100bp  P20790_A  0–10bp
# 337614               <=100bp  P25046_A  0–10bp
# 338133               <=100bp  P45209_A  0–10bp
# 338363               <=100bp  P42417_A  0–10bp
# 338396               <=100bp  P47440_A  0–10bp
# 338936               <=100bp  P56054_A  0–10bp
# 339244               <=100bp  P67277_A  0–10bp
# 339434               <=100bp  P71207_A  0–10bp
# 339482               <=100bp  P70727_A  0–10bp
# 339675               <=100bp  P72502_A  0–10bp

# %% [markdown]
# ## Relative TSS usage

# %%
combined_df[combined_df["TSS_type"] != "unique TSS"]["Gene stable ID"].nunique()
# Out:
# 9693

# %%
grouped = combined_df[combined_df["TSS_type"] != "unique TSS"].groupby(["Gene stable ID", "TSS_type"])["relative_tx_exp"].sum().reset_index()

pivot = grouped.pivot(index="Gene stable ID", columns="TSS_type", values="relative_tx_exp").fillna(0)


# Reorder columns
ordered_cols = [col for col in ["main TSS", "secondary TSS", "minor TSS"] if col in pivot.columns]
pivot = pivot[ordered_cols]

# Sort genes 
pivot = pivot.sort_values("main TSS", ascending=True)

pivot = pivot.rename(columns={
    "main TSS": "Primary",
    "secondary TSS": "Secondary",
    "minor TSS": "Others"
})

# Plot
colors = {
    "Primary": "#2274a5",
    "Secondary": "#f75c03",
    "Others": "#f1c40f"
}

plt.figure(figsize=(7, 3))
plt.stackplot(
    range(len(pivot)),
    [pivot[col] for col in pivot.columns],
    labels=pivot.columns,
    colors=[colors[col] for col in pivot.columns]
)

plt.legend(loc="lower right")
plt.ylabel("Proportion of expression")
plt.xlabel("Genes ranked by proportion of primary promoter expression")
plt.ylim(0, 1)
plt.xlim(0, len(pivot))
plt.tight_layout()
plt.show()

# %%
secondary_20 = pivot[pivot["Secondary"]>= 0.2]
secondary_20
# Out:
# TSS_type          Primary  Secondary    Others
# Gene stable ID
# ENSG00000012061  0.206305   0.202836  0.590859
# ENSG00000196924  0.211642   0.207288  0.581070
# ENSG00000111885  0.214943   0.208387  0.576670
# ENSG00000181722  0.221673   0.427021  0.351305
# ENSG00000116539  0.221932   0.209724  0.568344
# ...                   ...        ...       ...
# ENSG00000138311  0.799627   0.200373  0.000000
# ENSG00000135976  0.799740   0.200260  0.000000
# ENSG00000288602  0.799788   0.200212  0.000000
# ENSG00000213551  0.799957   0.200043  0.000000
# ENSG00000158106  0.799995   0.200005  0.000000
#
# [4707 rows x 3 columns]

# %%
combined_df[(combined_df["Gene stable ID"].isin(secondary_20.index))& (combined_df["TSS_type"] == "secondary TSS")].groupby("TSS distance category")["TSS_name"].nunique()
# Out:
# TSS distance category
# <=100bp    3279
# >100bp     1803
# Name: TSS_name, dtype: int64

# %%
1803 / (1803 + 3279) *100
# Out:
# 35.47815820543093

# %% [markdown]
# ### Different way of defining secondary promoter (second highest expression)

# %%
combined_df["TSS_rank"] = combined_df.groupby("Gene stable ID")["Relative TSS usage"].rank(method="dense", ascending=False)

# %%
def get_TSS_type(row):
    if row["Relative TSS usage"] == 1:
        return "unique TSS"
    elif row["TSS_rank"] == 1:
        return "main TSS"
    elif row["TSS_rank"] == 2:
        return "secondary TSS"
    else:
        return "minor TSS"

combined_df["Ranked_TSS_type"] = combined_df.apply(get_TSS_type, axis=1)
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 1          lncRNA          lncRNA  ENSG00000228606
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 4          lncRNA          lncRNA       FTMG005195
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 1  chr1:160261726-160261763_Peak_5604  Permissive      0.358414    -1.480300
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 4  chr1:233327323-233327461_Peak_7654  Permissive      0.616169    -0.698603
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 1      0.743874         0.481821          0.743874            1.000000
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 4      2.291033         0.268948          2.093885            0.913948
#
#      TSS_type    TSS_start      TSS_end  distance_to_closest_TSS  \
# 0   minor TSS   61077221.0   61077380.0                      6.0
# 1  unique TSS  160261726.0  160261763.0                      0.0
# 2    main TSS  239386576.0  239386587.0                      8.0
# 3  unique TSS   23217498.0   23217499.0                      3.0
# 4    main TSS  233327323.0  233327461.0                      3.0
#
#       closest_ref_id TSS distance category TSS_name  TSS_rank Ranked_TSS_type
# 0  ENST00000699964.1               <=100bp  P3111_A       4.0       minor TSS
# 1  ENST00000442130.1               <=100bp  P5604_A       1.0      unique TSS
# 2  ENST00000676153.1               <=100bp  P7900_A       1.0        main TSS
# 3  ENST00000374619.2               <=100bp  P1212_A       1.0      unique TSS
# 4  ENST00000771586.1               <=100bp  P7654_A       1.0        main TSS

# %%
# How many genes with >1 TSS?
combined_df[combined_df["Ranked_TSS_type"] != "unique TSS"]["Gene stable ID"].nunique()
# Out:
# 9693

# %%
grouped = combined_df[combined_df["Ranked_TSS_type"] != "unique TSS"].groupby(["Gene stable ID", "Ranked_TSS_type"])["relative_tx_exp"].sum().reset_index()

pivot = grouped.pivot(index="Gene stable ID", columns="Ranked_TSS_type", values="relative_tx_exp").fillna(0)


# Reorder columns
ordered_cols = [col for col in ["main TSS", "secondary TSS", "minor TSS"] if col in pivot.columns]
pivot = pivot[ordered_cols]

# Sort genes 
pivot = pivot.sort_values("main TSS", ascending=True)

pivot = pivot.rename(columns={
    "main TSS": "Primary",
    "secondary TSS": "Secondary",
    "minor TSS": "Others"
})

pivot["Secondary_high"] = np.where(pivot["Secondary"] >= 0.2, pivot["Secondary"], 0)
pivot["Secondary_low"]  = np.where(pivot["Secondary"] < 0.2, pivot["Secondary"], 0)

# Plot
colors = {
    "Primary": "#1f77b4",
    "Secondary_high": "#2ca02c",   
    "Secondary_low": "#e69f00",    
    "Others": "#d3d3d3"
}

# ["#377eb8", "#e41a1c"]

plt.figure(figsize=(4, 2.3))
plt.stackplot(
    range(len(pivot)),
    [
        pivot["Primary"],
        pivot["Secondary_high"],
        pivot["Secondary_low"],
        pivot["Others"]
    ],
    labels=["Primary", "Secondary ≥20%", "Secondary <20%", "Other"],
    colors=[colors["Primary"], colors["Secondary_high"], colors["Secondary_low"], colors["Others"]]
)

plt.legend(loc="lower right", fontsize=10)
plt.ylabel("Proportion of\nexpression", fontsize=11)
plt.xlabel("Genes ranked by proportion of primary\npromoter expression", fontsize=11)
plt.ylim(0, 1)
plt.xlim(0, len(pivot))
plt.tight_layout()
plt.show()

# %%
combined_df["Ranked_TSS_type"].value_counts()
# Out:
# Ranked_TSS_type
# main TSS         169809
# unique TSS       117143
# secondary TSS     51111
# minor TSS         38279
# Name: count, dtype: int64

# %%
# Secondary promoters contributing >20% to total expression
secondary_20 = pivot[pivot["Secondary"]>= 0.2]
secondary_20
# Out:
# Ranked_TSS_type   Primary  Secondary    Others  Secondary_high  Secondary_low
# Gene stable ID
# ENSG00000012061  0.206305   0.202836  0.590859        0.202836            0.0
# ENSG00000196924  0.211642   0.207288  0.581070        0.207288            0.0
# ENSG00000111885  0.214943   0.208387  0.576670        0.208387            0.0
# ENSG00000181722  0.221673   0.218314  0.560013        0.218314            0.0
# ENSG00000116539  0.221932   0.209724  0.568344        0.209724            0.0
# ...                   ...        ...       ...             ...            ...
# ENSG00000138311  0.799627   0.200373  0.000000        0.200373            0.0
# ENSG00000135976  0.799740   0.200260  0.000000        0.200260            0.0
# ENSG00000288602  0.799788   0.200212  0.000000        0.200212            0.0
# ENSG00000213551  0.799957   0.200043  0.000000        0.200043            0.0
# ENSG00000158106  0.799995   0.200005  0.000000        0.200005            0.0
#
# [4707 rows x 5 columns]

# %%
# Percent of genes where secondary promoter contributes more than 20%
4702 / 9693 * 100
# Out:
# 48.509233467450734

# %%
secondary_20.index
# Out:
# Index(['ENSG00000012061', 'ENSG00000196924', 'ENSG00000111885',
#        'ENSG00000181722', 'ENSG00000116539', 'ENSG00000139209',
#        'ENSG00000173064', 'ENSG00000116016', 'ENSG00000134138',
#        'ENSG00000055118',
#        ...
#        'ENSG00000125656', 'ENSG00000221963', 'ENSG00000290831',
#        'ENSG00000161542', 'ENSG00000137941', 'ENSG00000138311',
#        'ENSG00000135976', 'ENSG00000288602', 'ENSG00000213551',
#        'ENSG00000158106'],
#       dtype='object', name='Gene stable ID', length=4707)

# %%
combined_df[combined_df["Gene stable ID"].isin(secondary_20.index)]["TSS_name"].nunique()
# Out:
# 15917

# %%
# How many unique TSSs contribute >20% expression to gene
combined_df[(combined_df["Gene stable ID"].isin(secondary_20.index)) & (combined_df["Ranked_TSS_type"] == "secondary TSS")]["TSS_name"].nunique()
# Out:
# 4680

# %%
combined_df[(combined_df["Gene stable ID"].isin(secondary_20.index)) & (combined_df["Ranked_TSS_type"] == "secondary TSS")].groupby("TSS distance category")["TSS_name"].nunique()
# Out:
# TSS distance category
# <=100bp    3031
# >100bp     1649
# Name: TSS_name, dtype: int64

# %%
3031 + 1649
# Out:
# 4680

# %%
# How many of secondary promoters (with >20% expression contribution) are unannotated
1649/4680
# Out:
# 0.3523504273504274

# %%
tss_multi = combined_df[combined_df["Ranked_TSS_type"] != "unique TSS"]
tss_multi.loc[tss_multi["TSS_name"].str.endswith("_U"), "TSS_name"].nunique()
# Out:
# 10953

# %%
top_tss = (
    tss_multi
    .loc[tss_multi.groupby("Gene name")["Relative TSS usage"].idxmax(),
         ["Gene name", "TSS_name", "Relative TSS usage"]]
)

# Count how many of those top TSS end with "_U"
count_genes_u = top_tss["TSS_name"].str.endswith("_U").sum()

print("Number of genes where top TSS ends with _U:", count_genes_u)
# Out:
# Number of genes where top TSS ends with _U: 976

# %%
top_tss[top_tss["TSS_name"].str.endswith("_U")]
# Out:
#        Gene name  TSS_name  Relative TSS usage
# 157260  AASDHPPT  P15201_U            0.595856
# 313300      ABL1  P77733_U            0.502124
# 42684     ABLIM1  P11032_U            0.355775
# 48971      ACACA  P32130_U            0.344485
# 103204     ACKR2  P52196_U            0.502259
# ...          ...       ...                 ...
# 91612     ZNF667  P40391_U            0.596097
# 117428     ZNRF2  P68236_U            0.397726
# 103145     ZPLD1  P53538_U            0.529278
# 71464     ZRANB1  P11330_U            0.619928
# 66205     ZSWIM5   P2588_U            0.550020
#
# [975 rows x 3 columns]

# %% [markdown]
# ## Alternative promoter usage of genes

# %%
tss_counts = combined_df.groupby(['Gene stable ID', 'peak_type'])['peak_name'].nunique().reset_index()
tss_counts['binned'] = tss_counts['peak_name'].apply(lambda x: x if x < 5 else 5)

tss_counts = tss_counts.groupby(['binned', 'peak_type'])['Gene stable ID'].nunique().unstack(fill_value=0)


labels = ['1', '2', '3', '4', '≥5']
tss_counts = tss_counts.reindex(index=[1,2,3,4,5])  # ensure all bins in order

tss_counts.index = labels
colours =  ["#377eb8", "#e41a1c"]

tss_counts.plot(kind='bar', stacked=False, figsize=(3,3), width=0.8, color=colours)
plt.xlabel('Number of TSS per gene', fontsize=11)
plt.ylabel('Number of genes', fontsize=11)
plt.xticks(rotation=0)
plt.legend(title=None , frameon=False, fontsize=11)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
tss_counts
# Out:
# peak_type  Permissive  Robust
# 1               10118   11515
# 2                2545    2532
# 3                1060     536
# 4                 509     148
# ≥5                565     100

# %%
print(f"Total number of genes with >1 TSS in Robust peak: {tss_counts.loc[['2', '3', '4', '≥5'], 'Robust'].sum()}")
# Out:
# Total number of genes with >1 TSS in Robust peak: 3316

# %%
combined_df["Gene stable ID"].nunique()
# Out:
# 22111

# %%
3316/22111 *100
# Out:
# 14.99706028673511

# %%
robust = combined_df[combined_df["peak_type"] == "Robust"]

# Identify genes with >1 unique peaks
gene_peak_counts = (robust
    .groupby("Gene stable ID")["peak_name"]
    .nunique()
    .reset_index(name="n_peaks")
)
multi_peak_genes = gene_peak_counts[gene_peak_counts["n_peaks"] > 1]["Gene stable ID"]

# Subset df to just these genes
robust_multi = robust[robust["Gene stable ID"].isin(multi_peak_genes)]

gene_cat_counts = (robust_multi
    .drop_duplicates(subset=["Gene stable ID", "gene_category"])
    .groupby("gene_category")["Gene stable ID"]
    .nunique()
)
print("Genes with >1 Robust peak, by gene_category:")
print(gene_cat_counts)


distance_counts = (robust_multi[robust_multi["gene_category"] == "protein_coding"]
    .groupby("TSS distance category")["peak_name"]
    .nunique()
)
print("\nWithin protein_coding, peaks-per-distance-category:")
print(distance_counts)
# Out:
# Genes with >1 Robust peak, by gene_category:
# gene_category
# lncRNA              190
# other_noncoding      17
# protein_coding     3109
# Name: Gene stable ID, dtype: int64
#
# Within protein_coding, peaks-per-distance-category:
# TSS distance category
# <=100bp    5708
# >100bp     1378
# Name: peak_name, dtype: int64

# %%
robust_multi["Gene stable ID"].nunique()
# Out:
# 3316

# %%
robust_multi.groupby("TSS distance category")["peak_name"].nunique()
# Out:
# TSS distance category
# <=100bp    5998
# >100bp     1432
# Name: peak_name, dtype: int64

# %%
1432/(5998 + 1432) *100
# Out:
# 19.27321668909825

# %% [markdown]
# ## Do different protein coding genes share the same TSS?

# %%
tss_gene_counts = protein_coding_tss.groupby("peak_name")["Gene stable ID"].nunique()

shared_tss = tss_gene_counts[tss_gene_counts > 1]

# Get the rows corresponding to shared TSSs
shared_tss_df = protein_coding_tss[protein_coding_tss["peak_name"].isin(shared_tss.index)]
print("Number of TSSs shared by more than one gene:", shared_tss_df["peak_name"].nunique())
# Out:
# Number of TSSs shared by more than one gene: 1358

# %% [markdown]
# ## Is first exon of protein coding genes completely unannotated?

# %%
protein_coding_unannotated_tss = combined_df[(combined_df["gene_category"] == "protein_coding") & 
        (combined_df["distance_to_closest_TSS"] > 100)]


lncrna_unannotated_tss = combined_df[(combined_df["gene_category"] == "lncRNA") & 
        (combined_df["distance_to_closest_TSS"] > 100)]

# %%
protein_coding_unannotated_tss["peak_name"].nunique()
# Out:
# 10589

# %%
lncrna_unannotated_tss["peak_name"].nunique()
# Out:
# 1206

# %%
# Load gtf of all tx
gtf_column_names = ['Chromosome','source','feature','Start','End','score','Strand','frame','attribute']
gtf_df = pd.read_csv( 'jessies_HIT.gtf',sep='\t', header=None, names=gtf_column_names)
gtf_df.loc[:, 'transcript_id'] = gtf_df['attribute'].apply(split_attributes, args=("transcript_id",))
gtf_df.head()
# Out:
#   Chromosome  source feature      Start        End score Strand frame  \
# 0       chr1  custom    exon   61077274   61077628     .      +     .
# 1       chr1  custom    exon   61077916   61079203     .      +     .
# 2       chr1  custom    exon  160261734  160261922     .      +     .
# 3       chr1  custom    exon  160281430  160281892     .      +     .
# 4       chr1  custom    exon  239386568  239387227     .      +     .
#
#                                            attribute      transcript_id
# 0  gene_id "ENSG00000162599"; transcript_id "ENCT...  ENCT00000006334.1
# 1  gene_id "ENSG00000162599"; transcript_id "ENCT...  ENCT00000006334.1
# 2  gene_id "ENSG00000228606"; transcript_id "ENCT...  ENCT00000013056.1
# 3  gene_id "ENSG00000228606"; transcript_id "ENCT...  ENCT00000013056.1
# 4  gene_id "ENSG00000133019"; transcript_id "ENCT...  ENCT00000019620.1

# %%
# Get exons for these tx
gtf_protein_coding_unannotated_tss = gtf_df[gtf_df['transcript_id'].isin(protein_coding_unannotated_tss['transcript_id'])]

gtf_lncrna_unannotated_tss = gtf_df[gtf_df['transcript_id'].isin(lncrna_unannotated_tss['transcript_id'])]

# %%
# Keep 1st exon
protein_coding_first_exons = (
    gtf_protein_coding_unannotated_tss.sort_values(
        by=['transcript_id', 'Start'], 
        ascending=[True, True]
    )
    .assign(sort_key=lambda d: d['Start'].where(d['Strand'] == '+', -d['End']))
    .sort_values(['transcript_id', 'sort_key'])
    .drop_duplicates('transcript_id', keep='first')
    .drop(columns='sort_key')
)
protein_coding_first_exons = protein_coding_first_exons.merge(
    protein_coding_unannotated_tss[['transcript_id', 'peak_name']],
    on='transcript_id',
    how='left'
)


lncrna_first_exons = (
    gtf_lncrna_unannotated_tss.sort_values(
        by=['transcript_id', 'Start'], 
        ascending=[True, True]
    )
    .assign(sort_key=lambda d: d['Start'].where(d['Strand'] == '+', -d['End']))
    .sort_values(['transcript_id', 'sort_key'])
    .drop_duplicates('transcript_id', keep='first')
    .drop(columns='sort_key')
)
lncrna_first_exons = lncrna_first_exons.merge(
    lncrna_unannotated_tss[['transcript_id', 'peak_name']],
    on='transcript_id',
    how='left'
)

# %%
protein_coding_first_exons["peak_name"].nunique()
# Out:
# 10589

# %%
lncrna_first_exons["peak_name"].nunique()
# Out:
# 1206

# %%
# Convert to pyranges
protein_coding_first_exons = pr.PyRanges(protein_coding_first_exons)
lncrna_first_exons = pr.PyRanges(lncrna_first_exons)

# %%
# Load gencode exons and convert to pyranges
gencode_exons = pd.read_csv("gencode.v47.tsv", sep="\t", dtype=str)
gencode_exons = pr.PyRanges(
    gencode_exons.rename(columns={
        "seqname": "Chromosome",
        "start": "Start",
        "end": "End",
        "strand": "Strand"
    })[["Chromosome", "Start", "End", "Strand", "transcript_id"]]
)
gencode_exons
# Out:
# +--------------+-----------+-----------+--------------+-------------------+
# | Chromosome   | Start     | End       | Strand       | transcript_id     |
# | (category)   | (int64)   | (int64)   | (category)   | (object)          |
# |--------------+-----------+-----------+--------------+-------------------|
# | chr1         | 11121     | 11211     | +            | ENST00000832824.1 |
# | chr1         | 12010     | 12227     | +            | ENST00000832824.1 |
# | chr1         | 12613     | 12721     | +            | ENST00000832824.1 |
# | chr1         | 13453     | 14413     | +            | ENST00000832824.1 |
# | ...          | ...       | ...       | ...          | ...               |
# | chrY         | 57213880  | 57213964  | -            | ENST00000711270.1 |
# | chrY         | 57213526  | 57213602  | -            | ENST00000711270.1 |
# | chrY         | 57213204  | 57213357  | -            | ENST00000711270.1 |
# | chrY         | 57212184  | 57213125  | -            | ENST00000711270.1 |
# +--------------+-----------+-----------+--------------+-------------------+
# Stranded PyRanges object has 2,155,005 rows and 5 columns from 25 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.

# %%
# Find overlaps
overlapping_protein_coding_first_exon = protein_coding_first_exons.overlap(gencode_exons)
overlapping_lncrna_first_exon = lncrna_first_exons.overlap(gencode_exons)

# %%
# Protein coding
protein_coding_first_exons = protein_coding_first_exons.df
overlapping_protein_coding_first_exon = overlapping_protein_coding_first_exon.df

non_overlapping_protein_coding_first_exons = protein_coding_first_exons[~protein_coding_first_exons['transcript_id'].isin(
                                                overlapping_protein_coding_first_exon['transcript_id'])]

#lncRNA
lncrna_first_exons = lncrna_first_exons.df
overlapping_lncrna_first_exon = overlapping_lncrna_first_exon.df

non_overlapping_lncrna_first_exons = lncrna_first_exons[~lncrna_first_exons['transcript_id'].isin(
                                                overlapping_lncrna_first_exon['transcript_id'])]

# %%
counts_protein_coding = [len(non_overlapping_protein_coding_first_exons), len(overlapping_protein_coding_first_exon)]
counts_lncrna = [len(non_overlapping_lncrna_first_exons), len(overlapping_lncrna_first_exon)]

labels = ["1st exon not overlapping\na GENCODE exon", "1st exon overlapping\na GENCODE exon"]

plt.figure(figsize=(2.5, 3.5))
bar_positions = [0, 1]
bar_labels = ["Protein coding", "lncRNA"]

plt.bar(bar_positions[0], counts_protein_coding[0], label=labels[0], color="mediumblue")
plt.bar(bar_positions[0], counts_protein_coding[1], bottom=counts_protein_coding[0], label=labels[1], color="deepskyblue")

plt.bar(bar_positions[1], counts_lncrna[0], color="mediumblue")
plt.bar(bar_positions[1], counts_lncrna[1], bottom=counts_lncrna[0], color="deepskyblue")

plt.text(bar_positions[0], counts_protein_coding[0] / 2, str(counts_protein_coding[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[0], counts_protein_coding[0] + counts_protein_coding[1] / 2, str(counts_protein_coding[1]), ha='center', va='center', fontsize=8, color='black')

plt.text(bar_positions[1], counts_lncrna[0] / 2, str(counts_lncrna[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[1], counts_lncrna[0] + counts_lncrna[1] / 2, str(counts_lncrna[1]), ha='center', va='center', fontsize=8, color='black')

plt.xticks(bar_positions, bar_labels, fontsize=10)
plt.ylabel("Transcripts with unannotated TSS")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.45), frameon=False)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot on TSS level instead of transcript level

# %%
# Protein-coding TSSs
set_non_overlapping_protein_coding_first_exons = set(non_overlapping_protein_coding_first_exons["peak_name"])
set_overlapping_protein_coding_first_exon = set(overlapping_protein_coding_first_exon["peak_name"]) - set_non_overlapping_protein_coding_first_exons

print(len(set_overlapping_protein_coding_first_exon) + len(set_non_overlapping_protein_coding_first_exons))

# lncRNA TSSs
set_non_overlapping_lncrna_first_exons = set(non_overlapping_lncrna_first_exons["peak_name"])
set_overlapping_lncrna_first_exon = set(overlapping_lncrna_first_exon["peak_name"]) - set_non_overlapping_lncrna_first_exons

print(len(set_overlapping_lncrna_first_exon) + len(set_non_overlapping_lncrna_first_exons))
# Out:
# 10589
# 1206

# %%
counts_protein_coding = [len(set_non_overlapping_protein_coding_first_exons), len(set_overlapping_protein_coding_first_exon)]
counts_lncrna = [len(set_non_overlapping_lncrna_first_exons), len(set_overlapping_lncrna_first_exon)]

labels = ["1st exon not overlapping\na GENCODE exon", "1st exon overlapping\na GENCODE exon"]

plt.figure(figsize=(2.5, 3.5))
bar_positions = [0, 1]
bar_labels = ["Protein coding", "lncRNA"]

plt.bar(bar_positions[0], counts_protein_coding[0], label=labels[0], color="mediumblue")
plt.bar(bar_positions[0], counts_protein_coding[1], bottom=counts_protein_coding[0], label=labels[1], color="deepskyblue")

plt.bar(bar_positions[1], counts_lncrna[0], color="mediumblue")
plt.bar(bar_positions[1], counts_lncrna[1], bottom=counts_lncrna[0], color="deepskyblue")

plt.text(bar_positions[0], counts_protein_coding[0] / 2, str(counts_protein_coding[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[0], counts_protein_coding[0] + counts_protein_coding[1] / 2, str(counts_protein_coding[1]), ha='center', va='center', fontsize=8, color='black')

plt.text(bar_positions[1], counts_lncrna[0] / 2, str(counts_lncrna[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[1], counts_lncrna[0] + counts_lncrna[1] / 2, str(counts_lncrna[1]), ha='center', va='center', fontsize=8, color='black')

plt.xticks(bar_positions, bar_labels, fontsize=10)
plt.ylabel("Unannotated TSSs")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.45), frameon=False)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(2.1, 3.7))

# Data for the protein-coding bar only
counts_protein_coding = [len(set_non_overlapping_protein_coding_first_exons),
                         len(set_overlapping_protein_coding_first_exon)]
labels = ["1st exon unannotated",
          "1st exon overlapping\na GENCODE exon"]

# Single bar at position 0
bar_pos = 0

# Stacked bar
plt.bar(bar_pos, counts_protein_coding[0], label=labels[0], color="mediumblue")
plt.bar(bar_pos, counts_protein_coding[1],
        bottom=counts_protein_coding[0], label=labels[1], color="deepskyblue")

# Add text labels inside the bar
plt.text(bar_pos, counts_protein_coding[0] / 2, str(counts_protein_coding[0]),
         ha='center', va='center', fontsize=11, color='white')
plt.text(bar_pos, counts_protein_coding[0] + counts_protein_coding[1] / 2,
         str(counts_protein_coding[1]), ha='center', va='center', fontsize=11, color='black')

# Axis settings
plt.xticks([bar_pos], ["Protein coding"], fontsize=11)
plt.ylabel("Unannotated TSSs", fontsize=12)
plt.legend(loc='upper center', bbox_to_anchor=(0.4, 1.3), frameon=False, fontsize=11)

# Clean up spines
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
1879/10589 *100
# Out:
# 17.744829540088773

# %%
# Keep one representative tx per TSS 
protein_coding_first_tx = protein_coding_unannotated_tss.sort_values("log2_tx_exp", ascending=False).drop_duplicates(subset=["peak_name"])
lncrna_first_tx = lncrna_unannotated_tss.sort_values("log2_tx_exp", ascending=False).drop_duplicates(subset=["peak_name"])

# %%
# Get exons for these tx
gtf_protein_coding_first_tx = gtf_df[gtf_df['transcript_id'].isin(protein_coding_first_tx['transcript_id'])]

gtf_lncrna_first_tx = gtf_df[gtf_df['transcript_id'].isin(lncrna_first_tx['transcript_id'])]

# %%
# Keep 1st exon
protein_coding_first_tx_exons = (
    gtf_protein_coding_first_tx.sort_values(
        by=['transcript_id', 'Start'], 
        ascending=[True, True]
    )
    .assign(sort_key=lambda d: d['Start'].where(d['Strand'] == '+', -d['End']))
    .sort_values(['transcript_id', 'sort_key'])
    .drop_duplicates('transcript_id', keep='first')
    .drop(columns='sort_key')
)


lncrna_first_tx_exons = (
    gtf_lncrna_first_tx.sort_values(
        by=['transcript_id', 'Start'], 
        ascending=[True, True]
    )
    .assign(sort_key=lambda d: d['Start'].where(d['Strand'] == '+', -d['End']))
    .sort_values(['transcript_id', 'sort_key'])
    .drop_duplicates('transcript_id', keep='first')
    .drop(columns='sort_key')
)

# %%
# Convert to pyranges
protein_coding_first_tx_exons = pr.PyRanges(protein_coding_first_tx_exons)
lncrna_first_tx_exons = pr.PyRanges(lncrna_first_tx_exons)

# %%
# Find overlaps
overlapping_protein_coding_first_tx_exon = protein_coding_first_tx_exons.overlap(gencode_exons)
overlapping_lncrna_first_tx_exon = lncrna_first_tx_exons.overlap(gencode_exons)

# %%
# Protein coding
protein_coding_first_tx_exons = protein_coding_first_tx_exons.df
overlapping_protein_coding_first_tx_exon = overlapping_protein_coding_first_tx_exon.df

non_overlapping_protein_coding_first_tx_exons = protein_coding_first_tx_exons[~protein_coding_first_tx_exons['transcript_id'].isin(
                                                overlapping_protein_coding_first_tx_exon['transcript_id'])]

#lncRNA
lncrna_first_tx_exons = lncrna_first_tx_exons.df
overlapping_lncrna_first_tx_exon = overlapping_lncrna_first_tx_exon.df

non_overlapping_lncrna_first_tx_exons = lncrna_first_tx_exons[~lncrna_first_tx_exons['transcript_id'].isin(
                                                overlapping_lncrna_first_tx_exon['transcript_id'])]

# %%
counts_protein_coding = [len(non_overlapping_protein_coding_first_tx_exons), len(overlapping_protein_coding_first_tx_exon)]
counts_lncrna = [len(non_overlapping_lncrna_first_tx_exons), len(overlapping_lncrna_first_tx_exon)]

labels = ["1st exon not overlapping\na GENCODE exon", "1st exon overlapping\na GENCODE exon"]

plt.figure(figsize=(2.5, 3.5))
bar_positions = [0, 1]
bar_labels = ["Protein coding", "lncRNA"]

plt.bar(bar_positions[0], counts_protein_coding[0], label=labels[0], color="mediumblue")
plt.bar(bar_positions[0], counts_protein_coding[1], bottom=counts_protein_coding[0], label=labels[1], color="deepskyblue")

plt.bar(bar_positions[1], counts_lncrna[0], color="mediumblue")
plt.bar(bar_positions[1], counts_lncrna[1], bottom=counts_lncrna[0], color="deepskyblue")

plt.text(bar_positions[0], counts_protein_coding[0] / 2, str(counts_protein_coding[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[0], counts_protein_coding[0] + counts_protein_coding[1] / 2, str(counts_protein_coding[1]), ha='center', va='center', fontsize=8, color='black')

plt.text(bar_positions[1], counts_lncrna[0] / 2, str(counts_lncrna[0]), ha='center', va='center', fontsize=8, color='white')
plt.text(bar_positions[1], counts_lncrna[0] + counts_lncrna[1] / 2, str(counts_lncrna[1]), ha='center', va='center', fontsize=8, color='black')

plt.xticks(bar_positions, bar_labels, fontsize=10)
plt.ylabel("Unannotated TSSs")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.45), frameon=False)
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Run ORFanage on these 6,750 protein coding tx that don't have 1st exon overlap w/ GENCODE

# %%
non_overlapping_protein_coding_first_exons
# Out:
#       Chromosome  source feature     Start       End score Strand frame  \
# 0           chr1  custom    exon    938827    938950     .      +     .
# 3           chr1  custom    exon  16013096  16013287     .      +     .
# 4           chr1  custom    exon  16914086  16914137     .      +     .
# 6           chr1  custom    exon  18107495  18107658     .      +     .
# 14          chr1  custom    exon  32539183  32539212     .      +     .
# ...          ...     ...     ...       ...       ...   ...    ...   ...
# 32330       chrX  custom    exon  53683718  53683823     .      -     .
# 32331       chrX  custom    exon  54183464  54183545     .      -     .
# 32334       chrX  custom    exon  20267800  20267879     .      -     .
# 32343       chrY  custom    exon   6909885   6910103     .      +     .
# 32353       chrY  custom    exon   6909910   6910103     .      +     .
#
#                                                attribute      transcript_id  \
# 0      gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 3      gene_id "ENSG00000186510"; transcript_id "ENCT...  ENCT00000002013.1
# 4      gene_id "ENSG00000058453"; transcript_id "ENCT...  ENCT00000002137.1
# 6      gene_id "ENSG00000117154"; transcript_id "ENCT...  ENCT00000002237.1
# 14     gene_id "ENSG00000160062"; transcript_id "ENCT...  ENCT00000003840.1
# ...                                                  ...                ...
# 32330  gene_id "ENSG00000086758"; transcript_id "STRT...       STRT02288584
# 32331  gene_id "ENSG00000184083"; transcript_id "STRT...       STRT02288825
# 32334  gene_id "ENSG00000177189"; transcript_id "STRT...       STRT02291517
# 32343  gene_id "ENSG00000092377"; transcript_id "STRT...       STRT02292300
# 32353  gene_id "ENSG00000092377"; transcript_id "STRT...       STRT02295179
#
#                                peak_name
# 0             chr1:938656-938830_Peak_62
# 3        chr1:16013071-16013096_Peak_805
# 4        chr1:16914050-16914229_Peak_884
# 6        chr1:18107481-18107503_Peak_935
# 14      chr1:32539150-32539195_Peak_1889
# ...                                  ...
# 32330  chrX:53683817-53683846_Peak_79094
# 32331  chrX:54183546-54183581_Peak_79113
# 32334  chrX:20267913-20267917_Peak_78466
# 32343    chrY:6909846-6909865_Peak_80713
# 32353    chrY:6909846-6909865_Peak_80713
#
# [6709 rows x 11 columns]

# %%
# get exons of entire transcript
tx_non_overlapping_protein_coding_first_exons = gtf_df[gtf_df["transcript_id"].isin(non_overlapping_protein_coding_first_exons["transcript_id"])]

# %%
tx_non_overlapping_protein_coding_first_exons
# Out:
#         Chromosome  source feature      Start        End score Strand frame  \
# 597129        chr1  custom    exon     938827     938950     .      +     .
# 597130        chr1  custom    exon     939040     939129     .      +     .
# 597131        chr1  custom    exon     939272     939412     .      +     .
# 597132        chr1  custom    exon     941144     941306     .      +     .
# 597133        chr1  custom    exon     942136     942251     .      +     .
# ...            ...     ...     ...        ...        ...   ...    ...   ...
# 3539660       chrX  custom    exon  107153955  107154246     .      -     .
# 3539661       chrX  custom    exon  107155760  107156202     .      -     .
# 3539666       chrX  custom    exon  104100239  104106299     .      -     .
# 3539667       chrX  custom    exon  104110502  104111473     .      -     .
# 3539668       chrX  custom    exon  104112316  104112347     .      -     .
#
#                                                  attribute      transcript_id
# 597129   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 597130   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 597131   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 597132   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 597133   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# ...                                                    ...                ...
# 3539660  gene_id "ENSG00000198088"; transcript_id "STRT...       STRT02287569
# 3539661  gene_id "ENSG00000198088"; transcript_id "STRT...       STRT02287569
# 3539666  gene_id "ENSG00000269743"; transcript_id "STRT...       STRT02288477
# 3539667  gene_id "ENSG00000269743"; transcript_id "STRT...       STRT02288477
# 3539668  gene_id "ENSG00000269743"; transcript_id "STRT...       STRT02288477
#
# [86152 rows x 10 columns]

# %%
# Add transcript features (needed for ORFanage)

# Group by transcript_id to get transcript boundaries
transcripts = (
    tx_non_overlapping_protein_coding_first_exons.groupby("transcript_id")
    .agg({
        "Chromosome": "first",
        "source": "first",
        "Start": "min",
        "End": "max",
        "Strand": "first",
        "attribute": "first"
    })
    .reset_index()
)

# Add the required columns for transcript entries
transcripts["feature"] = "transcript"
transcripts["score"] = "."
transcripts["frame"] = "."
transcripts = transcripts[[
    "Chromosome", "source", "feature", "Start", "End", "score", "Strand", "frame", "attribute", "transcript_id"
]]

# Append transcript rows to original DataFrame
tx_non_overlapping_protein_coding_first_exons = pd.concat([transcripts, tx_non_overlapping_protein_coding_first_exons], ignore_index=True)

# Sort by Chromosome, Start
tx_non_overlapping_protein_coding_first_exons = tx_non_overlapping_protein_coding_first_exons.sort_values(["Chromosome", "Start"]).reset_index(drop=True)

# %%
tx_non_overlapping_protein_coding_first_exons["transcript_id"].nunique()
# Out:
# 6709

# %%
tx_non_overlapping_protein_coding_first_exons
# Out:
#       Chromosome  source     feature    Start      End score Strand frame  \
# 0           chr1  custom  transcript   938694   944574     .      +     .
# 1           chr1  custom        exon   938694   938950     .      +     .
# 2           chr1  custom  transcript   938749   944799     .      +     .
# 3           chr1  custom        exon   938749   938950     .      +     .
# 4           chr1  custom  transcript   938827   944267     .      +     .
# ...          ...     ...         ...      ...      ...   ...    ...   ...
# 92856       chrY  custom        exon  6912088  6912172     .      +     .
# 92857       chrY  custom        exon  6912088  6912172     .      +     .
# 92858       chrY  custom        exon  6914579  6914808     .      +     .
# 92859       chrY  custom        exon  6914579  6924255     .      +     .
# 92860       chrY  custom        exon  6915592  6920747     .      +     .
#
#                                                attribute
# 0      gene_id "ENSG00000187634"; transcript_id "STRT...
# 1      gene_id "ENSG00000187634"; transcript_id "STRT...
# 2      gene_id "ENSG00000187634"; transcript_id "FTMT...
# 3      gene_id "ENSG00000187634"; transcript_id "FTMT...
# 4      gene_id "ENSG00000187634"; transcript_id "ENCT...
# ...                                                  ...
# 92856  gene_id "ENSG00000092377"; transcript_id "STRT...
# 92857  gene_id "ENSG00000092377"; transcript_id "STRT...
# 92858  gene_id "ENSG00000092377"; transcript_id "STRT...
# 92859  gene_id "ENSG00000092377"; transcript_id "STRT...
# 92860  gene_id "ENSG00000092377"; transcript_id "STRT...
#
# [92861 rows x 9 columns]

# %%
tx_non_overlapping_protein_coding_first_exons = tx_non_overlapping_protein_coding_first_exons.drop(columns=["transcript_id"])

# %%
# Save gtf
#tx_non_overlapping_protein_coding_first_exons.to_csv('/no_backup/jferrer/jmidgley/ORFanage/non-overlap_1st_exons_for_orfanage.gtf', sep='\t', header=False, index=False, quoting=csv.QUOTE_NONE)

# %% [markdown]
# orfanage --reference /no_backup/jferrer/mplanas/VASAseq/files/hg38.fa --query /no_backup/jferrer/jmidgley/ORFanage/non-overlap_1st_exons_for_orfanage.gtf --output non-overlap_1st_exons_ORFanage_output.gtf /no_backup/jferrer/jmidgley/gencode.v47.annotation.gtf

# %%
orfanage_output = pd.read_csv( '/no_backup/jferrer/jmidgley/ORFanage/non-overlap_1st_exons_ORFanage_output.gtf',
                           sep='\t', header=None, names=gtf_column_names)
orfanage_output.loc[:, 'transcript_id'] = orfanage_output['attribute'].apply(split_attributes, args=("transcript_id",))

orfanage_output
# Out:
#        Chromosome  source     feature    Start      End score Strand frame  \
# 0            chr1  custom  transcript   938694   944574     .      +     .
# 1            chr1  custom        exon   938694   938950     .      +     .
# 2            chr1  custom        exon   939040   939129     .      +     .
# 3            chr1  custom        exon   939275   939412     .      +     .
# 4            chr1  custom        exon   941144   941306     .      +     .
# ...           ...     ...         ...      ...      ...   ...    ...   ...
# 153246       chrY  custom        exon  6915592  6920747     .      +     .
# 153247       chrY  custom  transcript  6909910  6924255     .      +     .
# 153248       chrY  custom        exon  6909910  6910103     .      +     .
# 153249       chrY  custom        exon  6912088  6912172     .      +     .
# 153250       chrY  custom        exon  6914579  6924255     .      +     .
#
#                                                 attribute transcript_id
# 0       transcript_id "STRT00176417"; gene_id "ENSG000...  STRT00176417
# 1                           transcript_id "STRT00176417";  STRT00176417
# 2                           transcript_id "STRT00176417";  STRT00176417
# 3                           transcript_id "STRT00176417";  STRT00176417
# 4                           transcript_id "STRT00176417";  STRT00176417
# ...                                                   ...           ...
# 153246                      transcript_id "STRT02292300";  STRT02292300
# 153247  transcript_id "STRT02295179"; gene_id "ENSG000...  STRT02295179
# 153248                      transcript_id "STRT02295179";  STRT02295179
# 153249                      transcript_id "STRT02295179";  STRT02295179
# 153250                      transcript_id "STRT02295179";  STRT02295179
#
# [153251 rows x 10 columns]

# %%
orfanage_output["transcript_id"].nunique()
# Out:
# 6709

# %%
# Keep only ORFanage output for transcripts where a CDS could be predicted
cds_rows = orfanage_output[orfanage_output["feature"] == "CDS"]
transcripts_with_cds = cds_rows["transcript_id"].unique()


orfanage_output_with_CDS = orfanage_output[orfanage_output["transcript_id"].isin(transcripts_with_cds)]

print(orfanage_output_with_CDS["transcript_id"].nunique())
# Out:
# 5635

# %%
# Keep only CDS rows where frame is 0
orfanage_output_with_CDS = orfanage_output_with_CDS[
    (orfanage_output_with_CDS["feature"] != "CDS") | (orfanage_output_with_CDS["frame"] == "0")
]

# %%
# Build a set of unique exon keys from first exons
first_exons = set(
    tuple(x) for x in non_overlapping_protein_coding_first_exons[["Chromosome", "Start", "End", "transcript_id", "Strand"]].values
)

# Mark first exons
orfanage_output_with_CDS["is_first_exon"] = orfanage_output_with_CDS.apply(
    lambda row: (
        (row["Chromosome"], row["Start"], row["End"], row["transcript_id"], row["Strand"]) in first_exons
    ) if row["feature"] == "exon" else False,
    axis=1
)

# %%
orfanage_output_with_CDS
# Out:
#        Chromosome    source     feature      Start        End score Strand  \
# 0            chr1    custom  transcript     938694     944574     .      +
# 1            chr1    custom        exon     938694     938950     .      +
# 2            chr1    custom        exon     939040     939129     .      +
# 3            chr1    custom        exon     939275     939412     .      +
# 4            chr1    custom        exon     941144     941306     .      +
# ...           ...       ...         ...        ...        ...   ...    ...
# 153204       chrX    custom        exon  150814862  150814936     .      -
# 153205       chrX    custom        exon  150816007  150816078     .      -
# 153206       chrX    custom        exon  150831231  150831293     .      -
# 153207       chrX    custom        exon  150854811  150854906     .      -
# 153210       chrX  ORFanage         CDS  150776174  150776291     .      -
#
#        frame                                          attribute transcript_id  \
# 0          .  transcript_id "STRT00176417"; gene_id "ENSG000...  STRT00176417
# 1          .                      transcript_id "STRT00176417";  STRT00176417
# 2          .                      transcript_id "STRT00176417";  STRT00176417
# 3          .                      transcript_id "STRT00176417";  STRT00176417
# 4          .                      transcript_id "STRT00176417";  STRT00176417
# ...      ...                                                ...           ...
# 153204     .                      transcript_id "STRT02275241";  STRT02275241
# 153205     .                      transcript_id "STRT02275241";  STRT02275241
# 153206     .                      transcript_id "STRT02275241";  STRT02275241
# 153207     .                      transcript_id "STRT02275241";  STRT02275241
# 153210     0                      transcript_id "STRT02275241";  STRT02275241
#
#         is_first_exon
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 153204          False
# 153205          False
# 153206          False
# 153207           True
# 153210          False
#
# [115090 rows x 11 columns]

# %%
# Mark predicted CDS that match first exon with at least one end
exons = orfanage_output_with_CDS[(orfanage_output_with_CDS["feature"] == "exon") & (orfanage_output_with_CDS["is_first_exon"] == True)].copy()
exon_start_keys = set(zip(exons["Chromosome"],
                          exons["Start"],
                          exons["transcript_id"],
                          exons["Strand"]))
exon_end_keys   = set(zip(exons["Chromosome"],
                          exons["End"].astype(int),
                          exons["transcript_id"],
                          exons["Strand"]))

# Flag CDS rows whose start OR end matches an exon boundary
orfanage_output_with_CDS["CDS_matches_exon"] = orfanage_output_with_CDS.apply(
    lambda row: (
        (row["Chromosome"], row["Start"], row["transcript_id"], row["Strand"]) in exon_start_keys
        or
        (row["Chromosome"], row["End"],   row["transcript_id"], row["Strand"]) in exon_end_keys
    ) if row["feature"] == "CDS" else False,
    axis=1
)

# %%
orfanage_output_with_CDS
# Out:
#        Chromosome    source     feature      Start        End score Strand  \
# 0            chr1    custom  transcript     938694     944574     .      +
# 1            chr1    custom        exon     938694     938950     .      +
# 2            chr1    custom        exon     939040     939129     .      +
# 3            chr1    custom        exon     939275     939412     .      +
# 4            chr1    custom        exon     941144     941306     .      +
# ...           ...       ...         ...        ...        ...   ...    ...
# 153204       chrX    custom        exon  150814862  150814936     .      -
# 153205       chrX    custom        exon  150816007  150816078     .      -
# 153206       chrX    custom        exon  150831231  150831293     .      -
# 153207       chrX    custom        exon  150854811  150854906     .      -
# 153210       chrX  ORFanage         CDS  150776174  150776291     .      -
#
#        frame                                          attribute transcript_id  \
# 0          .  transcript_id "STRT00176417"; gene_id "ENSG000...  STRT00176417
# 1          .                      transcript_id "STRT00176417";  STRT00176417
# 2          .                      transcript_id "STRT00176417";  STRT00176417
# 3          .                      transcript_id "STRT00176417";  STRT00176417
# 4          .                      transcript_id "STRT00176417";  STRT00176417
# ...      ...                                                ...           ...
# 153204     .                      transcript_id "STRT02275241";  STRT02275241
# 153205     .                      transcript_id "STRT02275241";  STRT02275241
# 153206     .                      transcript_id "STRT02275241";  STRT02275241
# 153207     .                      transcript_id "STRT02275241";  STRT02275241
# 153210     0                      transcript_id "STRT02275241";  STRT02275241
#
#         is_first_exon  CDS_matches_exon
# 0               False             False
# 1                True             False
# 2               False             False
# 3               False             False
# 4               False             False
# ...               ...               ...
# 153204          False             False
# 153205          False             False
# 153206          False             False
# 153207           True             False
# 153210          False             False
#
# [115090 rows x 12 columns]

# %%
# Only keep transcripts where CDS matches the unannotated exon
valid_ids = orfanage_output_with_CDS[(orfanage_output_with_CDS["CDS_matches_exon"] == True)]["transcript_id"].unique()

orfanage_output_with_CDS = orfanage_output_with_CDS[
    orfanage_output_with_CDS["transcript_id"].isin(valid_ids)
]


print(orfanage_output_with_CDS["transcript_id"].nunique())
# Out:
# 546

# %%
orfanage_output_with_CDS[(orfanage_output_with_CDS["feature"] == "CDS") & (orfanage_output_with_CDS["CDS_matches_exon"] == True)]
# Out:
#        Chromosome    source feature      Start        End score Strand frame  \
# 207          chr1  ORFanage     CDS   15724187   15724301     .      +     0
# 3289         chr1  ORFanage     CDS   43559011   43559065     .      +     0
# 3349         chr1  ORFanage     CDS   43559011   43559065     .      +     0
# 3781         chr1  ORFanage     CDS   74734396   74734446     .      +     0
# 5435         chr1  ORFanage     CDS  147612717  147612754     .      +     0
# ...           ...       ...     ...        ...        ...   ...    ...   ...
# 153868       chrX  ORFanage     CDS  107118431  107118543     .      -     0
# 153883       chrX  ORFanage     CDS  107118431  107118543     .      -     0
# 153892       chrX  ORFanage     CDS  107118431  107118543     .      -     0
# 153907       chrX  ORFanage     CDS  107156027  107156217     .      -     0
# 153930       chrX  ORFanage     CDS  107156112  107156217     .      -     0
#
#                             attribute transcript_id  is_first_exon  \
# 207      transcript_id "PBT00032272";   PBT00032272          False
# 3289     transcript_id "PBT00033330";   PBT00033330          False
# 3349     transcript_id "PBT00033331";   PBT00033331          False
# 3781    transcript_id "STRT00085127";  STRT00085127          False
# 5435    transcript_id "STRT00128650";  STRT00128650          False
# ...                               ...           ...            ...
# 153868  transcript_id "STRT02256479";  STRT02256479          False
# 153883   transcript_id "PBT00440623";   PBT00440623          False
# 153892  transcript_id "STRT02285019";  STRT02285019          False
# 153907  transcript_id "STRT02263808";  STRT02263808          False
# 153930  transcript_id "STRT02273515";  STRT02273515          False
#
#         CDS_matches_exon
# 207                 True
# 3289                True
# 3349                True
# 3781                True
# 5435                True
# ...                  ...
# 153868              True
# 153883              True
# 153892              True
# 153907              True
# 153930              True
#
# [546 rows x 12 columns]

# %%
import pickle

with open("orfanage_output_with_CDS_first_exons.pkl", "wb") as f:
    pickle.dump(orfanage_output_with_CDS, f)

# %%
combined_df[combined_df["transcript_id"].isin(orfanage_output_with_CDS["transcript_id"].unique())]
# Out:
#             transcript_id   chr  \
# 64891   ENCT00000023649.1  chr1
# 65505         PBT00032272  chr1
# 65601         PBT00033330  chr1
# 65602         PBT00033331  chr1
# 65675         PBT00035051  chr1
# ...                   ...   ...
# 332059       STRT01545078  chr3
# 333104        PBT00348094  chr5
# 333523       STRT01772333  chr5
# 334788       STRT01918789  chr7
# 335456       STRT02084399  chr8
#
#                                                     exons matched_to  \
# 64891   [(30732445, 30733917), (30735173, 30735265), (...        NaN
# 65505   [(15724178, 15724301), (15725317, 15725545), (...        NaN
# 65601   [(43558982, 43559065), (43569590, 43569778), (...        NaN
# 65602   [(43558983, 43559065), (43569590, 43569778), (...        NaN
# 65675   [(147612708, 147612754), (147612883, 147613199...        NaN
# ...                                                   ...        ...
# 332059   [(172440565, 172445465), (172448742, 172448873)]        NaN
# 333104   [(168316254, 168316427), (168371424, 168373718)]        NaN
# 333523       [(33751337, 33751548), (33783728, 33783869)]        NaN
# 334788       [(30905231, 30905487), (30921681, 30921900)]        NaN
# 335456               [(617709, 627238), (628980, 629169)]        NaN
#
#                                            matched_ref_id  \
# 64891          ['ENST00000464569.1', 'ENST00000294507.4']
# 65505   ['ENST00000718276.1', 'ENST00000718275.1', 'EN...
# 65601   ['ENST00000477970.1', 'ENST00000437607.1', 'EN...
# 65602   ['ENST00000477970.1', 'ENST00000437607.1', 'EN...
# 65675   ['ENST00000684121.1', 'ENST00000683836.1', 'EN...
# ...                                                   ...
# 332059                                                NaN
# 333104                                                NaN
# 333523                                                NaN
# 334788                                                NaN
# 335456                                                NaN
#
#                                                  category  \
# 64891   Transcripts with annotated exons and non-overl...
# 65505   Transcripts with annotated exons and non-overl...
# 65601   Transcripts with annotated exons and non-overl...
# 65602   Transcripts with annotated exons and non-overl...
# 65675   Transcripts with annotated exons and non-overl...
# ...                                                   ...
# 332059  Fully unannotated transcripts with overlapping...
# 333104  Fully unannotated transcripts with overlapping...
# 333523  Fully unannotated transcripts with overlapping...
# 334788  Fully unannotated transcripts with overlapping...
# 335456  Fully unannotated transcripts with overlapping...
#
#                                    unannotated_exons  best_match_ref_id  \
# 64891   [(30742471, 30742549), (30756396, 30756618)]  ENST00000294507.4
# 65505                         [(15724178, 15724301)]  ENST00000718276.1
# 65601                         [(43558982, 43559065)]  ENST00000438120.5
# 65602                         [(43558983, 43559065)]  ENST00000438120.5
# 65675                       [(147612708, 147612754)]  ENST00000234739.8
# ...                                              ...                ...
# 332059                                           NaN                NaN
# 333104                                           NaN                NaN
# 333523                                           NaN                NaN
# 334788                                           NaN                NaN
# 335456                                           NaN                NaN
#
#        largest_overlap_gencode_id Strand  \
# 64891                         NaN      -
# 65505                         NaN      +
# 65601                         NaN      +
# 65602                         NaN      +
# 65675                         NaN      +
# ...                           ...    ...
# 332059          ENST00000241256.3      -
# 333104          ENST00000265293.9      +
# 333523          ENST00000515401.1      -
# 334788          ENST00000409611.1      +
# 335456          ENST00000523415.5      -
#
#                                       summarized_category             ref_id  \
# 64891   Unannotated transcripts with annotated and una...  ENST00000294507.4
# 65505   Unannotated transcripts with annotated and una...  ENST00000718276.1
# 65601   Unannotated transcripts with annotated and una...  ENST00000438120.5
# 65602   Unannotated transcripts with annotated and una...  ENST00000438120.5
# 65675   Unannotated transcripts with annotated and una...  ENST00000234739.8
# ...                                                   ...                ...
# 332059  Unannotated transcripts without any annotated ...  ENST00000241256.3
# 333104  Unannotated transcripts without any annotated ...  ENST00000265293.9
# 333523  Unannotated transcripts without any annotated ...  ENST00000515401.1
# 334788  Unannotated transcripts without any annotated ...  ENST00000409611.1
# 335456  Unannotated transcripts without any annotated ...  ENST00000523415.5
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 64891   ENST00000294507  ENSG00000162511    LAPTM5  protein_coding
# 65505   ENST00000718276  ENSG00000116786   PLEKHM2  protein_coding
# 65601   ENST00000438120  ENSG00000142949     PTPRF  protein_coding
# 65602   ENST00000438120  ENSG00000142949     PTPRF  protein_coding
# 65675   ENST00000234739  ENSG00000116128      BCL9  protein_coding
# ...                 ...              ...       ...             ...
# 332059  ENST00000241256  ENSG00000121853      GHSR  protein_coding
# 333104  ENST00000265293  ENSG00000113645      WWC1  protein_coding
# 333523  ENST00000515401  ENSG00000151388  ADAMTS12  protein_coding
# 334788  ENST00000409611  ENSG00000240583      AQP1  protein_coding
# 335456  ENST00000523415  ENSG00000104714    ERICH1  protein_coding
#
#          gene_category       og_gene_id                            peak_name  \
# 64891   protein_coding  ENSG00000162511     chr1:30756617-30756618_Peak_1722
# 65505   protein_coding  ENSG00000116786      chr1:15724169-15724229_Peak_770
# 65601   protein_coding  ENSG00000142949     chr1:43558981-43558984_Peak_2479
# 65602   protein_coding  ENSG00000142949     chr1:43558981-43558984_Peak_2479
# 65675   protein_coding  ENSG00000116128   chr1:147612677-147612712_Peak_4593
# ...                ...              ...                                  ...
# 332059  protein_coding  ENSG00000121853  chr3:172448835-172448891_Peak_55276
# 333104  protein_coding  ENSG00000113645  chr5:168316252-168316387_Peak_62517
# 333523  protein_coding  ENSG00000151388    chr5:33783822-33783897_Peak_59531
# 334788  protein_coding  ENSG00000240583    chr7:30905237-30905267_Peak_68269
# 335456  protein_coding  ENSG00000104714        chr8:629180-629184_Peak_71816
#
#          peak_type  mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 64891   Permissive      0.111917    -3.159495      9.193881         0.012173
# 65505   Permissive      0.083096    -3.589084     34.534098         0.002406
# 65601   Permissive      0.167916    -2.574187     54.475083         0.003082
# 65602   Permissive      0.028632    -5.126213     54.475083         0.000526
# 65675   Permissive      1.395049     0.480316      8.337521         0.167322
# ...            ...           ...          ...           ...              ...
# 332059  Permissive      0.325544    -1.619076      1.743603         0.186708
# 333104      Robust      0.157204    -2.669289     25.883358         0.006074
# 333523  Permissive      0.021237    -5.557278      4.714895         0.004504
# 334788  Permissive      0.214348    -2.221972     16.421385         0.013053
# 335456  Permissive      0.058134    -4.104479      5.088809         0.011424
#
#         TSS_TPM_per_gene  Relative TSS usage       TSS_type  TSS_start  \
# 64891           0.111917            0.012173      minor TSS   30756617
# 65505           0.596578            0.017275      minor TSS   15724169
# 65601           0.196549            0.003608      minor TSS   43558981
# 65602           0.196549            0.003608      minor TSS   43558981
# 65675           1.791491            0.214871  secondary TSS  147612677
# ...                  ...                 ...            ...        ...
# 332059          1.029101            0.590215       main TSS  172448835
# 333104          1.035840            0.040020      minor TSS  168316252
# 333523          1.049784            0.222653  secondary TSS   33783822
# 334788          0.319049            0.019429      minor TSS   30905237
# 335456          0.631110            0.124019      minor TSS     629180
#
#           TSS_end  distance_to_closest_TSS     closest_ref_id  \
# 64891    30756618                     1139  ENST00000476492.1
# 65505    15724229                     3822  ENST00000718276.1
# 65601    43558984                    13905  ENST00000437607.1
# 65602    43558984                    13905  ENST00000437607.1
# 65675   147612712                     1087  ENST00000675347.1
# ...           ...                      ...                ...
# 332059  172448891                      379  ENST00000241256.3
# 333104  168316387                      233  ENST00000519859.1
# 333523   33783897                    56415  ENST00000504582.5
# 334788   30905267                     6586  ENST00000652696.1
# 335456     629184                    11448  ENST00000519909.1
#
#        TSS distance category  TSS_name  TSS_rank Ranked_TSS_type
# 64891                 >100bp   P1722_U       2.0   secondary TSS
# 65505                 >100bp    P770_U       4.0       minor TSS
# 65601                 >100bp   P2479_U      18.0       minor TSS
# 65602                 >100bp   P2479_U      18.0       minor TSS
# 65675                 >100bp   P4593_U       3.0       minor TSS
# ...                      ...       ...       ...             ...
# 332059                >100bp  P55276_U       1.0        main TSS
# 333104                >100bp  P62517_U       5.0       minor TSS
# 333523                >100bp  P59531_U       2.0   secondary TSS
# 334788                >100bp  P68269_U       2.0   secondary TSS
# 335456                >100bp  P71816_U       2.0   secondary TSS
#
# [546 rows x 35 columns]

# %%
# How many genes?
combined_df[combined_df["transcript_id"].isin(orfanage_output_with_CDS["transcript_id"].unique())]["Gene stable ID"].nunique()
# Out:
# 247

# %%
# Which genes?
genes_with_first_exon_CDS = set(combined_df[combined_df["transcript_id"].isin(orfanage_output_with_CDS["transcript_id"].unique())]["Gene name"].unique())
genes_with_first_exon_CDS
# Out:
# {'ABI1',
#  'ABLIM1',
#  'ABLIM3',
#  'ABR',
#  'ACLY',
#  'ACMSD',
#  'ADAM9',
#  'ADAMTS12',
#  'ADCY5',
#  'AGPAT5',
#  'AGPS',
#  'AHRR',
#  'ALOX5AP',
#  'ANK2',
#  'ANKRD44',
#  'ANO5',
#  'AQP1',
#  'ASPH',
#  'ASXL3',
#  'ATG2B',
#  'ATP9A',
#  'ATXN10',
#  'BACE1',
#  'BACH1',
#  'BAIAP2',
#  'BCAT2',
#  'BCL9',
#  'BRAP',
#  'C8orf76',
#  'CACNA1D',
#  'CACNA2D1',
#  'CACNA2D2',
#  'CACNB2',
#  'CAPZB',
#  'CARNMT1',
#  'CATSPERE',
#  'CCDC61',
#  'CCND1',
#  'CCT8',
#  'CD109',
#  'CD5',
#  'CDK19',
#  'CERKL',
#  'CHCHD6',
#  'CLIC1',
#  'CLMN',
#  'CLPSL1',
#  'CMTM8',
#  'COL28A1',
#  'CRADD',
#  'DCDC1',
#  'DHRS7B',
#  'DIP2C',
#  'DOCK4',
#  'DPYD',
#  'DSCAML1',
#  'DYNC2I1',
#  'EFNA1',
#  'EHF',
#  'EIF2S1',
#  'EIF3H',
#  'ELAPOR2',
#  'EML5',
#  'ENPP2',
#  'ENSG00000249319',
#  'ENTHD1',
#  'EPHA2',
#  'ERCC1',
#  'ERICH1',
#  'ERP27',
#  'EXOC6B',
#  'FEV',
#  'FGF12',
#  'FGF9',
#  'FMN1',
#  'FMO1',
#  'FNTB',
#  'FOXP2',
#  'FSTL4',
#  'GAB2',
#  'GGA2',
#  'GHSR',
#  'GLI3',
#  'GMDS',
#  'GPR37L1',
#  'GRAMD1B',
#  'GRAMD4',
#  'GRIP1',
#  'GRM8',
#  'GSE1',
#  'H2AZ2',
#  'HIP1',
#  'HMGCLL1',
#  'HOOK2',
#  'IGF1R',
#  'IGFBP5',
#  'INSC',
#  'KCND2',
#  'KCNMA1',
#  'KCTD3',
#  'KHDRBS3',
#  'KIAA1614',
#  'KLF13',
#  'LANCL2',
#  'LAPTM5',
#  'LMO1',
#  'LRP5',
#  'MACROD2',
#  'MAPRE1',
#  'MARCHF2',
#  'MARCHF8',
#  'MBOAT2',
#  'ME3',
#  'MEF2A',
#  'MGAM2',
#  'MLIP',
#  'MRC1',
#  'MTMR7',
#  'MXD4',
#  'MYBPHL',
#  'MYO16',
#  'MYO7A',
#  'NAV2',
#  'NAXD',
#  'NCAM1',
#  'NCKAP5',
#  'NDC1',
#  'NDRG4',
#  'NEBL',
#  'NEK8',
#  'NEURL1',
#  'NLGN1',
#  'NPAS2',
#  'NR5A2',
#  'NRXN2',
#  'NUP35',
#  'NUP62CL',
#  'OTOGL',
#  'PARD3B',
#  'PARVA',
#  'PCNT',
#  'PCSK1',
#  'PDE3A',
#  'PDE4D',
#  'PDE4DIP',
#  'PDE8B',
#  'PDGFA',
#  'PDX1',
#  'PEMT',
#  'PHAF1',
#  'PIAS4',
#  'PIEZO1',
#  'PIK3R3',
#  'PLB1',
#  'PLCL2',
#  'PLEKHA6',
#  'PLEKHA7',
#  'PLEKHM2',
#  'PPM1E',
#  'PPP2R3A',
#  'PTBP1',
#  'PTH2R',
#  'PTMA',
#  'PTPRF',
#  'PTPRN2',
#  'PTPRT',
#  'QPCT',
#  'RAB3GAP1',
#  'RABL3',
#  'RAP1GAP2',
#  'RBFOX2',
#  'RBM41',
#  'RBPMS',
#  'RBX1',
#  'REG4',
#  'RFX6',
#  'RGPD5',
#  'RND2',
#  'ROBO1',
#  'SAMD15',
#  'SCG5',
#  'SDK1',
#  'SGCZ',
#  'SHC2',
#  'SHTN1',
#  'SLC12A7',
#  'SLC2A13',
#  'SLC37A1',
#  'SLC44A5',
#  'SLC4A8',
#  'SLC7A5',
#  'SLTM',
#  'SMURF1',
#  'SNTG2',
#  'SNX29',
#  'SNX3',
#  'SNX9',
#  'SORL1',
#  'SP1',
#  'SPTBN4',
#  'SRCIN1',
#  'SRF',
#  'SSBP4',
#  'ST3GAL6',
#  'STARD13',
#  'STN1',
#  'STX1A',
#  'SUGCT',
#  'SURF4',
#  'SYNJ2',
#  'SYT16',
#  'SYT17',
#  'SYT7',
#  'TACC2',
#  'TARS1',
#  'TBC1D22A',
#  'TBCD',
#  'TEF',
#  'TENM3',
#  'TENT5B',
#  'TMEM164',
#  'TNS2',
#  'TNS3',
#  'TP63',
#  'TPD52',
#  'TRPM5',
#  'TYW3',
#  'UNC5B',
#  'VAV2',
#  'VNN1',
#  'VOPP1',
#  'VPS13B',
#  'WAPL',
#  'WDR25',
#  'WNK2',
#  'WNT5A',
#  'WWC1',
#  'XRCC1',
#  'ZBTB47',
#  'ZC3H12C',
#  'ZC3H3',
#  'ZNF365',
#  'ZNF395',
#  'ZNF638',
#  'ZPLD1',
#  'ZZEF1'}

# %%
combined_df[(combined_df["transcript_id"].isin(orfanage_output_with_CDS["transcript_id"].unique()) & (combined_df["Gene name"] == "PTPRF"))]
# Out:
#       transcript_id   chr                                              exons  \
# 65601   PBT00033330  chr1  [(43558982, 43559065), (43569590, 43569778), (...
# 65602   PBT00033331  chr1  [(43558983, 43559065), (43569590, 43569778), (...
#
#       matched_to                                     matched_ref_id  \
# 65601        NaN  ['ENST00000477970.1', 'ENST00000437607.1', 'EN...
# 65602        NaN  ['ENST00000477970.1', 'ENST00000437607.1', 'EN...
#
#                                                 category  \
# 65601  Transcripts with annotated exons and non-overl...
# 65602  Transcripts with annotated exons and non-overl...
#
#             unannotated_exons  best_match_ref_id largest_overlap_gencode_id  \
# 65601  [(43558982, 43559065)]  ENST00000438120.5                        NaN
# 65602  [(43558983, 43559065)]  ENST00000438120.5                        NaN
#
#       Strand                                summarized_category  \
# 65601      +  Unannotated transcripts with annotated and una...
# 65602      +  Unannotated transcripts with annotated and una...
#
#                   ref_id  stripped_ref_id   Gene stable ID Gene name  \
# 65601  ENST00000438120.5  ENST00000438120  ENSG00000142949     PTPRF
# 65602  ENST00000438120.5  ENST00000438120  ENSG00000142949     PTPRF
#
#             Gene type   gene_category       og_gene_id  \
# 65601  protein_coding  protein_coding  ENSG00000142949
# 65602  protein_coding  protein_coding  ENSG00000142949
#
#                               peak_name   peak_type  mean_TPM_ref  \
# 65601  chr1:43558981-43558984_Peak_2479  Permissive      0.167916
# 65602  chr1:43558981-43558984_Peak_2479  Permissive      0.028632
#
#        log2_tx_exp  gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  \
# 65601    -2.574187     54.475083         0.003082          0.196549
# 65602    -5.126213     54.475083         0.000526          0.196549
#
#        Relative TSS usage   TSS_type  TSS_start   TSS_end  \
# 65601            0.003608  minor TSS   43558981  43558984
# 65602            0.003608  minor TSS   43558981  43558984
#
#        distance_to_closest_TSS     closest_ref_id TSS distance category  \
# 65601                    13905  ENST00000437607.1                >100bp
# 65602                    13905  ENST00000437607.1                >100bp
#
#       TSS_name  TSS_rank Ranked_TSS_type
# 65601  P2479_U      18.0       minor TSS
# 65602  P2479_U      18.0       minor TSS

# %% [markdown]
# #### Plot the exon tracks

# %%
gencode_exons = gencode_exons.df

# %%
from matplotlib.patches import Patch


transcript_id = "PBT00032272"


frame_colors = {
    "0": "green",
    "1": "lightseagreen",
    "2": "yellowgreen"
}

exon_colors = {
    "First exon": "crimson",
    "Other exon": "steelblue"
}


exons = orfanage_output_with_CDS[(orfanage_output_with_CDS["feature"] == "exon") & (orfanage_output_with_CDS["transcript_id"] == transcript_id)]
cds = orfanage_output[(orfanage_output["feature"] == "CDS") & (orfanage_output["transcript_id"] == transcript_id) ]


# Get ref transcript
ref_id = combined_df[combined_df["transcript_id"] == transcript_id]["ref_id"].iloc[0]
ref_transcript = gencode_exons[gencode_exons['transcript_id'] == ref_id]
ref_transcript = ref_transcript[["Start", "End", "transcript_id"]]
ref_transcript["Start"] = ref_transcript["Start"].astype(int)
ref_transcript["End"] = ref_transcript["End"].astype(int)


fig, ax = plt.subplots(figsize=(11, 3))



# Plot ref
for _, row in ref_transcript.iterrows():
    ax.add_patch(
        plt.Rectangle(
            (row["Start"], 0.8), row["End"] - row["Start"], 0.3,
            edgecolor="grey",
            facecolor="grey"
        )
    )


# Plot exons
for _, row in exons.iterrows():
    if row["is_first_exon"]:
        color = "crimson"
    else:
        color = "steelblue"

    ax.add_patch(
        plt.Rectangle(
            (row["Start"], 0.4), row["End"] - row["Start"], 0.3,
            edgecolor=color,
            facecolor=color
        )
    )


# Plot ORFanage CDS 
for _, row in cds.iterrows():
    color = frame_colors.get(row["frame"])
    ax.add_patch(
        plt.Rectangle(
            (row["Start"], 0.0), row["End"] - row["Start"], 0.3,
            edgecolor=color,
            facecolor=color
        )
    )


cds_legend_elements = [
    Patch(facecolor=color, edgecolor=color, label=f'Frame {frame}')
    for frame, color in frame_colors.items()
]



exon_legend_elements = [
    Patch(facecolor=color, edgecolor=color, label=label)
    for label, color in exon_colors.items()
]
exon_legend = ax.legend(handles=exon_legend_elements, loc='lower left', bbox_to_anchor=(1, 0.5), title='Exon Status')
cds_legend = ax.legend(handles=cds_legend_elements, loc='upper left', bbox_to_anchor=(1, 0.5), title='ORFanage CDS')
ax.add_artist(exon_legend) 

ax.set_xlim(exons["Start"].min() - 3000, exons["End"].max() + 3000)
# ax.set_xlim(82335000, 82336000)
ax.set_ylim(-0.2, 1.2)
ax.set_yticks([0.15, 0.55, 0.95])
ax.set_yticklabels(["ORFanage CDS", f"HIT transcript: {transcript_id}", f"Reference transcript: {ref_id}"])
ax.set_xlabel("Genomic Position")
plt.title(f"{combined_df.loc[combined_df['transcript_id'] == transcript_id, 'Gene name'].iloc[0]} ({combined_df.loc[combined_df['transcript_id'] == transcript_id, 'Strand'].iloc[0]})")

plt.tight_layout()
plt.show()

# %%
orfanage_output_with_CDS[orfanage_output_with_CDS["transcript_id"] == "PBT00032272"]
# Out:
#     Chromosome    source     feature     Start       End score Strand frame  \
# 192       chr1    custom  transcript  15724178  15734767     .      +     .
# 193       chr1    custom        exon  15724178  15724301     .      +     .
# 194       chr1    custom        exon  15725317  15725545     .      +     .
# 195       chr1    custom        exon  15727014  15727832     .      +     .
# 196       chr1    custom        exon  15728079  15728148     .      +     .
# 197       chr1    custom        exon  15728267  15728357     .      +     .
# 198       chr1    custom        exon  15728669  15728733     .      +     .
# 199       chr1    custom        exon  15729102  15729190     .      +     .
# 200       chr1    custom        exon  15729797  15729929     .      +     .
# 201       chr1    custom        exon  15730532  15730722     .      +     .
# 202       chr1    custom        exon  15731192  15731257     .      +     .
# 203       chr1    custom        exon  15731889  15732048     .      +     .
# 204       chr1    custom        exon  15732350  15732529     .      +     .
# 205       chr1    custom        exon  15732612  15732728     .      +     .
# 206       chr1    custom        exon  15733797  15734767     .      +     .
# 207       chr1  ORFanage         CDS  15724187  15724301     .      +     0
# 211       chr1  ORFanage         CDS  15728267  15728357     .      +     0
# 213       chr1  ORFanage         CDS  15729102  15729190     .      +     0
# 215       chr1  ORFanage         CDS  15730532  15730722     .      +     0
# 218       chr1  ORFanage         CDS  15732350  15732529     .      +     0
# 219       chr1  ORFanage         CDS  15732612  15732728     .      +     0
# 220       chr1  ORFanage         CDS  15733797  15733934     .      +     0
#
#                                              attribute transcript_id  \
# 192  transcript_id "PBT00032272"; gene_id "ENSG0000...   PBT00032272
# 193                       transcript_id "PBT00032272";   PBT00032272
# 194                       transcript_id "PBT00032272";   PBT00032272
# 195                       transcript_id "PBT00032272";   PBT00032272
# 196                       transcript_id "PBT00032272";   PBT00032272
# 197                       transcript_id "PBT00032272";   PBT00032272
# 198                       transcript_id "PBT00032272";   PBT00032272
# 199                       transcript_id "PBT00032272";   PBT00032272
# 200                       transcript_id "PBT00032272";   PBT00032272
# 201                       transcript_id "PBT00032272";   PBT00032272
# 202                       transcript_id "PBT00032272";   PBT00032272
# 203                       transcript_id "PBT00032272";   PBT00032272
# 204                       transcript_id "PBT00032272";   PBT00032272
# 205                       transcript_id "PBT00032272";   PBT00032272
# 206                       transcript_id "PBT00032272";   PBT00032272
# 207                       transcript_id "PBT00032272";   PBT00032272
# 211                       transcript_id "PBT00032272";   PBT00032272
# 213                       transcript_id "PBT00032272";   PBT00032272
# 215                       transcript_id "PBT00032272";   PBT00032272
# 218                       transcript_id "PBT00032272";   PBT00032272
# 219                       transcript_id "PBT00032272";   PBT00032272
# 220                       transcript_id "PBT00032272";   PBT00032272
#
#      is_first_exon  CDS_matches_exon
# 192          False             False
# 193           True             False
# 194          False             False
# 195          False             False
# 196          False             False
# 197          False             False
# 198          False             False
# 199          False             False
# 200          False             False
# 201          False             False
# 202          False             False
# 203          False             False
# 204          False             False
# 205          False             False
# 206          False             False
# 207          False              True
# 211          False             False
# 213          False             False
# 215          False             False
# 218          False             False
# 219          False             False
# 220          False             False

# %%
cacna2d1_gtf = orfanage_output_with_CDS[orfanage_output_with_CDS["transcript_id"] == "PBT00392775"]
cacna2d1_gtf
# Out:
#       Chromosome    source     feature     Start       End score Strand frame  \
# 69130       chr7    custom  transcript  81946445  82335955     .      -     .
# 69131       chr7    custom        exon  81946445  81950508     .      -     .
# 69132       chr7    custom        exon  81959275  81959357     .      -     .
# 69133       chr7    custom        exon  81959720  81959829     .      -     .
# 69134       chr7    custom        exon  81961894  81962023     .      -     .
# 69135       chr7    custom        exon  81962440  81962495     .      -     .
# 69136       chr7    custom        exon  81964056  81964108     .      -     .
# 69137       chr7    custom        exon  81964207  81964359     .      -     .
# 69138       chr7    custom        exon  81965594  81965665     .      -     .
# 69139       chr7    custom        exon  81967169  81967207     .      -     .
# 69140       chr7    custom        exon  81967596  81967663     .      -     .
# 69141       chr7    custom        exon  81968887  81968973     .      -     .
# 69142       chr7    custom        exon  81969881  81969984     .      -     .
# 69143       chr7    custom        exon  81970675  81970737     .      -     .
# 69144       chr7    custom        exon  81971777  81971864     .      -     .
# 69145       chr7    custom        exon  81974455  81974552     .      -     .
# 69146       chr7    custom        exon  81982567  81982627     .      -     .
# 69147       chr7    custom        exon  81984635  81984711     .      -     .
# 69148       chr7    custom        exon  81991185  81991246     .      -     .
# 69149       chr7    custom        exon  81994868  81994939     .      -     .
# 69150       chr7    custom        exon  81997179  81997250     .      -     .
# 69151       chr7    custom        exon  82005423  82005497     .      -     .
# 69152       chr7    custom        exon  82005765  82005839     .      -     .
# 69153       chr7    custom        exon  82007679  82007756     .      -     .
# 69154       chr7    custom        exon  82012154  82012243     .      -     .
# 69155       chr7    custom        exon  82013461  82013510     .      -     .
# 69156       chr7    custom        exon  82014401  82014479     .      -     .
# 69157       chr7    custom        exon  82032797  82032901     .      -     .
# 69158       chr7    custom        exon  82038077  82038235     .      -     .
# 69159       chr7    custom        exon  82060428  82060527     .      -     .
# 69160       chr7    custom        exon  82064304  82064354     .      -     .
# 69161       chr7    custom        exon  82066455  82066524     .      -     .
# 69162       chr7    custom        exon  82084769  82084900     .      -     .
# 69163       chr7    custom        exon  82117044  82117173     .      -     .
# 69164       chr7    custom        exon  82136635  82136676     .      -     .
# 69165       chr7    custom        exon  82170550  82170609     .      -     .
# 69166       chr7    custom        exon  82335135  82335251     .      -     .
# 69167       chr7    custom        exon  82335920  82335955     .      -     .
# 69168       chr7  ORFanage         CDS  81950392  81950508     .      -     0
# 69173       chr7  ORFanage         CDS  81964056  81964108     .      -     0
# 69174       chr7  ORFanage         CDS  81964207  81964359     .      -     0
# 69175       chr7  ORFanage         CDS  81965594  81965665     .      -     0
# 69176       chr7  ORFanage         CDS  81967169  81967207     .      -     0
# 69185       chr7  ORFanage         CDS  81991185  81991246     .      -     0
# 69186       chr7  ORFanage         CDS  81994868  81994939     .      -     0
# 69187       chr7  ORFanage         CDS  81997179  81997250     .      -     0
# 69188       chr7  ORFanage         CDS  82005423  82005497     .      -     0
# 69189       chr7  ORFanage         CDS  82005765  82005839     .      -     0
# 69190       chr7  ORFanage         CDS  82007679  82007756     .      -     0
# 69191       chr7  ORFanage         CDS  82012154  82012243     .      -     0
# 69193       chr7  ORFanage         CDS  82014401  82014479     .      -     0
# 69194       chr7  ORFanage         CDS  82032797  82032901     .      -     0
# 69195       chr7  ORFanage         CDS  82038077  82038235     .      -     0
# 69200       chr7  ORFanage         CDS  82117044  82117173     .      -     0
# 69201       chr7  ORFanage         CDS  82136635  82136676     .      -     0
# 69202       chr7  ORFanage         CDS  82170550  82170609     .      -     0
# 69203       chr7  ORFanage         CDS  82335135  82335251     .      -     0
# 69204       chr7  ORFanage         CDS  82335920  82335955     .      -     0
#
#                                                attribute transcript_id  \
# 69130  transcript_id "PBT00392775"; gene_id "ENSG0000...   PBT00392775
# 69131                       transcript_id "PBT00392775";   PBT00392775
# 69132                       transcript_id "PBT00392775";   PBT00392775
# 69133                       transcript_id "PBT00392775";   PBT00392775
# 69134                       transcript_id "PBT00392775";   PBT00392775
# 69135                       transcript_id "PBT00392775";   PBT00392775
# 69136                       transcript_id "PBT00392775";   PBT00392775
# 69137                       transcript_id "PBT00392775";   PBT00392775
# 69138                       transcript_id "PBT00392775";   PBT00392775
# 69139                       transcript_id "PBT00392775";   PBT00392775
# 69140                       transcript_id "PBT00392775";   PBT00392775
# 69141                       transcript_id "PBT00392775";   PBT00392775
# 69142                       transcript_id "PBT00392775";   PBT00392775
# 69143                       transcript_id "PBT00392775";   PBT00392775
# 69144                       transcript_id "PBT00392775";   PBT00392775
# 69145                       transcript_id "PBT00392775";   PBT00392775
# 69146                       transcript_id "PBT00392775";   PBT00392775
# 69147                       transcript_id "PBT00392775";   PBT00392775
# 69148                       transcript_id "PBT00392775";   PBT00392775
# 69149                       transcript_id "PBT00392775";   PBT00392775
# 69150                       transcript_id "PBT00392775";   PBT00392775
# 69151                       transcript_id "PBT00392775";   PBT00392775
# 69152                       transcript_id "PBT00392775";   PBT00392775
# 69153                       transcript_id "PBT00392775";   PBT00392775
# 69154                       transcript_id "PBT00392775";   PBT00392775
# 69155                       transcript_id "PBT00392775";   PBT00392775
# 69156                       transcript_id "PBT00392775";   PBT00392775
# 69157                       transcript_id "PBT00392775";   PBT00392775
# 69158                       transcript_id "PBT00392775";   PBT00392775
# 69159                       transcript_id "PBT00392775";   PBT00392775
# 69160                       transcript_id "PBT00392775";   PBT00392775
# 69161                       transcript_id "PBT00392775";   PBT00392775
# 69162                       transcript_id "PBT00392775";   PBT00392775
# 69163                       transcript_id "PBT00392775";   PBT00392775
# 69164                       transcript_id "PBT00392775";   PBT00392775
# 69165                       transcript_id "PBT00392775";   PBT00392775
# 69166                       transcript_id "PBT00392775";   PBT00392775
# 69167                       transcript_id "PBT00392775";   PBT00392775
# 69168                       transcript_id "PBT00392775";   PBT00392775
# 69173                       transcript_id "PBT00392775";   PBT00392775
# 69174                       transcript_id "PBT00392775";   PBT00392775
# 69175                       transcript_id "PBT00392775";   PBT00392775
# 69176                       transcript_id "PBT00392775";   PBT00392775
# 69185                       transcript_id "PBT00392775";   PBT00392775
# 69186                       transcript_id "PBT00392775";   PBT00392775
# 69187                       transcript_id "PBT00392775";   PBT00392775
# 69188                       transcript_id "PBT00392775";   PBT00392775
# 69189                       transcript_id "PBT00392775";   PBT00392775
# 69190                       transcript_id "PBT00392775";   PBT00392775
# 69191                       transcript_id "PBT00392775";   PBT00392775
# 69193                       transcript_id "PBT00392775";   PBT00392775
# 69194                       transcript_id "PBT00392775";   PBT00392775
# 69195                       transcript_id "PBT00392775";   PBT00392775
# 69200                       transcript_id "PBT00392775";   PBT00392775
# 69201                       transcript_id "PBT00392775";   PBT00392775
# 69202                       transcript_id "PBT00392775";   PBT00392775
# 69203                       transcript_id "PBT00392775";   PBT00392775
# 69204                       transcript_id "PBT00392775";   PBT00392775
#
#        is_first_exon  CDS_matches_exon
# 69130          False             False
# 69131          False             False
# 69132          False             False
# 69133          False             False
# 69134          False             False
# 69135          False             False
# 69136          False             False
# 69137          False             False
# 69138          False             False
# 69139          False             False
# 69140          False             False
# 69141          False             False
# 69142          False             False
# 69143          False             False
# 69144          False             False
# 69145          False             False
# 69146          False             False
# 69147          False             False
# 69148          False             False
# 69149          False             False
# 69150          False             False
# 69151          False             False
# 69152          False             False
# 69153          False             False
# 69154          False             False
# 69155          False             False
# 69156          False             False
# 69157          False             False
# 69158          False             False
# 69159          False             False
# 69160          False             False
# 69161          False             False
# 69162          False             False
# 69163          False             False
# 69164          False             False
# 69165          False             False
# 69166          False             False
# 69167           True             False
# 69168          False             False
# 69173          False             False
# 69174          False             False
# 69175          False             False
# 69176          False             False
# 69185          False             False
# 69186          False             False
# 69187          False             False
# 69188          False             False
# 69189          False             False
# 69190          False             False
# 69191          False             False
# 69193          False             False
# 69194          False             False
# 69195          False             False
# 69200          False             False
# 69201          False             False
# 69202          False             False
# 69203          False             False
# 69204          False              True

# %%
import pickle

with open("cacna2d1_gtf.pkl", "wb") as f:
    pickle.dump(cacna2d1_gtf, f)

# %% [markdown]
# ### Is non-overlapping exon in intron region of GENCODE transcripts or outside of transcripts?

# %%
# Add gene ID & name column 
non_overlapping_protein_coding_first_exons.loc[:, 'gene_id'] = non_overlapping_protein_coding_first_exons['attribute'].apply(split_attributes, args=("gene_id",))
non_overlapping_protein_coding_first_exons.loc[:, 'gene_name'] = non_overlapping_protein_coding_first_exons['attribute'].apply(split_attributes, args=("gene_name",))

non_overlapping_protein_coding_first_exons.head()
# Out:
# /tmp/18110612/ipykernel_1287073/724753300.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_overlapping_protein_coding_first_exons.loc[:, 'gene_id'] = non_overlapping_protein_coding_first_exons['attribute'].apply(split_attributes, args=("gene_id",))
# /tmp/18110612/ipykernel_1287073/724753300.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_overlapping_protein_coding_first_exons.loc[:, 'gene_name'] = non_overlapping_protein_coding_first_exons['attribute'].apply(split_attributes, args=("gene_name",))
#    Chromosome  source feature     Start       End score Strand frame  \
# 0        chr1  custom    exon    938827    938950     .      +     .
# 3        chr1  custom    exon  16013096  16013287     .      +     .
# 4        chr1  custom    exon  16914086  16914137     .      +     .
# 6        chr1  custom    exon  18107495  18107658     .      +     .
# 14       chr1  custom    exon  32539183  32539212     .      +     .
#
#                                             attribute      transcript_id  \
# 0   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 3   gene_id "ENSG00000186510"; transcript_id "ENCT...  ENCT00000002013.1
# 4   gene_id "ENSG00000058453"; transcript_id "ENCT...  ENCT00000002137.1
# 6   gene_id "ENSG00000117154"; transcript_id "ENCT...  ENCT00000002237.1
# 14  gene_id "ENSG00000160062"; transcript_id "ENCT...  ENCT00000003840.1
#
#                            peak_name          gene_id gene_name
# 0         chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11
# 3    chr1:16013071-16013096_Peak_805  ENSG00000186510    CLCNKA
# 4    chr1:16914050-16914229_Peak_884  ENSG00000058453     CROCC
# 6    chr1:18107481-18107503_Peak_935  ENSG00000117154    IGSF21
# 14  chr1:32539150-32539195_Peak_1889  ENSG00000160062    ZBTB8A

# %%
# Create stripped version of gene ID to match with other df
gencode_v47_transcripts['stripped_gene_id'] = gencode_v47_transcripts['gene_id'].str.replace(r'\.\d+$', '', regex=True)
gencode_v47_transcripts.head()
# Out:
#     chr  source     feature  start    end score strand frame  \
# 0  chr1  HAVANA  transcript  11121  14413     .      +     .
# 1  chr1  HAVANA  transcript  11125  14405     .      +     .
# 2  chr1  HAVANA  transcript  11410  14413     .      +     .
# 3  chr1  HAVANA  transcript  11411  14413     .      +     .
# 4  chr1  HAVANA  transcript  11426  14409     .      +     .
#
#              gene_id      transcript_id gene_type gene_name transcript_type  \
# 0  ENSG00000290825.2  ENST00000832824.1    lncRNA  DDX11L16          lncRNA
# 1  ENSG00000290825.2  ENST00000832825.1    lncRNA  DDX11L16          lncRNA
# 2  ENSG00000290825.2  ENST00000832826.1    lncRNA  DDX11L16          lncRNA
# 3  ENSG00000290825.2  ENST00000832827.1    lncRNA  DDX11L16          lncRNA
# 4  ENSG00000290825.2  ENST00000832828.1    lncRNA  DDX11L16          lncRNA
#
#   transcript_name level     tag transcript_support_level havana_transcript  \
# 0    DDX11L16-260     2  TAGENE                      NaN               NaN
# 1    DDX11L16-261     2  TAGENE                      NaN               NaN
# 2    DDX11L16-262     2  TAGENE                      NaN               NaN
# 3    DDX11L16-263     2  TAGENE                      NaN               NaN
# 4    DDX11L16-264     2  TAGENE                      NaN               NaN
#
#   hgnc_id  ont havana_gene protein_id ccdsid stripped_gene_id
# 0     NaN  NaN         NaN        NaN    NaN  ENSG00000290825
# 1     NaN  NaN         NaN        NaN    NaN  ENSG00000290825
# 2     NaN  NaN         NaN        NaN    NaN  ENSG00000290825
# 3     NaN  NaN         NaN        NaN    NaN  ENSG00000290825
# 4     NaN  NaN         NaN        NaN    NaN  ENSG00000290825

# %%
# Keep only the ref tx of the genes which contain the HIT tx with non-overlapping first exons
ref_tx = gencode_v47_transcripts[gencode_v47_transcripts["stripped_gene_id"].isin(non_overlapping_protein_coding_first_exons["gene_id"].unique())]

# %%
ref_tx
# Out:
#          chr  source     feature      start        end score strand frame  \
# 1201    chr1  HAVANA  transcript     923923     944574     .      +     .
# 1202    chr1  HAVANA  transcript     923923     944574     .      +     .
# 1203    chr1  HAVANA  transcript     925150     935793     .      +     .
# 1204    chr1  HAVANA  transcript     925731     944574     .      +     .
# 1205    chr1  HAVANA  transcript     925942     944153     .      +     .
# ...      ...     ...         ...        ...        ...   ...    ...   ...
# 383326  chrX  HAVANA  transcript  154364632  154365207     .      -     .
# 384232  chrY  HAVANA  transcript    6910686    7091683     .      +     .
# 384233  chrY  HAVANA  transcript    6910686    7091683     .      +     .
# 384234  chrY  HAVANA  transcript    6910697    7091683     .      +     .
# 384235  chrY  HAVANA  transcript    7086381    7101970     .      +     .
#
#                    gene_id      transcript_id       gene_type gene_name  \
# 1201    ENSG00000187634.13  ENST00000616016.5  protein_coding    SAMD11
# 1202    ENSG00000187634.13  ENST00000618323.5  protein_coding    SAMD11
# 1203    ENSG00000187634.13  ENST00000437963.5  protein_coding    SAMD11
# 1204    ENSG00000187634.13  ENST00000342066.8  protein_coding    SAMD11
# 1205    ENSG00000187634.13  ENST00000616125.5  protein_coding    SAMD11
# ...                    ...                ...             ...       ...
# 383326  ENSG00000196924.19  ENST00000465144.1  protein_coding      FLNA
# 384232  ENSG00000092377.15  ENST00000346432.3  protein_coding     TBL1Y
# 384233  ENSG00000092377.15  ENST00000355162.6  protein_coding     TBL1Y
# 384234  ENSG00000092377.15  ENST00000383032.6  protein_coding     TBL1Y
# 384235  ENSG00000092377.15  ENST00000651523.1  protein_coding     TBL1Y
#
#         transcript_type transcript_name level                tag  \
# 1201     protein_coding      SAMD11-209     2               CCDS
# 1202     protein_coding      SAMD11-213     2               CCDS
# 1203     protein_coding      SAMD11-203     2  alternative_5_UTR
# 1204     protein_coding      SAMD11-202     2               CCDS
# 1205     protein_coding      SAMD11-210     2       cds_start_NF
# ...                 ...             ...   ...                ...
# 383326  retained_intron        FLNA-210     2                NaN
# 384232   protein_coding       TBL1Y-201     2               CCDS
# 384233   protein_coding       TBL1Y-202     2               CCDS
# 384234   protein_coding       TBL1Y-203     2               CCDS
# 384235   protein_coding       TBL1Y-204     2       cds_start_NF
#
#        transcript_support_level     havana_transcript     hgnc_id  ont  \
# 1201                          5  OTTHUMT00000316521.3  HGNC:28706  NaN
# 1202                          5                   NaN  HGNC:28706  NaN
# 1203                          5  OTTHUMT00000097862.5  HGNC:28706  NaN
# 1204                          5  OTTHUMT00000276866.3  HGNC:28706  NaN
# 1205                          5                   NaN  HGNC:28706  NaN
# ...                         ...                   ...         ...  ...
# 383326                        2  OTTHUMT00000130298.1   HGNC:3754  NaN
# 384232                        1  OTTHUMT00000085362.1  HGNC:18502  NaN
# 384233                        1  OTTHUMT00000085361.1  HGNC:18502  NaN
# 384234                        1  OTTHUMT00000085360.2  HGNC:18502  NaN
# 384235                      NaN  OTTHUMT00000501656.1  HGNC:18502  NaN
#
#                   havana_gene         protein_id       ccdsid stripped_gene_id
# 1201    OTTHUMG00000040719.11  ENSP00000478421.2  CCDS90834.1  ENSG00000187634
# 1202    OTTHUMG00000040719.11  ENSP00000480678.2  CCDS90833.1  ENSG00000187634
# 1203    OTTHUMG00000040719.11  ENSP00000393181.1          NaN  ENSG00000187634
# 1204    OTTHUMG00000040719.11  ENSP00000342313.3      CCDS2.2  ENSG00000187634
# 1205    OTTHUMG00000040719.11  ENSP00000484643.1          NaN  ENSG00000187634
# ...                       ...                ...          ...              ...
# 383326  OTTHUMG00000022712.33                NaN          NaN  ENSG00000196924
# 384232   OTTHUMG00000035299.3  ENSP00000328879.4  CCDS14779.1  ENSG00000092377
# 384233   OTTHUMG00000035299.3  ENSP00000347289.2  CCDS14779.1  ENSG00000092377
# 384234   OTTHUMG00000035299.3  ENSP00000372499.1  CCDS14779.1  ENSG00000092377
# 384235   OTTHUMG00000035299.3  ENSP00000498861.1          NaN  ENSG00000092377
#
# [15796 rows x 24 columns]

# %%
# Convert to pyranges
exons_pr = pr.PyRanges(non_overlapping_protein_coding_first_exons)

tx_pr = pr.PyRanges(ref_tx.rename(columns={"chr": "Chromosome", "start": "Start", "end": "End", "strand": "Strand"})[
        ["Chromosome", "Start", "End", "Strand", "transcript_id", "stripped_gene_id"]])

# %%
joined = exons_pr.join(tx_pr, suffix="_tx")
# Out:
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.

# %%
# Find the exons that are contained in ref tx
fully_contained = joined.df[
    (joined.df["Start"] >= joined.df["Start_tx"]) &
    (joined.df["End"] <= joined.df["End_tx"]) &
    (joined.df["gene_id"] == joined.df["stripped_gene_id"])
]
fully_contained.head()
# Out:
#   Chromosome  source feature   Start     End score Strand frame  \
# 0       chr1  custom    exon  938827  938950     .      +     .
# 1       chr1  custom    exon  938827  938950     .      +     .
# 2       chr1  custom    exon  938827  938950     .      +     .
# 3       chr1  custom    exon  938827  938950     .      +     .
# 4       chr1  custom    exon  938827  938950     .      +     .
#
#                                            attribute      transcript_id  \
# 0  gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 1  gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 2  gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 3  gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 4  gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
#
#                     peak_name          gene_id gene_name  Start_tx  End_tx  \
# 0  chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11    923923  944574
# 1  chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11    923923  944574
# 2  chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11    925731  944574
# 3  chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11    925942  944153
# 4  chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11    925942  944153
#
#   Strand_tx   transcript_id_tx stripped_gene_id
# 0         +  ENST00000616016.5  ENSG00000187634
# 1         +  ENST00000618323.5  ENSG00000187634
# 2         +  ENST00000342066.8  ENSG00000187634
# 3         +  ENST00000616125.5  ENSG00000187634
# 4         +  ENST00000618779.5  ENSG00000187634

# %%
# Add info as column to original df
non_overlapping_protein_coding_first_exons["is_contained"] = non_overlapping_protein_coding_first_exons["transcript_id"].isin(fully_contained["transcript_id"].unique())
non_overlapping_protein_coding_first_exons.head()
# Out:
# /tmp/18110612/ipykernel_1287073/635989619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_overlapping_protein_coding_first_exons["is_contained"] = non_overlapping_protein_coding_first_exons["transcript_id"].isin(fully_contained["transcript_id"].unique())
#    Chromosome  source feature     Start       End score Strand frame  \
# 0        chr1  custom    exon    938827    938950     .      +     .
# 3        chr1  custom    exon  16013096  16013287     .      +     .
# 4        chr1  custom    exon  16914086  16914137     .      +     .
# 6        chr1  custom    exon  18107495  18107658     .      +     .
# 14       chr1  custom    exon  32539183  32539212     .      +     .
#
#                                             attribute      transcript_id  \
# 0   gene_id "ENSG00000187634"; transcript_id "ENCT...  ENCT00000000083.1
# 3   gene_id "ENSG00000186510"; transcript_id "ENCT...  ENCT00000002013.1
# 4   gene_id "ENSG00000058453"; transcript_id "ENCT...  ENCT00000002137.1
# 6   gene_id "ENSG00000117154"; transcript_id "ENCT...  ENCT00000002237.1
# 14  gene_id "ENSG00000160062"; transcript_id "ENCT...  ENCT00000003840.1
#
#                            peak_name          gene_id gene_name  is_contained
# 0         chr1:938656-938830_Peak_62  ENSG00000187634    SAMD11          True
# 3    chr1:16013071-16013096_Peak_805  ENSG00000186510    CLCNKA         False
# 4    chr1:16914050-16914229_Peak_884  ENSG00000058453     CROCC          True
# 6    chr1:18107481-18107503_Peak_935  ENSG00000117154    IGSF21         False
# 14  chr1:32539150-32539195_Peak_1889  ENSG00000160062    ZBTB8A         False

# %%
non_overlapping_protein_coding_first_exons["is_contained"].value_counts()
# Out:
# is_contained
# True     5295
# False    1414
# Name: count, dtype: int64

# %%
non_overlapping_protein_coding_first_exons[non_overlapping_protein_coding_first_exons["gene_id"] == "ENSG00000153956"]
# Out:
#       Chromosome  source feature     Start       End score Strand frame  \
# 13331       chr7  custom    exon  82335920  82335955     .      -     .
#
#                                                attribute transcript_id  \
# 13331  gene_id "ENSG00000153956"; transcript_id "PBT0...   PBT00392775
#
#                                peak_name          gene_id gene_name  \
# 13331  chr7:82335974-82336008_Peak_69353  ENSG00000153956  CACNA2D1
#
#        is_contained
# 13331          True

# %%
# % of exons outside of ref tx region
1414/(1414+5295) *100
# Out:
# 21.076166343717397

# %%
combined_df[(combined_df["Gene name"] == "NEUROD1") & (combined_df["TSS distance category"] == ">100bp")]
# Out:
#        transcript_id   chr                     exons matched_to  \
# 330403  STRT01287272  chr2  [(181680814, 181681497)]        NaN
#
#        matched_ref_id                                           category  \
# 330403            NaN  Fully unannotated transcripts with overlapping...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 330403               NaN               NaN          ENST00000496876.2      -
#
#                                       summarized_category             ref_id  \
# 330403  Unannotated transcripts without any annotated ...  ENST00000496876.2
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 330403  ENST00000496876  ENSG00000162992   NEUROD1  protein_coding
#
#          gene_category  og_gene_id                            peak_name  \
# 330403  protein_coding  STRG137581  chr2:181681469-181681476_Peak_44658
#
#          peak_type  mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 330403  Permissive      1.151595     0.203634     57.419146         0.020056
#
#         TSS_TPM_per_gene  Relative TSS usage   TSS_type  TSS_start    TSS_end  \
# 330403          1.151595            0.020056  minor TSS  181681469  181681476
#
#         distance_to_closest_TSS     closest_ref_id TSS distance category  \
# 330403                      642  ENST00000496876.2                >100bp
#
#         TSS_name  TSS_rank Ranked_TSS_type
# 330403  P44658_U       2.0   secondary TSS

# %%
combined_df[(combined_df["transcript_id"] == "STRT01598057")]
# Out:
#        transcript_id   chr                                              exons  \
# 268749  STRT01598057  chr4  [(84492089, 84493549), (84495672, 84495844), (...
#
#        matched_to                              matched_ref_id  \
# 268749        NaN  ['ENST00000515820.6', 'ENST00000295886.5']
#
#                                                  category  \
# 268749  Transcripts with annotated exons and only over...
#
#                                         unannotated_exons  best_match_ref_id  \
# 268749  [(84492089, 84493549), (84497559, 84498870), (...  ENST00000295886.5
#
#        largest_overlap_gencode_id Strand  \
# 268749                        NaN      -
#
#                                       summarized_category             ref_id  \
# 268749  Unannotated transcripts with annotated and una...  ENST00000295886.5
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 268749  ENST00000295886  ENSG00000163623    NKX6-1  protein_coding
#
#          gene_category       og_gene_id                          peak_name  \
# 268749  protein_coding  ENSG00000163623  chr4:84499125-84499340_Peak_57609
#
#        peak_type  mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 268749    Robust      1.062026     0.086818     35.750168         0.029707
#
#         TSS_TPM_per_gene  Relative TSS usage  TSS_type  TSS_start   TSS_end  \
# 268749         35.185256            0.984198  main TSS   84499125  84499340
#
#         distance_to_closest_TSS     closest_ref_id TSS distance category  \
# 268749                       48  ENST00000295886.5               <=100bp
#
#         TSS_name  TSS_rank Ranked_TSS_type
# 268749  P57609_A       1.0        main TSS

# %%
non_overlapping_protein_coding_first_exons[(non_overlapping_protein_coding_first_exons["is_contained"] == False) & 
                                            (non_overlapping_protein_coding_first_exons["gene_name"] == "PDX1")]
# Out:
# Empty DataFrame
# Columns: [Chromosome, source, feature, Start, End, score, Strand, frame, attribute, transcript_id, peak_name, gene_id, gene_name, is_contained]
# Index: []

# %%
# Which genes have first exons outside of ref tx region?
genes_with_first_exon_outside = set(non_overlapping_protein_coding_first_exons[non_overlapping_protein_coding_first_exons["is_contained"] == False]["gene_name"])

# %%
genes_with_first_exon_CDS & genes_with_first_exon_outside
# Out:
# {'AGPAT5',
#  'ANK2',
#  'AQP1',
#  'ATP9A',
#  'BCAT2',
#  'CATSPERE',
#  'CCT8',
#  'CD109',
#  'EFNA1',
#  'ENPP2',
#  'FEV',
#  'FSTL4',
#  'GHSR',
#  'GPR37L1',
#  'HMGCLL1',
#  'LMO1',
#  'MAPRE1',
#  'ME3',
#  'MYBPHL',
#  'NLGN1',
#  'PARVA',
#  'PDE3A',
#  'PDE8B',
#  'PTPRF',
#  'RAP1GAP2',
#  'RFX6',
#  'RGPD5',
#  'SAMD15',
#  'SHC2',
#  'SLC12A7',
#  'SNX3',
#  'SORL1',
#  'SRCIN1',
#  'SYNJ2',
#  'SYT17',
#  'SYT7',
#  'TARS1',
#  'TENT5B',
#  'TMEM164',
#  'VOPP1',
#  'ZBTB47',
#  'ZC3H12C',
#  'ZNF365'}

# %% [markdown]
# ## Plot relative TSS usage

# %%
protein_coding_tss = combined_df[(combined_df["gene_category"] == "protein_coding") & (combined_df["distance_to_closest_TSS"].notna())]

# %%
protein_coding_tss.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 5  ENCT00000039480.1  chr1  [(235826319, 235829036), (235830226, 235830424...
# 7  ENST00000008440.9  chr1  [(231338256, 231338604), (231339769, 231339868...
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 5  [(235826364, 235829036), (235830226, 235830424...  ENST00000697183.1
# 7  [(231338256, 231338604), (231339769, 231339868...  ENST00000008440.9
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 5  GENCODE-annotated transcripts               NaN               NaN
# 7  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 5                        NaN      -  GENCODE-annotated transcripts
# 7                        NaN      +  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599      NFIA
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019     CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546     HTR1D
# 5  ENST00000697183.1  ENST00000697183  ENSG00000143669      LYST
# 7  ENST00000008440.9  ENST00000008440  ENSG00000010072     SPRTN
#
#         Gene type   gene_category       og_gene_id  \
# 0  protein_coding  protein_coding  ENSG00000162599
# 2  protein_coding  protein_coding  ENSG00000133019
# 3  protein_coding  protein_coding  ENSG00000179546
# 5  protein_coding  protein_coding  ENSG00000143669
# 7  protein_coding  protein_coding  ENSG00000010072
#
#                             peak_name   peak_type  mean_TPM_ref  log2_tx_exp  \
# 0    chr1:61077221-61077380_Peak_3111  Permissive      0.178215    -2.488310
# 2  chr1:239386576-239386587_Peak_7900      Robust      0.468766    -1.093061
# 3    chr1:23217498-23217499_Peak_1212  Permissive      0.064644    -3.951339
# 5  chr1:235866857-235866943_Peak_7768      Robust      0.935162    -0.096711
# 7  chr1:231338247-231338298_Peak_7607      Robust      0.149198    -2.744704
#
#    gene_exp_ref  relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  \
# 0      4.820350         0.036971          0.213765            0.044346
# 2      3.127170         0.149901          1.421490            0.454561
# 3      0.116743         0.553728          0.116743            1.000000
# 5      6.695224         0.139676          6.258520            0.934774
# 7      4.454665         0.033492          0.702539            0.157709
#
#      TSS_type  TSS_start    TSS_end  distance_to_closest_TSS  \
# 0   minor TSS   61077221   61077380                        6
# 2    main TSS  239386576  239386587                        8
# 3  unique TSS   23217498   23217499                        3
# 5    main TSS  235866857  235866943                        6
# 7   minor TSS  231338247  231338298                        3
#
#       closest_ref_id TSS distance category TSS_name  TSS_rank Ranked_TSS_type
# 0  ENST00000699964.1               <=100bp  P3111_A       4.0       minor TSS
# 2  ENST00000676153.1               <=100bp  P7900_A       1.0        main TSS
# 3  ENST00000374619.2               <=100bp  P1212_A       1.0      unique TSS
# 5  ENST00000389793.7               <=100bp  P7768_A       1.0        main TSS
# 7  ENST00000492437.1               <=100bp  P7607_A       2.0   secondary TSS

# %%
fig, ax1 = plt.subplots(figsize=(3, 3))

sns.violinplot(
    x="gene_category",
    y="Relative TSS usage",
    hue="TSS distance category",
    split=True,
    inner="quart",
    palette={"<=100bp": "lightgrey", ">100bp": "coral"},
    data=protein_coding_tss,
    ax=ax1
)


# Remove the default legend
ax1.legend_.remove()

ax1.set_xticks([])
ax1.set_xticklabels([])
# Label axes
ax1.set_xlabel("")
ax1.set_ylabel("Relative TSS usage\nfor the gene", fontsize=12)

# Increase tick font size
ax1.tick_params(axis='x', labelsize=10)
ax1.tick_params(axis='y', labelsize=10)

# Add custom text labels above each violin
ax1.text(-0.22, 1.16, "Annotated\nTSSs", ha='center', va='bottom', fontsize=11, weight='bold', color='grey')
ax1.text(0.22, 1.16, "Unannotated\nTSSs", ha='center', va='bottom', fontsize=11, weight='bold', color='indianred')

# Optional: horizontal colored lines above violins (like in example)
ax1.plot([-0.4, -0.05], [1.13, 1.13], color='grey', lw=3, solid_capstyle='round')
ax1.plot([0.05, 0.4], [1.13, 1.13], color='indianred', lw=3, solid_capstyle='round')

# Horizontal reference line
ax1.axhline(0.2, color='black', linestyle='--', lw=1)

sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %%
# for protein coding genes
fig, ax1 = plt.subplots(figsize=(3,3)) 
sns.violinplot(x="gene_category", y="Relative TSS usage", hue="TSS distance category",
                                       split=True, inner="quart",
                                       palette={"<=100bp": "lightgrey", ">100bp": "coral"},
                                       data=protein_coding_tss, ax=ax1)
sns.despine(left=True, bottom=True)
handles, labels = ax1.get_legend_handles_labels()
labels = ['Annotated TSS', 'Unannotated TSS']
ax1.legend(handles, labels, bbox_to_anchor=(1,1.3), frameon=False, fontsize=11)


ax1.set_ylabel('Relative TSS usage', fontsize=11)
ax1.set_xlabel('')
ax1.tick_params(axis='x', which='both', length=0, labelbottom=False)
ax1.axhline(y=0.2, xmin=-0.5, xmax=1.5, color='k', linewidth=1, dashes=(5,5))

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)
                 & (protein_coding_tss['TSS_type'] == "main TSS")]['peak_name'].nunique()
# Out:
# 808

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)
                 & (protein_coding_tss['TSS_type'] == "unique TSS")]['peak_name'].nunique()
# Out:
# 235

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)
                 & (protein_coding_tss['Relative TSS usage'] > 0.2)]['peak_name'].nunique()
# Out:
# 2678

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)]['peak_name'].nunique()
# Out:
# 10589

# %%
2678/10589 *100
# Out:
# 25.290395693644346

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)
                 & (protein_coding_tss['Ranked_TSS_type'] == "secondary TSS")
                 & (protein_coding_tss['Relative TSS usage'] > 0.2)]['peak_name'].nunique()
# Out:
# 1498

# %%
# combined_df.to_csv('jessies_gffcompare.tsv', sep='\t', index=False)

# %% [markdown]
# ## Newly annotated promoters in well-characterized islet genes

# %%
protein_coding_tss = protein_coding_tss = (
    protein_coding_tss
    .merge(non_overlapping_protein_coding_first_exons[["transcript_id", "is_contained"]], on="transcript_id", how="left")
)

# %%
protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100)
                 & (protein_coding_tss['TSS_type'] == "main TSS")]["Gene name"].unique()
# Out:
# array(['SERINC2', 'XPOT', 'ESD', 'EMC7', 'ATP6V0C', 'KRT19', 'MEIS1',
#        'IL12A', 'IGFBP7', 'TOMM20', 'ENSG00000288674', 'NBL1', 'ELOA',
#        'CAP1', 'TMEM125', 'B4GALT2', 'RPL5', 'ARF1', 'C1orf127', 'DHRS3',
#        'EPHA10', 'JAK1', 'ADIPOR1', 'SLC45A3', 'C1orf198', 'CSF1', 'TNR',
#        'SFPQ', 'PAQR6', 'REG4', 'SMYD3', 'TSPAN1', 'PPP3CB', 'ARHGAP12',
#        'VCL', 'KAT6B', 'PLCE1', 'JMJD1C', 'LOXL4', 'ANKRD1', 'SFTPA1',
#        'ABLIM1', 'LARGE2', 'CD5', 'RAB1B', 'CCND1', 'TRPM5', 'VPS37C',
#        'MAP6', 'TMEM123', 'NACA', 'DENND5B', 'LTBR', 'GABARAPL1', 'PEBP1',
#        'CHD4', 'MLF2', 'DNAJC14', 'TMEM132D', 'DIP2B', 'PRPH', 'IKBIP',
#        'HMGB1', 'STK24', 'PRKCH', 'CHGA', 'SLC22A17', 'SMAD3', 'RHOV',
#        'SPG21', 'NPTN', 'SIN3A', 'TSPAN3', 'CD276', 'TMC5',
#        'ENSG00000285043', 'VPS4A', 'TERF2IP', 'LITAF', 'ZCCHC14', 'CDH1',
#        'SYCE1L', 'MMP15', 'ENSG00000282034', 'CYB561', 'PCGF2', 'ACACA',
#        'CCL2', 'IGFBP4', 'PIPOX', 'NAGLU', 'CLTC', 'PRKAR1A', 'ATP2A3',
#        'DVL2', 'PHF12', 'P4HB', 'SOCS7', 'DNAJC7', 'CYB5A', 'TPM4',
#        'MYH14', 'U2AF2', 'KEAP1', 'RFX1', 'NPHS1', 'MVB12A', 'GTF2F1',
#        'NYAP2', 'GCC2', 'LIMS1', 'SPATS2L', 'FAM117B', 'YWHAQ', 'GTF3C2',
#        'AUP1', 'TMEM127', 'TMBIM1', 'CHPF', 'HDLBP', 'MPHOSPH10', 'NFU1',
#        'SATB2', 'RMND5A', 'RAMP1', 'ITSN2', 'GNAS', 'HM13', 'RIN2',
#        'RPN2', 'EDN3', 'SEZ6L', 'ADA2', 'XBP1', 'TMEM184B', 'CECR2',
#        'CPB1', 'LPP', 'TBC1D23', 'ATP6V1A', 'ST6GAL1', 'TWF2', 'CNBP',
#        'CYP2U1', 'RPS3A', 'SCD5', 'SETD7', 'TBC1D9', 'GASK1B', 'PDS5A',
#        'NDFIP1', 'PAM', 'ENSG00000283782', 'GALNT10', 'WWC1', 'CPLX2',
#        'SQSTM1', 'GOLPH3', 'ZFR', 'VDAC1', 'GEMIN5', 'IRX2', 'RIPK1',
#        'ENSG00000124593', 'STXBP5', 'CDKN1A', 'CD109', 'LRP11', 'MCUR1',
#        'FGD2', 'SENP6', 'SYNGAP1', 'PRKAR1B', 'RAC1', 'PEG10', 'PCOLCE',
#        'UBE3C', 'ACTB', 'CYP51A1', 'CEP41', 'DENND11', 'KCNH2', 'SDK1',
#        'MRPS17', 'POM121C', 'ZNF395', 'SLC39A14', 'STMN2', 'LAPTM4B',
#        'KLF10', 'KIFC2', 'PDLIM2', 'TUBB4B', 'ZFAND5', 'KIF12', 'RAB14',
#        'COL27A1', 'FAM120A', 'ENSG00000257524', 'REPS2', 'PDHA1', 'SYP',
#        'TMEM255A', 'HCFC1', 'CROCC', 'EPHA2', 'PMVK', 'IFT25', 'LRRC41',
#        'CAMSAP2', 'AGO4', 'PDE4B', 'UAP1', 'ATP1B1', 'NEGR1', 'RNF11',
#        'NPHP4', 'TENT5B', 'SLC44A5', 'SLC26A9', 'EPRS1', 'FAF1', 'ANXA9',
#        'MYBPHL', 'ZSWIM5', 'PGBD5', 'LMO4', 'NUCKS1', 'AGL', 'KCNK1',
#        'PTGFRN', 'SVBP', 'PRG4', 'SLC6A9', 'RGS4', 'NIBAN1', 'ARID1A',
#        'YTHDF2', 'EFNA1', 'TET1', 'VWA2', 'GRK5', 'SLC16A12', 'MASTL',
#        'RHOBTB1', 'SFTPD', 'CTNNA3', 'SFRP5', 'PPIF', 'ZRANB1', 'CAMK2G',
#        'BEND7', 'APBB1IP', 'BICC1', 'ZFAND4', 'ARID5B', 'CTBP2', 'OR13A1',
#        'GOLGA7B', 'SEPHS1', 'CNNM1', 'PRRG4', 'QSER1', 'KDM2A', 'PRDM11',
#        'DUSP8', 'BEST1', 'NECTIN1', 'GRAMD1B', 'INSC', 'CCDC86', 'SORL1',
#        'BARX2', 'TENM4', 'CNGA4', 'OAF', 'MPPED2', 'HNRNPUL2',
#        'HNRNPUL2-BSCL2', 'UBE2L6', 'ZBTB44', 'SERPINH1', 'CBL', 'FKBP2',
#        'PPME1', 'SP1', 'PLXNC1', 'ATP2A2', 'PTMS', 'TRHDE', 'OTOGL',
#        'SLCO1A2', 'TMEM132C', 'NAV3', 'ITGA5', 'BCAT1', 'ERP27', 'ATP8A2',
#        'KL', 'LNX2', 'DGKH', 'ENSG00000285444', 'FGF14', 'FGF9', 'TMCO3',
#        'SAMD4A', 'FBXO33', 'SYT16', 'SIPA1L1', 'TTC9', 'CRIP1', 'BEGAIN',
#        'LOXL1', 'CIB2', 'THBS1', 'BAHD1', 'FEM1B', 'ANPEP',
#        'ENSG00000258461', 'FMN1', 'CARMIL2', 'IL34', 'PRSS22', 'PKD1',
#        'CBFA2T3', 'TELO2', 'NECAB2', 'ZNF469', 'STX1B', 'TSPOAP1',
#        'TANC2', 'SMIM5', 'CYGB', 'SHISA6', 'NAGS', 'RPH3AL', 'SLC6A4',
#        'RAP1GAP2', 'CCDC92B', 'ATXN7L3', 'CDK12', 'HOXB2', 'VMO1',
#        'PITPNC1', 'CDK5R1', 'MIB1', 'LPIN2', 'ST8SIA3', 'KIRREL2',
#        'PLIN3', 'SCAF1', 'PRR12', 'TSHZ3', 'GGN', 'ENSG00000269693',
#        'NFKBID', 'ZNF667', 'TEAD2', 'RASIP1', 'MLLT1', 'AP3D1', 'CFD',
#        'TIMM13', 'SELENOW', 'SPTBN1', 'LAPTM4A', 'LONRF2', 'NCKAP5',
#        'SGPP2', 'PLB1', 'PARD3B', 'ANKRD23', 'RNF103-CHMP3', 'TTL',
#        'CIB4', 'FEV', 'CYS1', 'PLEKHA3', 'BUB1', 'RGPD5', 'ANKRD36C',
#        'TMEM163', 'ACMSD', 'RHOQ', 'LRRTM4', 'MAPRE3', 'MTCL2', 'MAPRE1',
#        'PROCR', 'APCDD1L', 'ITPA', 'WFDC3', 'DSTN', 'CFAP61', 'FERMT1',
#        'PTPRT', 'RPRD1B', 'KCNJ6', 'ETS2', 'DSCAM', 'GNAZ', 'PDGFB',
#        'RBX1', 'GRAMD4', 'USP18', 'ADORA2A', 'CABP7', 'CSDC2', 'TBC1D22A',
#        'SEC14L6', 'SLC5A4', 'GRAP2', 'SHISAL1', 'SLC5A1', 'APOBEC3D',
#        'PARVB', 'RFPL2', 'PATZ1', 'MORC2', 'TNNC1', 'PLCH1', 'KCNAB1',
#        'CMTM8', 'ZPLD1', 'ACKR2', 'CACNA1D', 'FYTTD1', 'OSBPL10', 'CADPS',
#        'VGLL3', 'PHF7', 'ATP13A3', 'TNIK', 'FGF12', 'ZNF639', 'ITGB5',
#        'SMARCA5', 'NR3C2', 'RNF150', 'MRPL1', 'MOB1B', 'DCLK2', 'GBA3',
#        'FAM193A', 'SLC4A4', 'STOX2', 'PPP2R2C', 'SLAIN2', 'PGRMC2',
#        'UGT8', 'NADK2', 'GCNT4', 'TTC23L', 'PDE8B', 'ADGRV1', 'COMMD10',
#        'CARD6', 'TMED7-TICAM2', 'MAML1', 'ENSG00000289791', 'UBTD2',
#        'SHROOM1', 'TAP1', 'VNN1', 'DLL1', 'ELOVL5', 'MAN1A1', 'GRM4',
#        'KIFC1', 'BAG2', 'CNPY3', 'SYTL3', 'MAP3K5', 'EDN1', 'UTRN',
#        'JARID2', 'HEBP2', 'PXDC1', 'PDGFA', 'BAZ1B', 'LFNG', 'ZNRF2',
#        'THSD7A', 'MGAM2', 'ELAPOR2', 'MTURN', 'ADCY1', 'VOPP1', 'ITGB8',
#        'HSPB1', 'GRM8', 'JAZF1', 'SMARCD3', 'TMEM178B', 'MTMR9', 'SNTB1',
#        'TDRP', 'ZDHHC2', 'DKK4', 'ZC3H3', 'SGCZ', 'UBR5', 'HNF4G',
#        'KCNB2', 'XKR9', 'DOCK5', 'FAM83H', 'SDC2', 'KBTBD11', 'ADAMTS13',
#        'DENND1A', 'TRAF1', 'KANK1', 'PIP5K1B', 'MFSD14B', 'LPAR1',
#        'TNFSF15', 'NTNG2', 'CDKN2A', 'ADAMTSL1', 'RXRA', 'SPACA9',
#        'FREM1', 'MEGF9', 'EPB41L4B', 'GTF3C4', 'JAK2', 'FAM199X',
#        'ARHGEF6', 'FAM133A', 'PHKA2', 'KDM6A', 'GPRASP2', 'MXRA5',
#        'TMEM187', 'FAM120C', 'ENSG00000285602', 'TEX11', 'NUP62CL',
#        'BCLAF3', 'MAP3K15', 'SPRTN', 'PALMD', 'DDAH1', 'LAMB3', 'TMCC2',
#        'SH3BP5L', 'ITPKB', 'SOX13', 'S100A16', 'CIMAP3', 'TXNDC12',
#        'RCC2', 'CDKN2C', 'POGK', 'ASH1L', 'SKI', 'OBSCN', 'PINK1',
#        'CAPZA1', 'IGSF9', 'FMOD', 'RRAGC', 'COLGALT2', 'DNTTIP2', 'PCBD1',
#        'PSAP', 'GAD2', 'PNLIP', 'ZNF503', 'IDI1', 'FUT11', 'TNKS2',
#        'PLEKHS1', 'PPA1', 'NUTM2E', 'ENSG00000254536', 'NTM', 'AASDHPPT',
#        'AQP11', 'SLC35C1', 'GSTP1', 'BCL9L', 'AMPD3', 'JAM3', 'DCHS1',
#        'LGR4', 'NAV2', 'MAPK8IP1', 'CAPRIN1', 'EPS8', 'ANO6', 'KRT7',
#        'ATN1', 'TNS2', 'SRGAP1', 'GALNT8', 'KLHL42', 'IKZF4', 'NUDT4',
#        'PIANP', 'TUBA1C', 'FREM2', 'SPRY2', 'PLEKHH1', 'TMED8', 'CBLN3',
#        'BAG5', 'ERH', 'LTBP2', 'LGALS3', 'TMX1', 'NAA30', 'PPM1A', 'DLK1',
#        'ENSG00000257341', 'CORO2B', 'SPRED1', 'CHRNA3', 'NEO1', 'ALPK3',
#        'DUOX1', 'SYNM', 'EME2', 'MMP2', 'PRSS27', 'ADCY9', 'ITFG1',
#        'ITGAM', 'CDIP1', 'ARL6IP1', 'TUFM', 'TAT', 'GLIS2', 'PRR11',
#        'MRC2', 'UBTF', 'MSL1', 'THRA', 'FGF11', 'PRKCA', 'KIF1C', 'CHD3',
#        'ARHGEF15', 'POLDIP2', 'CBX1', 'FOXJ1', 'TRIM25', 'TUBB6', 'SOCS6',
#        'GNAL', 'SMAD7', 'ADCYAP1', 'CEACAM6', 'ZNF614', 'MYADM', 'ADGRL1',
#        'IFI30', 'DOHH', 'MISP3', 'CATSPERG', 'LILRB2', 'FUT1', 'ZNF446',
#        'DNAJB1', 'MIDN', 'SERTAD3', 'SH3RF3', 'B3GNT7', 'FRZB', 'FZD5',
#        'LBH', 'RALB', 'CENPA', 'ID2', 'QPCT', 'CNOT11', 'MFSD6', 'FBXO11',
#        'RAB1A', 'SNTA1', 'SRC', 'ATP9A', 'TFF2', 'LZTR1', 'EP300',
#        'MRPL40', 'KIAA1671', 'PIM3', 'MAPK1', 'NEFH', 'UPB1', 'DTX3L',
#        'TM4SF1', 'MB21D2', 'PROS1', 'ADCY5', 'RYBP', 'LIMD1', 'SPCS1',
#        'TNK2', 'DNAH1', 'HSD17B11', 'CCNG2', 'MTHFD2L', 'YTHDC1', 'GAB1',
#        'TACC3', 'AFF1', 'CPE', 'RBM47', 'GRSF1', 'CXCL11', 'FGB', 'ARL9',
#        'ENPEP', 'TAF9', 'PANK3', 'CARTPT', 'EBF1', 'SEC24A', 'CPEB4',
#        'ETF1', 'GLRA1', 'GTF2H2', 'UBE2D2', 'ZMAT2', 'CPNE5', 'NT5E',
#        'TUBB2B', 'GTF3C6', 'VARS1', 'ZNF165', 'MDGA1', 'RNF217', 'PTP4A1',
#        'HIVEP1', 'NEU1', 'WRNIP1', 'TMEM60', 'SEMA3C', 'STEAP1', 'GIGYF1',
#        'WIPF3', 'SLC26A4', 'NAT16', 'CHN2', 'MFSD3', 'ZBTB10', 'DMTN',
#        'ABL1', 'TRUB2', 'GNG10', 'HABP4', 'RAD23B', 'PHPT1', 'ZNF462',
#        'ECPAS', 'RALGDS', 'FUNDC2', 'BCAP31', 'TSPAN7', 'CLTRN', 'PDZD4',
#        'HUWE1', 'IRAK1', 'LAMP2', 'NHSL2', 'SLC38A5', 'SH3BGRL3',
#        'TACSTD2', 'RNF187', 'MLLT11', 'ZMIZ1', 'SRSF8', 'MUC6', 'UQCC3',
#        'KCNA6', 'UBC', 'SMIM10L1', 'LUM', 'PDX1', 'ACOT1', 'CLDN9',
#        'ASIC2', 'F2RL3', 'IER2', 'SWSAP1', 'IFT70A', 'KCNJ3', 'CDC42EP3',
#        'KCMF1', 'CD93', 'TOB2', 'P2RY1', 'GHSR', 'CCNI', 'DAP', 'PLCXD3',
#        'PRPH2', 'PERP', 'HSPA1B', 'CLDN3', 'CCDC71L', 'ATG9B', 'MPLKIP',
#        'CYCS', 'RNF139', 'MAFA', 'DMRTA1'], dtype=object)

# %%
uncontained_main_protein_TSS = protein_coding_tss[(protein_coding_tss['distance_to_closest_TSS'] > 100) &
                                                  (protein_coding_tss['TSS_type'] == "main TSS") &
                                                  (protein_coding_tss['is_contained'] == False)]
uncontained_main_protein_TSS["Gene name"].unique()
# Out:
# array(['AGO4', 'RNF11', 'TENT5B', 'NEGR1', 'MYBPHL', 'LMO4', 'AGL',
#        'ANXA9', 'RGS4', 'EFNA1', 'SFRP5', 'PPIF', 'OR13A1', 'PRRG4',
#        'KDM2A', 'BEST1', 'CCDC86', 'SORL1', 'BARX2', 'CBL',
#        'ENSG00000285444', 'CIB2', 'THBS1', 'ATP6V0C', 'SHISA6', 'CDK5R1',
#        'SCAF1', 'TSHZ3', 'GGN', 'SGPP2', 'CIB4', 'RGPD5', 'FEV', 'PROCR',
#        'MAPRE1', 'DSTN', 'FERMT1', 'CABP7', 'CSDC2', 'SHISAL1',
#        'APOBEC3D', 'MORC2', 'TNNC1', 'ZNF639', 'NR3C2', 'MRPL1', 'GBA3',
#        'GCNT4', 'UBTD2', 'TAP1', 'KIFC1', 'SYTL3', 'EDN1', 'THSD7A',
#        'VOPP1', 'HSPB1', 'JAZF1', 'TMEM178B', 'DKK4', 'MFSD14B',
#        'TNFSF15', 'NTNG2', 'FAM199X', 'FAM133A', 'FAM120C', 'GHSR',
#        'MPLKIP'], dtype=object)

# %%
uncontained_main_protein_TSS[uncontained_main_protein_TSS["Gene name"] == "JAZF1"]
# Out:
#        transcript_id   chr                                              exons  \
# 106221  STRT01927171  chr7  [(27832279, 27832976), (27840698, 27840867), (...
# 106549  STRT01940701  chr7  [(27846298, 27846547), (27895220, 27895416), (...
#
#        matched_to                                     matched_ref_id  \
# 106221        NaN  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 106549        NaN  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
#
#                                                  category  \
# 106221  Transcripts with annotated exons and non-overl...
# 106549  Transcripts with annotated exons and non-overl...
#
#                                         unannotated_exons  best_match_ref_id  \
# 106221  [(27832279, 27832976), (28180463, 28180581), (...  ENST00000649905.1
# 106549  [(27846298, 27846547), (28180463, 28180670), (...  ENST00000452993.5
#
#        largest_overlap_gencode_id Strand  \
# 106221                        NaN      -
# 106549                        NaN      -
#
#                                       summarized_category             ref_id  \
# 106221  Unannotated transcripts with annotated and una...  ENST00000649905.1
# 106549  Unannotated transcripts with annotated and una...  ENST00000452993.5
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 106221  ENST00000649905  ENSG00000153814     JAZF1  protein_coding
# 106549  ENST00000452993  ENSG00000153814     JAZF1  protein_coding
#
#          gene_category                          peak_name   peak_type  \
# 106221  protein_coding  chr7:28181025-28181026_Peak_68177  Permissive
# 106549  protein_coding  chr7:28181025-28181026_Peak_68177  Permissive
#
#              og_gene_id  mean_TPM_ref  log2_tx_exp  gene_exp_ref  \
# 106221  ENSG00000153814      0.028226    -5.146851     14.933891
# 106549  ENSG00000153814      0.015353    -6.025377     14.933891
#
#         relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage  TSS_type  \
# 106221         0.001890          7.364827            0.493162  main TSS
# 106549         0.001028          7.364827            0.493162  main TSS
#
#          TSS_start     TSS_end  distance_to_closest_TSS      closest_ref_id  \
# 106221  28181025.0  28181026.0                      230  ENST00000283928.10
# 106549  28181025.0  28181026.0                      230  ENST00000283928.10
#
#        TSS distance category is_contained
# 106221                >100bp        False
# 106549                >100bp        False

# %%
combined_df[combined_df["Gene name"] == "JAZF1"]
# Out:
#             transcript_id   chr  \
# 34371   ENST00000454041.1  chr7
# 60703   FTMT22500027354.1  chr7
# 117379  FTMT22500024833.1  chr7
# 117403  FTMT22500039401.1  chr7
# 117766        PBT00391887  chr7
# 118399       STRT01926641  chr7
# 118407       STRT01927171  chr7
# 118779       STRT01939313  chr7
# 118803       STRT01940251  chr7
# 118822       STRT01940701  chr7
# 119090       STRT01951003  chr7
# 120116       STRT01987177  chr7
# 296039  ENST00000283928.5  chr7
# 297270        PBT00386374  chr7
# 298166        PBT00391889  chr7
# 298167        PBT00391890  chr7
# 299069       STRT01904714  chr7
# 301589       STRT01955916  chr7
# 301859       STRT01961316  chr7
# 302426       STRT01975064  chr7
# 372627       STRT01951875  chr7
#
#                                                     exons  \
# 34371   [(27895219, 27895416), (27913392, 27913453), (...
# 60703   [(27840720, 27840867), (27991909, 27991981), (...
# 117379       [(28104852, 28105070), (28180463, 28180636)]
# 117403       [(28095522, 28095739), (28180463, 28180636)]
# 117766  [(27830582, 27832976), (27840698, 27840867), (...
# 118399  [(28101637, 28101804), (28104970, 28105070), (...
# 118407  [(27832279, 27832976), (27840698, 27840867), (...
# 118779  [(27953924, 27965541), (27991909, 27991981), (...
# 118803  [(27950100, 27950185), (27991909, 27991981), (...
# 118822  [(27846298, 27846547), (27895220, 27895416), (...
# 119090  [(27832682, 27832976), (27840698, 27840867), (...
# 120116  [(27935061, 27941664), (27991909, 27991981), (...
# 296039  [(27830582, 27832976), (27840698, 27840867), (...
# 297270  [(27838030, 27840867), (27895220, 27895416), (...
# 298166  [(27890808, 27895416), (27991909, 27991981), (...
# 298167       [(27988393, 27991981), (28180463, 28180813)]
# 299069  [(27845892, 27846547), (27895220, 27895416), (...
# 301589  [(27846439, 27846547), (27895220, 27895416), (...
# 301859  [(27832252, 27832976), (27840698, 27840867), (...
# 302426  [(27832297, 27832976), (27840698, 27840867), (...
# 372627  [(27832740, 27832976), (27840698, 27840867), (...
#
#                                                matched_to  \
# 34371   [(27895219, 27895416), (27913392, 27913453), (...
# 60703   [(27840769, 27840867), (27895220, 27895416), (...
# 117379                                                NaN
# 117403                                                NaN
# 117766                                                NaN
# 118399                                                NaN
# 118407                                                NaN
# 118779                                                NaN
# 118803                                                NaN
# 118822                                                NaN
# 119090                                                NaN
# 120116                                                NaN
# 296039                                                NaN
# 297270                                                NaN
# 298166                                                NaN
# 298167                                                NaN
# 299069                                                NaN
# 301589                                                NaN
# 301859                                                NaN
# 302426                                                NaN
# 372627                                                NaN
#
#                                            matched_ref_id  \
# 34371                                   ENST00000454041.1
# 60703                                   ENST00000452993.5
# 117379  ['ENST00000452993.5', 'ENST00000649905.1', 'EN...
# 117403  ['ENST00000452993.5', 'ENST00000649905.1', 'EN...
# 117766  ['ENST00000427814.5', 'ENST00000649905.1', 'EN...
# 118399  ['ENST00000452993.5', 'ENST00000649905.1', 'EN...
# 118407  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 118779  ['ENST00000447620.5', 'ENST00000649905.1', 'EN...
# 118803  ['ENST00000447620.5', 'ENST00000649905.1', 'EN...
# 118822  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 119090  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 120116  ['ENST00000447620.5', 'ENST00000649905.1', 'EN...
# 296039  ['ENST00000427814.5', 'ENST00000649905.1', 'EN...
# 297270  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 298166  ['ENST00000447620.5', 'ENST00000649905.1', 'EN...
# 298167                             ['ENST00000283928.10']
# 299069  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 301589  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 301859  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 302426  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
# 372627  ['ENST00000427814.5', 'ENST00000447620.5', 'EN...
#
#                                                  category  \
# 34371                       GENCODE-annotated transcripts
# 60703   Unannotated transcripts fully contained within...
# 117379  Transcripts with annotated exons and non-overl...
# 117403  Transcripts with annotated exons and non-overl...
# 117766  Transcripts with annotated exons and non-overl...
# 118399  Transcripts with annotated exons and non-overl...
# 118407  Transcripts with annotated exons and non-overl...
# 118779  Transcripts with annotated exons and non-overl...
# 118803  Transcripts with annotated exons and non-overl...
# 118822  Transcripts with annotated exons and non-overl...
# 119090  Transcripts with annotated exons and non-overl...
# 120116  Transcripts with annotated exons and non-overl...
# 296039  Transcripts with annotated exons and only over...
# 297270  Transcripts with annotated exons and only over...
# 298166  Transcripts with annotated exons and only over...
# 298167  Transcripts with annotated exons and only over...
# 299069  Transcripts with annotated exons and only over...
# 301589  Transcripts with annotated exons and only over...
# 301859  Transcripts with annotated exons and only over...
# 302426  Transcripts with annotated exons and only over...
# 372627  Unannotated transcripts composed entirely of a...
#
#                                         unannotated_exons   best_match_ref_id  \
# 34371                                                 NaN                 NaN
# 60703                                                 NaN                 NaN
# 117379                             [(28104852, 28105070)]   ENST00000454041.1
# 117403                             [(28095522, 28095739)]   ENST00000454041.1
# 117766                             [(28179830, 28179869)]   ENST00000649905.1
# 118399       [(28101637, 28101804), (28104970, 28105070)]   ENST00000454041.1
# 118407  [(27832279, 27832976), (28180463, 28180581), (...   ENST00000649905.1
# 118779                             [(27953924, 27965541)]   ENST00000452993.5
# 118803                             [(27950100, 27950185)]   ENST00000454041.1
# 118822  [(27846298, 27846547), (28180463, 28180670), (...   ENST00000452993.5
# 119090  [(27832682, 27832976), (27979078, 27979106), (...   ENST00000649905.1
# 120116                             [(27935061, 27941664)]   ENST00000454041.1
# 296039                             [(28180463, 28181017)]  ENST00000283928.10
# 297270                             [(27838030, 27840867)]  ENST00000283928.10
# 298166                             [(27890808, 27895416)]   ENST00000454041.1
# 298167                             [(27988393, 27991981)]  ENST00000283928.10
# 299069                             [(27845892, 27846547)]   ENST00000452993.5
# 301589                             [(28101619, 28101716)]   ENST00000452993.5
# 301859       [(27832252, 27832976), (28101619, 28101716)]   ENST00000649905.1
# 302426       [(27832297, 27832976), (27846431, 27846547)]  ENST00000283928.10
# 372627                                                NaN   ENST00000649905.1
#
#        largest_overlap_gencode_id Strand  \
# 34371                         NaN      -
# 60703                         NaN      -
# 117379                        NaN      -
# 117403                        NaN      -
# 117766                        NaN      -
# 118399                        NaN      -
# 118407                        NaN      -
# 118779                        NaN      -
# 118803                        NaN      -
# 118822                        NaN      -
# 119090                        NaN      -
# 120116                        NaN      -
# 296039                        NaN      -
# 297270                        NaN      -
# 298166                        NaN      -
# 298167                        NaN      -
# 299069                        NaN      -
# 301589                        NaN      -
# 301859                        NaN      -
# 302426                        NaN      -
# 372627                        NaN      -
#
#                                       summarized_category              ref_id  \
# 34371                       GENCODE-annotated transcripts   ENST00000454041.1
# 60703    Unannotated transcripts with all exons annotated   ENST00000452993.5
# 117379  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 117403  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 117766  Unannotated transcripts with annotated and una...   ENST00000649905.1
# 118399  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 118407  Unannotated transcripts with annotated and una...   ENST00000649905.1
# 118779  Unannotated transcripts with annotated and una...   ENST00000452993.5
# 118803  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 118822  Unannotated transcripts with annotated and una...   ENST00000452993.5
# 119090  Unannotated transcripts with annotated and una...   ENST00000649905.1
# 120116  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 296039  Unannotated transcripts with annotated and una...  ENST00000283928.10
# 297270  Unannotated transcripts with annotated and una...  ENST00000283928.10
# 298166  Unannotated transcripts with annotated and una...   ENST00000454041.1
# 298167  Unannotated transcripts with annotated and una...  ENST00000283928.10
# 299069  Unannotated transcripts with annotated and una...   ENST00000452993.5
# 301589  Unannotated transcripts with annotated and una...   ENST00000452993.5
# 301859  Unannotated transcripts with annotated and una...   ENST00000649905.1
# 302426  Unannotated transcripts with annotated and una...  ENST00000283928.10
# 372627   Unannotated transcripts with all exons annotated   ENST00000649905.1
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 34371   ENST00000454041  ENSG00000153814     JAZF1  protein_coding
# 60703   ENST00000452993  ENSG00000153814     JAZF1  protein_coding
# 117379  ENST00000454041  ENSG00000153814     JAZF1  protein_coding
# 117403  ENST00000454041  ENSG00000153814     JAZF1  protein_coding
# 117766  ENST00000649905  ENSG00000153814     JAZF1  protein_coding
# 118399  ENST00000454041  ENSG00000153814     JAZF1  protein_coding
# 118407  ENST00000649905  ENSG00000153814     JAZF1  protein_coding
ative_tx_exp  TSS_TPM_per_gene  Relative TSS usage       TSS_type  \
# 34371          0.001210          3.529867            0.236366  secondary TSS
# 60703          0.001845          3.529867            0.236366  secondary TSS
# 117379         0.021351          3.529867            0.236366  secondary TSS
# 117403         0.022056          3.529867            0.236366  secondary TSS
# 117766         0.270472          4.039197            0.270472  secondary TSS
# 118399         0.005282          3.529867            0.236366  secondary TSS
# 118407         0.001890          7.364827            0.493162       main TSS
# 118779         0.020343          3.529867            0.236366  secondary TSS
# 118803         0.022410          3.529867            0.236366  secondary TSS
# 118822         0.001028          7.364827            0.493162       main TSS
# 119090         0.004552          3.529867            0.236366  secondary TSS
# 120116         0.016235          3.529867            0.236366  secondary TSS
# 296039         0.490244          7.364827            0.493162       main TSS
# 297270         0.012259          3.529867            0.236366  secondary TSS
# 298166         0.013348          3.529867            0.236366  secondary TSS
# 298167         0.071676          3.529867            0.236366  secondary TSS
# 299069         0.013878          3.529867            0.236366  secondary TSS
# 301589         0.002004          3.529867            0.236366  secondary TSS
# 301859         0.003040          3.529867            0.236366  secondary TSS
# 302426         0.001020          3.529867            0.236366  secondary TSS
# 372627         0.003858          3.529867            0.236366  secondary TSS
#
#          TSS_start     TSS_end  distance_to_closest_TSS      closest_ref_id  \
# 34371   28180519.0  28180817.0                       22  ENST00000283928.10
# 60703   28180519.0  28180817.0                       22  ENST00000283928.10
# 117379  28180519.0  28180817.0                       22  ENST00000283928.10
# 117403  28180519.0  28180817.0                       22  ENST00000283928.10
# 117766  28179889.0  28179890.0                      688   ENST00000452993.5
# 118399  28180519.0  28180817.0                       22  ENST00000283928.10
# 118407  28181025.0  28181026.0                      230  ENST00000283928.10
# 118779  28180519.0  28180817.0                       22  ENST00000283928.10
# 118803  28180519.0  28180817.0                       22  ENST00000283928.10
# 118822  28181025.0  28181026.0                      230  ENST00000283928.10
# 119090  28180519.0  28180817.0                       22  ENST00000283928.10
# 120116  28180519.0  28180817.0                       22  ENST00000283928.10
# 296039  28181025.0  28181026.0                      230  ENST00000283928.10
# 297270  28180519.0  28180817.0                       22  ENST00000283928.10
# 298166  28180519.0  28180817.0                       22  ENST00000283928.10
# 298167  28180519.0  28180817.0                       22  ENST00000283928.10
# 299069  28180519.0  28180817.0                       22  ENST00000283928.10
# 301589  28180519.0  28180817.0                       22  ENST00000283928.10
# 301859  28180519.0  28180817.0                       22  ENST00000283928.10
# 302426  28180519.0  28180817.0                       22  ENST00000283928.10
# 372627  28180519.0  28180817.0                       22  ENST00000283928.10
#
#        TSS distance category
# 34371                <=100bp
# 60703                <=100bp
# 117379               <=100bp
# 117403               <=100bp
# 117766                >100bp
# 118399               <=100bp
# 118407                >100bp
# 118779               <=100bp
# 118803               <=100bp
# 118822                >100bp
# 119090               <=100bp
# 120116               <=100bp
# 296039                >100bp
# 297270               <=100bp
# 298166               <=100bp
# 298167               <=100bp
# 299069               <=100bp
# 301589               <=100bp
# 301859               <=100bp
# 302426               <=100bp
# 372627               <=100bp

# %%
non_overlapping_protein_coding_first_exons[non_overlapping_protein_coding_first_exons["gene_name"] == "CHGA"]
# Out:
#       Chromosome  source feature     Start       End score Strand frame  \
# 22766      chr14  custom    exon  92922631  92923012     .      +     .
# 22797      chr14  custom    exon  92922631  92923012     .      +     .
# 22817      chr14  custom    exon  92922666  92923012     .      +     .
# 22818      chr14  custom    exon  92922613  92923012     .      +     .
# 22819      chr14  custom    exon  92922666  92923012     .      +     .
# 22820      chr14  custom    exon  92922666  92923012     .      +     .
# 22920      chr14  custom    exon  92922601  92923012     .      +     .
# 22921      chr14  custom    exon  92922664  92923012     .      +     .
# 22922      chr14  custom    exon  92922664  92923012     .      +     .
# 22923      chr14  custom    exon  92922664  92923012     .      +     .
# 22924      chr14  custom    exon  92922664  92923012     .      +     .
# 22925      chr14  custom    exon  92922673  92923012     .      +     .
# 22961      chr14  custom    exon  92922642  92923012     .      +     .
# 23108      chr14  custom    exon  92922664  92923012     .      +     .
# 23169      chr14  custom    exon  92922635  92923012     .      +     .
# 23197      chr14  custom    exon  92922627  92923012     .      +     .
# 23198      chr14  custom    exon  92922627  92923012     .      +     .
# 23221      chr14  custom    exon  92922631  92923022     .      +     .
# 23257      chr14  custom    exon  92922664  92923027     .      +     .
# 23319      chr14  custom    exon  92922631  92923012     .      +     .
# 23322      chr14  custom    exon  92922627  92923027     .      +     .
# 23323      chr14  custom    exon  92922627  92923012     .      +     .
# 23405      chr14  custom    exon  92922664  92923012     .      +     .
#
#                                                                                                           attribute  \
# 22766  gene_id "ENSG00000100604"; transcript_id "FTMT25500021605.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22797  gene_id "ENSG00000100604"; transcript_id "FTMT25500037019.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22817  gene_id "ENSG00000100604"; transcript_id "HBMT00000435570.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22818  gene_id "ENSG00000100604"; transcript_id "HBMT00000435577.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22819  gene_id "ENSG00000100604"; transcript_id "HBMT00000435578.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22820  gene_id "ENSG00000100604"; transcript_id "HBMT00000435579.1"; gene_name "CHGA"; gene_type "protein_coding";
# 22920        gene_id "ENSG00000100604"; transcript_id "PBT00132357"; gene_name "CHGA"; gene_type "protein_coding";
# 22921        gene_id "ENSG00000100604"; transcript_id "PBT00132361"; gene_name "CHGA"; gene_type "protein_coding";
# 22922        gene_id "ENSG00000100604"; transcript_id "PBT00132362"; gene_name "CHGA"; gene_type "protein_coding";
# 22923        gene_id "ENSG00000100604"; transcript_id "PBT00132365"; gene_name "CHGA"; gene_type "protein_coding";
# 22924        gene_id "ENSG00000100604"; transcript_id "PBT00132366"; gene_name "CHGA"; gene_type "protein_coding";
# 22925        gene_id "ENSG00000100604"; transcript_id "PBT00132371"; gene_name "CHGA"; gene_type "protein_coding";
# 22961       gene_id "ENSG00000100604"; transcript_id "STRT00609818"; gene_name "CHGA"; gene_type "protein_coding";
# 23108       gene_id "ENSG00000100604"; transcript_id "STRT00635194"; gene_name "CHGA"; gene_type "protein_coding";
# 23169       gene_id "ENSG00000100604"; transcript_id "STRT00645668"; gene_name "CHGA"; gene_type "protein_coding";
# 23197       gene_id "ENSG00000100604"; transcript_id "STRT00647726"; gene_name "CHGA"; gene_type "protein_coding";
# 23198       gene_id "ENSG00000100604"; transcript_id "STRT00647727"; gene_name "CHGA"; gene_type "protein_coding";
# 23221       gene_id "ENSG00000100604"; transcript_id "STRT00650371"; gene_name "CHGA"; gene_type "protein_coding";
# 23257       gene_id "ENSG00000100604"; transcript_id "STRT00652340"; gene_name "CHGA"; gene_type "protein_coding";
# 23319       gene_id "ENSG00000100604"; transcript_id "STRT00657909"; gene_name "CHGA"; gene_type "protein_coding";
# 23322       gene_id "ENSG00000100604"; transcript_id "STRT00658172"; gene_name "CHGA"; gene_type "protein_coding";
# 23323       gene_id "ENSG00000100604"; transcript_id "STRT00658173"; gene_name "CHGA"; gene_type "protein_coding";
# 23405       gene_id "ENSG00000100604"; transcript_id "STRT00670458"; gene_name "CHGA"; gene_type "protein_coding";
#
#            transcript_id                           peak_name          gene_id  \
# 22766  FTMT25500021605.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22797  FTMT25500037019.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22817  HBMT00000435570.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22818  HBMT00000435577.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22819  HBMT00000435578.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22820  HBMT00000435579.1  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22920        PBT00132357  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22921        PBT00132361  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22922        PBT00132362  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22923        PBT00132365  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22924        PBT00132366  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22925        PBT00132371  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 22961       STRT00609818  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23108       STRT00635194  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23169       STRT00645668  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23197       STRT00647726  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23198       STRT00647727  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23221       STRT00650371  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23257       STRT00652340  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23319       STRT00657909  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23322       STRT00658172  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23323       STRT00658173  chr14:92922629-92922671_Peak_23994  ENSG00000100604
# 23405       STRT00670458  chr14:92922629-92922671_Peak_23994  ENSG00000100604
#
#       gene_name  is_contained
# 22766      CHGA         False
# 22797      CHGA         False
# 22817      CHGA         False
# 22818      CHGA         False
# 22819      CHGA         False
# 22820      CHGA         False
# 22920      CHGA         False
# 22921      CHGA         False
# 22922      CHGA         False
# 22923      CHGA         False
# 22924      CHGA         False
# 22925      CHGA         False
# 22961      CHGA         False
# 23108      CHGA         False
# 23169      CHGA         False
# 23197      CHGA         False
# 23198      CHGA         False
# 23221      CHGA         False
# 23257      CHGA         False
# 23319      CHGA         False
# 23322      CHGA         False
# 23323      CHGA         False
# 23405      CHGA         False

# %%
combined_df[combined_df["transcript_id"] == "ENCT00000410423.1"]
# Out:
#             transcript_id   chr                   exons matched_to  \
# 344815  ENCT00000410423.1  chr7  [(28178453, 28179890)]        NaN
#
#        matched_ref_id                                           category  \
# 344815            NaN  Fully unannotated transcripts without any over...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 344815               NaN               NaN                        NaN      -
#
#                                       summarized_category ref_id  \
# 344815  Unannotated transcripts without any annotated ...    NaN
#
#        stripped_ref_id Gene stable ID   Gene name Gene type gene_category  \
# 344815             NaN     Peak_68175  Peak_68175       NaN      unmapped
#
#                                 peak_name   peak_type  og_gene_id  \
# 344815  chr7:28179889-28179890_Peak_68175  Permissive  FTMG048766
#
#         mean_TPM_ref  log2_tx_exp  gene_exp_ref  relative_tx_exp  \
# 344815      0.877368    -0.188746      0.877368              1.0
#
#         TSS_TPM_per_gene  Relative TSS usage    TSS_type   TSS_start  \
# 344815          0.877368                 1.0  unique TSS  28179889.0
#
#            TSS_end  distance_to_closest_TSS     closest_ref_id  \
# 344815  28179890.0                      688  ENST00000452993.5
#
#        TSS distance category
# 344815                >100bp
