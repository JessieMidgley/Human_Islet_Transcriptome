# %% [markdown]
# # Making initial exploratory plots

# %%
import pandas as pd
from tqdm import tqdm
from collections import defaultdict
import pyranges as pr
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from collections import defaultdict
from matplotlib import font_manager
import numpy as np
# Out:
# /users/jferrer/jmidgley/annotation_project/lib64/python3.9/site-packages/sorted_nearest/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

font_path = "ARIAL.TTF"  
font_manager.fontManager.addfont(font_path)

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
font = {'family' : 'arial',
       'weight' : 'normal',
       'size'   : 9}

mpl.rc('font', **font)
mpl.rc('lines', lw=1, c='k')
sns.set_context("notebook", font_scale=1, rc={"axes.linewidth": 1,
                                              "lines.linewidth": 1, 
                                              "font.size": 10,
                                              "axes.titlesize": 10,
                                              "axes.labelsize": 10,
                                              "legend.fontsize": 10,
                                              "xtick.labelsize": 8,
                                              "ytick.labelsize": 8})

# %%
combined_df = pd.read_csv( 'jessies_gffcompare.tsv', sep='\t')
combined_df.head()
# Out:
# /tmp/15068059/ipykernel_3338988/4294323767.py:1: DtypeWarning: Columns (3,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_df = pd.read_csv( 'jessies_gffcompare.tsv', sep='\t')
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id            summarized_category  \
# 0                        NaN  GENCODE-annotated transcripts
# 1                        NaN  GENCODE-annotated transcripts
# 2                        NaN  GENCODE-annotated transcripts
# 3                        NaN  GENCODE-annotated transcripts
# 4                        NaN  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599      NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606  DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019     CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546     HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424       NaN
#
#         Gene type   gene_category  log2_tx_exp
# 0  protein_coding  protein_coding    -2.488310
# 1          lncRNA          lncRNA    -1.480300
# 2  protein_coding  protein_coding    -1.093061
# 3  protein_coding  protein_coding    -3.951339
# 4          lncRNA          lncRNA    -0.698603

# %% [markdown]
# ## Plotting transcript categories

# %%
class_code = combined_df[['transcript_id','category']].groupby('category').count()

category_order = [
    "GENCODE-annotated transcripts",
    "Unannotated transcripts fully contained within GENCODE transcripts",
    "Unannotated transcripts composed entirely of annotated exons",
    "Transcripts with annotated exons and overlapping unannotated exons",
    "Transcripts with annotated exons and non-overlapping unannotated exons",
    "Fully unannotated transcripts with overlapping exons",
    "Fully unannotated transcripts with non-overlapping exons"
]
class_code = class_code.reindex(category_order)
class_code
# Out:
#                                                     transcript_id
# category
# GENCODE-annotated transcripts                               38891
# Unannotated transcripts fully contained within ...          25891
# Unannotated transcripts composed entirely of an...          31022
# Transcripts with annotated exons and overlappin...         199109
# Transcripts with annotated exons and non-overla...          63675
# Fully unannotated transcripts with overlapping ...          14464
# Fully unannotated transcripts with non-overlapp...           3291

# %%
#color_list = ['#F4511E', '#00897B', '#3949AB', '#FFA000', '#BA68C8', '#E53935', '#43A047']
labels = class_code.index
sizes = class_code['transcript_id']
explode = (0.1, 0, 0, 0, 0, 0, 0)

# Calculate percentages
total = sizes.sum()
percent_labels = [f"{label} ({size / total:.1%})" for label, size in zip(labels, sizes)]

# Plot
fig_class_code, ax = plt.subplots(figsize=(3, 2))
patches, texts = ax.pie(
    sizes,
    startangle=90,
    counterclock=False,
    radius=1,
    wedgeprops=dict(width=0.3, edgecolor='w'),
    explode=explode
    #colors=color_list[:len(sizes)]
)

for w in patches:
    w.set_linewidth(0.1)

# Add legend with percentages
ax.legend(patches, percent_labels, frameon=False, bbox_to_anchor=(0.8, 1), fontsize=8)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Plotting summarized transcript categories

# %%
class_code = combined_df[['transcript_id','summarized_category']].groupby('summarized_category').count()
class_code
# Out:
#                                                     transcript_id
# summarized_category
# GENCODE-annotated transcripts                               38891
# Unannotated transcripts with all exons annotated            56913
# Unannotated transcripts with annotated and unan...         262784
# Unannotated transcripts without any annotated e...          17755

# %%
color_list = ['#00897B', '#3949AB', '#FFA000', '#E53935']
labels = class_code.index
sizes = class_code['transcript_id']
explode = (0.1, 0, 0, 0)

# Calculate percentages
total = sizes.sum()
percent_labels = [f"{label} ({size / total:.1%})" for label, size in zip(labels, sizes)]

# Plot
fig_class_code, ax = plt.subplots(figsize=(3, 2))
patches, texts = ax.pie(
    sizes,
    startangle=90,
    counterclock=False,
    radius=1,
    wedgeprops=dict(width=0.3, edgecolor='w'),
    explode=explode,
    colors=color_list[:len(sizes)]
)

for w in patches:
    w.set_linewidth(0.1)

# Add legend with percentages
ax.legend(patches, percent_labels, frameon=False, bbox_to_anchor=(0.8, 1), fontsize=8)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Plotting gene types per transcript category

# %%
counts_table = pd.crosstab(
    combined_df["summarized_category"],
    combined_df["gene_category"]
)
counts_table
# Out:
# gene_category                                       lncRNA  other_noncoding  \
# summarized_category
# GENCODE-annotated transcripts                         3145              223
# Unannotated transcripts with all exons annotated      5190               38
# Unannotated transcripts with annotated and unan...   27479              546
# Unannotated transcripts without any annotated e...    5201              429
#
# gene_category                                       protein_coding  unmapped
# summarized_category
# GENCODE-annotated transcripts                                35523         0
# Unannotated transcripts with all exons annotated             51685         0
# Unannotated transcripts with annotated and unan...          234759         0
# Unannotated transcripts without any annotated e...            8834      3291

# %%
proportions = counts_table.div(counts_table.sum(axis=1), axis=0)
ax = proportions.plot(kind='barh', stacked=True, figsize=(10, 3), colormap='Set2')

custom_labels = ['lncRNA', 'Other non-coding', 'Protein coding', 'None (unmapped transcripts)']  
ax.legend(custom_labels, title="Gene Category", bbox_to_anchor=(0.5, 1), loc='upper center')

plt.ylabel("")
plt.xlabel("Proportion of transcripts")
plt.tight_layout()
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Plotting protein coding and lncRNA transcript categories

# %%
counts_long = counts_table.copy()
counts_long = counts_long.reset_index()

counts_long = counts_long.melt(id_vars='summarized_category', 
                                var_name='gene_category', 
                                value_name='transcript_count')

tx_type_coding = counts_long[counts_long['gene_category'] == 'protein_coding'].copy()
tx_type_lnc = counts_long[counts_long['gene_category'] == 'lncRNA'].copy()

# %%
fig_tx_type, ax = plt.subplots(1,2, figsize=(5,1), sharey=True)

tx_color = [[0, 137, 123], [57, 72, 170], [255, 160, 0], [229, 57, 53]]
tx_color = [[i/255, j/255, k/255] for i,j,k in tx_color]

ax[0].barh(tx_type_coding['summarized_category'], tx_type_coding['transcript_count'], color=tx_color)


ax[1].barh(tx_type_lnc['summarized_category'], tx_type_lnc['transcript_count'], color=tx_color)

ax[0].invert_yaxis()
ax[0].set_title('Protein coding genes')
ax[1].set_title('lncRNA')
ax[0].set_xlabel('Number of transcripts')
ax[1].set_xlabel('Number of transcripts')

for axes in ax:
    for spine in ['top', 'right']:
        axes.spines[spine].set_visible(False)
    axes.set_xscale("log")
    axes.set_xlim(1,1000000)
    axes.set_xticks(np.geomspace(1, 1000000, num=7))

# %% [markdown]
# ## Plotting transcript expression

# %%
tx_color = [[0, 137, 123], [57, 72, 170], [255, 160, 0], [229, 57, 53]]
tx_color = [[i/255, j/255, k/255] for i,j,k in tx_color]
categories = ['Annotated in GENCODE', 'All exons annotated',
              'Some exons annotated', 'No exons annotated' ]

fig_exp, ax = plt.subplots(figsize=(3,1))
sns.boxplot(y='summarized_category', x='log2_tx_exp',
            orient='h',
            palette=tx_color, saturation=1,
            fliersize=0, hue='summarized_category',
            data=combined_df, ax=ax)
ax.set_xticks(np.arange(-10, 15, 5))
ax.set_xlim(-10,8)
sns.despine()
ax.set_yticklabels(categories, fontsize=10)
ax.set_ylabel('')
ax.set_xlabel('Transcript expression (log2)')
# Out:
# /tmp/15068059/ipykernel_3338988/1398659459.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(categories, fontsize=10)
# Text(0.5, 0, 'Transcript expression (log2)')
