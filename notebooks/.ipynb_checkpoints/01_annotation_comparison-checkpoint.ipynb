# %% [markdown]
# # Comparing the HIT to GENCODE v47

# %%
import pandas as pd
from tqdm import tqdm
from collections import defaultdict
import pyranges as pr
import matplotlib as mpl
from collections import defaultdict
import numpy as np
# Out:
# /users/jferrer/jmidgley/annotation_project/lib64/python3.9/site-packages/sorted_nearest/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
gencode_v47_df = pd.read_csv(
    "gencode.v47.tsv",
    sep="\t",
    dtype=str)
gencode_v47_df
# Out:
#         seqname   source feature  start    end score strand frame  \
# 0          chr1   HAVANA    exon  11121  11211     .      +     .
# 1          chr1   HAVANA    exon  12010  12227     .      +     .
# 2          chr1   HAVANA    exon  12613  12721     .      +     .
# 3          chr1   HAVANA    exon  13453  14413     .      +     .
# 4          chr1   HAVANA    exon  11125  11211     .      +     .
# ...         ...      ...     ...    ...    ...   ...    ...   ...
# 2155000    chrM  ENSEMBL    exon  14149  14673     .      -     .
# 2155001    chrM  ENSEMBL    exon  14674  14742     .      -     .
# 2155002    chrM  ENSEMBL    exon  14747  15887     .      +     .
# 2155003    chrM  ENSEMBL    exon  15888  15953     .      +     .
# 2155004    chrM  ENSEMBL    exon  15956  16023     .      -     .
#
#                    gene_id      transcript_id  ...            exon_id level  \
# 0        ENSG00000290825.2  ENST00000832824.1  ...  ENSE00004248723.1     2
# 1        ENSG00000290825.2  ENST00000832824.1  ...  ENSE00004248735.1     2
# 2        ENSG00000290825.2  ENST00000832824.1  ...  ENSE00003582793.1     2
# 3        ENSG00000290825.2  ENST00000832824.1  ...  ENSE00004248730.1     2
# 4        ENSG00000290825.2  ENST00000832825.1  ...  ENSE00004248721.1     2
# ...                    ...                ...  ...                ...   ...
# 2155000  ENSG00000198695.2  ENST00000361681.2  ...  ENSE00001434974.2     3
# 2155001  ENSG00000210194.1  ENST00000387459.1  ...  ENSE00001544476.1     3
# 2155002  ENSG00000198727.2  ENST00000361789.2  ...  ENSE00001436074.2     3
# 2155003  ENSG00000210195.2  ENST00000387460.2  ...  ENSE00001544475.2     3
# 2155004  ENSG00000210196.2  ENST00000387461.2  ...  ENSE00001544473.2     3
#
#                         tag transcript_support_level havana_transcript  \
# 0                    TAGENE                      NaN               NaN
# 1                    TAGENE                      NaN               NaN
# 2                    TAGENE                      NaN               NaN
# 3                    TAGENE                      NaN               NaN
# 4                    TAGENE                      NaN               NaN
# ...                     ...                      ...               ...
# 2155000  appris_principal_1                      NaN               NaN
# 2155001   Ensembl_canonical                      NaN               NaN
# 2155002  appris_principal_1                      NaN               NaN
# 2155003   Ensembl_canonical                      NaN               NaN
# 2155004   Ensembl_canonical                      NaN               NaN
#
#            hgnc_id  ont havana_gene         protein_id ccdsid
# 0              NaN  NaN         NaN                NaN    NaN
# 1              NaN  NaN         NaN                NaN    NaN
# 2              NaN  NaN         NaN                NaN    NaN
# 3              NaN  NaN         NaN                NaN    NaN
# 4              NaN  NaN         NaN                NaN    NaN
# ...            ...  ...         ...                ...    ...
# 2155000  HGNC:7462  NaN         NaN  ENSP00000354665.2    NaN
# 2155001  HGNC:7479  NaN         NaN                NaN    NaN
# 2155002  HGNC:7427  NaN         NaN  ENSP00000354554.2    NaN
# 2155003  HGNC:7499  NaN         NaN                NaN    NaN
# 2155004  HGNC:7494  NaN         NaN                NaN    NaN
#
# [2155005 rows x 25 columns]

# %%
HIT_hg38_df = pd.read_csv(
    "HIT_hg38.tsv",
    sep="\t",
    dtype=str)
HIT_hg38_df
# Out:
#         seqname     source feature     start       end score strand frame  \
# 0          chr1     PacBio    exon     14360     14829     .      -     .
# 1          chr1     PacBio    exon     14970     15038     .      -     .
# 2          chr1     PacBio    exon     15796     15947     .      -     .
# 3          chr1     PacBio    exon     16607     16765     .      -     .
# 4          chr1     PacBio    exon     16854     17055     .      -     .
# ...         ...        ...     ...       ...       ...   ...    ...   ...
# 3967844    chrY  StringTie    exon  20582590  20582693     .      +     .
# 3967845    chrY  StringTie    exon  20584474  20584524     .      +     .
# 3967846    chrY  StringTie    exon  20588024  20588105     .      +     .
# 3967847    chrY  StringTie    exon  20589484  20589575     .      +     .
# 3967848    chrY  StringTie    exon  20592341  20592624     .      +     .
#
#                  gene_id transcript_id gene_name       gene_type  \
# 0        ENSG00000227232   PBT00037199    WASH7P      pseudogene
# 1        ENSG00000227232   PBT00037199    WASH7P      pseudogene
# 2        ENSG00000227232   PBT00037199    WASH7P      pseudogene
# 3        ENSG00000227232   PBT00037199    WASH7P      pseudogene
# 4        ENSG00000227232   PBT00037199    WASH7P      pseudogene
# ...                  ...           ...       ...             ...
# 3967844  ENSG00000198692  STRT02294670    EIF1AY  protein_coding
# 3967845  ENSG00000198692  STRT02294670    EIF1AY  protein_coding
# 3967846  ENSG00000198692  STRT02294670    EIF1AY  protein_coding
# 3967847  ENSG00000198692  STRT02294670    EIF1AY  protein_coding
# 3967848  ENSG00000198692  STRT02294670    EIF1AY  protein_coding
#
#                                  transcript_classification  \
# 0        Novel Protein coding not overlapping annotated...
# 1        Novel Protein coding not overlapping annotated...
# 2        Novel Protein coding not overlapping annotated...
# 3        Novel Protein coding not overlapping annotated...
# 4        Novel Protein coding not overlapping annotated...
# ...                                                    ...
# 3967844  Novel Protein coding: internal additional pept...
# 3967845  Novel Protein coding: internal additional pept...
# 3967846  Novel Protein coding: internal additional pept...
# 3967847  Novel Protein coding: internal additional pept...
# 3967848  Novel Protein coding: internal additional pept...
#
#         protein_id_orf_summary Intron Exon 5prime 3prime closest
# 0                          NaN    NaN  NaN    NaN    NaN     NaN
# 1                          NaN    NaN  NaN    NaN    NaN     NaN
# 2                          NaN    NaN  NaN    NaN    NaN     NaN
# 3                          NaN    NaN  NaN    NaN    NaN     NaN
# 4                          NaN    NaN  NaN    NaN    NaN     NaN
# ...                        ...    ...  ...    ...    ...     ...
# 3967844                    NaN    NaN  NaN    NaN    NaN     NaN
# 3967845                    NaN    NaN  NaN    NaN    NaN     NaN
# 3967846                    NaN    NaN  NaN    NaN    NaN     NaN
# 3967847                    NaN    NaN  NaN    NaN    NaN     NaN
# 3967848                    NaN    NaN  NaN    NaN    NaN     NaN
#
# [3967849 rows x 19 columns]

# %%
# remove duplicated tx
dup_tx = pd.read_csv("duplicated_transcripts.tsv", sep="\t", dtype=str)["transcript_id"].unique()
HIT_hg38_df = HIT_hg38_df[~HIT_hg38_df["transcript_id"].isin(dup_tx)]

# %%
# remove non-standard chr
standard_chromosomes = {f'chr{i}' for i in range(1, 23)}.union({'chrX', 'chrY'})
HIT_hg38_df = HIT_hg38_df[HIT_hg38_df['seqname'].isin(standard_chromosomes)]

# %%
print("Number unique transcripts")
print("GENCODE:", len(gencode_v47_df["transcript_id"].unique()))
print("HIT:", len(HIT_hg38_df["transcript_id"].unique()))
print("Number unique genes")
print("GENCODE:", len(gencode_v47_df["gene_id"].unique()))
print("HIT:", len(HIT_hg38_df["gene_id"].unique()))
# Out:
# Number unique transcripts
# GENCODE: 385659
# HIT: 376343
# Number unique genes
# GENCODE: 78724
# HIT: 22119

# %%
# Build exon dictionaries for each chromosome
def build_transcript_dict(df):
    chr_dict = defaultdict(list)
    grouped = df.groupby("transcript_id")
    
    for tid, group in grouped:
        seqname = group["seqname"].iloc[0]
        exon_coords = sorted(list(zip(group["start"].astype(int), group["end"].astype(int))))
        chr_dict[seqname].append((tid, exon_coords))
    return chr_dict

HIT_hg38_df_exons = build_transcript_dict(HIT_hg38_df)
gencode_v47_df_exons = build_transcript_dict(gencode_v47_df)

# %%
# Find transcripts fully annotated in GENCODE
def exon_overlap(exons1, exons2, tolerance=100):
    for i, ((s1, e1), (s2, e2)) in enumerate(zip(exons1, exons2)):
        if i == 0:  # first exon
            if abs(s1 - s2) > tolerance or e1 != e2:
                return False
        elif i == len(exons1) - 1:  # last exon
            if abs(e1 - e2) > tolerance or s1 != s2:
                return False
        else:  # internal exon
            if s1 != s2 or e1 != e2:
                return False
    return True


# Find new splice variants with ALL exons annotated (GENCODE transcript may contain additional exons)
def subset_match(HIT_exons, gencode_exons, tolerance=100):
    g_idx = 0
    for i, (hit_start, hit_end) in enumerate(HIT_exons):
        found = False
        while g_idx < len(gencode_exons):
            gen_start, gen_end = gencode_exons[g_idx]
            if i == 0:
                # First HIT exon — allow tolerance only on start
                if abs(hit_start - gen_start) <= tolerance and hit_end == gen_end:
                    found = True
                    g_idx += 1
                    break
            elif i == len(HIT_exons) - 1:
                # Last HIT exon — allow tolerance only on end
                if abs(hit_end - gen_end) <= tolerance and hit_start == gen_start:
                    found = True
                    g_idx += 1
                    break
            else:
                # Internal exon — exact match
                if hit_start == gen_start and hit_end == gen_end:
                    found = True
                    g_idx += 1
                    break

            g_idx += 1
        if not found:
            return False

    return True


# Find HIT exons that are annotated in GENCODE
def found_exon(HIT_exon, gencode_exon_dict, position, nr_HIT_exons):
    hit_start, hit_end = HIT_exon
    if position == 0:
        key = (hit_start, hit_end, 'first')
    elif position == nr_HIT_exons - 1:
        key = (hit_start, hit_end, 'last')
    else:
        key = (hit_start, hit_end, 'internal')
    
    if key in gencode_exon_dict:
        return True, gencode_exon_dict[key]
    else:
        return False, set()

# %%
# Build a lookup set of GENCODE exons which includes a tolerance window for the start and end of a tx
def build_tolerant_gencode_set(transcripts, tolerance=100):
    exon_dict = defaultdict(set)
    for tid, exons in transcripts:
        for i, (start, end) in enumerate(exons):
            if i == 0:
                for delta in range(-tolerance, tolerance + 1):
                    exon_dict[(start + delta, end, 'first')].add(tid)
            elif i == len(exons) - 1:
                for delta in range(-tolerance, tolerance + 1):
                    exon_dict[(start, end + delta, 'last')].add(tid)
            else:
                exon_dict[(start, end, 'internal')].add(tid)
    return exon_dict

# %%
# Merge exons that are directly adjacent to each other
def merge_adjacent_exons(exons, tid):
    if not exons:
        return []
    
    # Sort exons by start coordinate 
    exons = sorted(exons, key=lambda x: x[0])
    merged = [exons[0]]
    merged_count = 0
    
    for start, end in exons[1:]:
        last_start, last_end = merged[-1]
        
        # If current exon starts directly after the last one ends
        if start == last_end + 1:
            # Merge them
            merged[-1] = (last_start, end)
            merged_count += 1
        else:
            merged.append((start, end))

    return merged

# %%
matching_transcripts = {}
subset_transcripts = {}
partially_unannotated_transcripts = {}
fully_unannotated_transcripts = {}
new_combo_annotated_exons = {}

for chr_name in HIT_hg38_df_exons:
    print(chr_name)
    if chr_name not in gencode_v47_df_exons:
        continue
    
    HIT_hg38_transcript_list = HIT_hg38_df_exons[chr_name]
    gencode_v47_transcript_list = gencode_v47_df_exons[chr_name]
    
    # Group GENCODE transcripts by exon count
    gencode_by_exon_count = defaultdict(list)
    for tid, exons in gencode_v47_transcript_list:
        gencode_by_exon_count[len(exons)].append((tid, exons))

    # Build fast exon lookup set (for finding individual annotated exons)
    gencode_exon_set = build_tolerant_gencode_set(gencode_v47_transcript_list)

    
    for HIT_tid, HIT_exons in tqdm(HIT_hg38_transcript_list, desc=f"Transcripts in {chr_name}", leave=False):
        HIT_exons = merge_adjacent_exons(HIT_exons, HIT_tid)
        matched = False
        len_hit = len(HIT_exons)
        
        # Try to match entire transcript exactly
        for gencode_tid, gencode_exons in gencode_by_exon_count[len_hit]:
            if exon_overlap(HIT_exons, gencode_exons):
                matching_transcripts[HIT_tid] = {
                    'chr': chr_name,
                    'exons': HIT_exons,
                    'matched_to': gencode_exons,
                    'matched_ref_id': gencode_tid
                }
                matched = True
                break

        if matched:
            continue
            
        # Try subset match (HIT tx contained in GENCODE tx)
        for longer_len in range(len_hit + 1, max(gencode_by_exon_count.keys()) + 1):
            for gencode_tid, gencode_exons in gencode_by_exon_count[longer_len]:
                # Skip if exon coordinates are out of possible range
                if HIT_exons[0][0] > gencode_exons[-1][1] or HIT_exons[-1][1] < gencode_exons[0][0]:
                    continue
                if subset_match(HIT_exons, gencode_exons):
                    subset_transcripts[HIT_tid] = {
                        'chr': chr_name,
                        'exons': HIT_exons,
                        'matched_to': gencode_exons,
                        'matched_ref_id': gencode_tid
                    }
                    matched = True
                    break
            if matched:
                break
            
        if not matched:
            # If entire tx can't be matched, try to match individual exons
            annotated_info = [
                found_exon(exon, gencode_exon_set, i, len_hit)
                for i, exon in enumerate(HIT_exons)
                ]
            annotated_flags = [flag for flag, _ in annotated_info]
            matched_tids = set().union(*[tids for flag, tids in annotated_info if flag])
     
            # No exons are annotated
            if all(not flag for flag in annotated_flags):
                fully_unannotated_transcripts[HIT_tid] = {
                    'chr': chr_name,
                    'exons': HIT_exons
                }
            # All exons are annotated (new splice variant)
            elif all(annotated_flags):
                ref_match_counts = defaultdict(int)
                for flag, tids in annotated_info:
                    for tid in tids:
                        ref_match_counts[tid] += 1

                # Find the reference ID with the most matches
                if ref_match_counts:
                    # Get the highest match count
                    max_count = max(ref_match_counts.values())
    
                    # Find all ref IDs with that count
                    tied_ref_ids = [tid for tid, count in ref_match_counts.items() if count == max_count]
    
                    if len(tied_ref_ids) == 1:
                        # No tie: take the sole best match
                        best_ref_id = tied_ref_ids[0]
                    else:
                        # Tie: resolve by comparing tx lengths
                        hit_exons = dict(HIT_hg38_transcript_list)[HIT_tid]
                        hit_length = hit_exons[-1][1] - hit_exons[0][0]
        
                        ref_lengths = {}
                        for tid in tied_ref_ids:
                            ref_exons = dict(gencode_v47_transcript_list)[tid]
                            ref_lengths[tid] = ref_exons[-1][1] - ref_exons[0][0]
        
                        # Choose the ref ID with length closest to HIT
                        best_ref_id = min(ref_lengths.items(), key=lambda x: abs(x[1] - hit_length))[0]
                else:
                    best_ref_id = None

                # Save result
                new_combo_annotated_exons[HIT_tid] = {
                    'chr': chr_name,
                    'exons': HIT_exons,
                    'matched_ref_id': list(matched_tids),
                    'best_match_ref_id': best_ref_id
                }
            # Some exons annotated
            elif any(not flag for flag in annotated_flags):
                unannotated_exons = [
                    exon for exon, is_annotated in zip(HIT_exons, annotated_flags) if not is_annotated
                ]
                # Count how many times each reference ID appears across annotated exons
                ref_match_counts = defaultdict(int)
                for flag, tids in annotated_info:
                    if flag:
                        for tid in tids:
                            ref_match_counts[tid] += 1

                # Find the reference ID with the most matches
                if ref_match_counts:
                    # Get the highest match count
                    max_count = max(ref_match_counts.values())
    
                    # Find all ref IDs with that count
                    tied_ref_ids = [tid for tid, count in ref_match_counts.items() if count == max_count]
    
                    if len(tied_ref_ids) == 1:
                        # No tie: take the sole best match
                        best_ref_id = tied_ref_ids[0]
                    else:
                        # Tie: resolve by comparing tx lengths
                        hit_exons = dict(HIT_hg38_transcript_list)[HIT_tid]
                        hit_length = hit_exons[-1][1] - hit_exons[0][0]
        
                        ref_lengths = {}
                        for tid in tied_ref_ids:
                            ref_exons = dict(gencode_v47_transcript_list)[tid]
                            ref_lengths[tid] = ref_exons[-1][1] - ref_exons[0][0]
        
                        # Choose the ref ID with length closest to HIT
                        best_ref_id = min(ref_lengths.items(), key=lambda x: abs(x[1] - hit_length))[0]
                else:
                    best_ref_id = None

                # Save result
                partially_unannotated_transcripts[HIT_tid] = {
                    'chr': chr_name,
                    'unannotated_exons': unannotated_exons,
                    'exons': HIT_exons,
                    'matched_ref_id': list(matched_tids),
                    'best_match_ref_id': best_ref_id
                }
# Out:
# chr1
# chr10
# chr11
# chr12
# chr13
# chr14
# chr15
# chr16
# chr17
# chr18
# chr19
# chr2
# chr20
# chr21
# chr22
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chrX
# chrY

# %%
len(matching_transcripts)
# Out:
# 38891

# %%
len(subset_transcripts)
# Out:
# 25891

# %%
len(partially_unannotated_transcripts)
# Out:
# 262784

# %%
len(fully_unannotated_transcripts)
# Out:
# 17755

# %%
len(new_combo_annotated_exons)
# Out:
# 31022

# %%
len(matching_transcripts) + len(subset_transcripts) + len(partially_unannotated_transcripts) + len(fully_unannotated_transcripts) + len(new_combo_annotated_exons)
# Out:
# 376343

# %%
sum(len(v) for v in HIT_hg38_df_exons.values())
# Out:
# 376343

# %% [markdown]
# ### Split up partially unannotated tx into overlapping & non-overlapping

# %%
# Convert dictionary of partially unannotated exons into PyRanges
rows = []
for tid, info in partially_unannotated_transcripts.items():
    for exon in info["unannotated_exons"]:
        start, end = exon
        rows.append({
            "Chromosome": info["chr"],
            "Start": start,
            "End": end,
            "transcript_id": tid
        })

partially_unannotated_df = pd.DataFrame(rows)
# Add strand info
strand_info = HIT_hg38_df[['transcript_id', 'strand']].drop_duplicates(subset='transcript_id')
strand_info = strand_info.rename(columns={'strand': 'Strand'})

# Merge 
partially_unannotated_df = partially_unannotated_df.merge(
    strand_info,
    on='transcript_id',
    how='left'
)

partially_unannotated_pr = pr.PyRanges(partially_unannotated_df)


gencode_pr = pr.PyRanges(
    gencode_v47_df.rename(columns={
        "seqname": "Chromosome",
        "start": "Start",
        "end": "End",
        "strand": "Strand"
    })[["Chromosome", "Start", "End", "Strand", "transcript_id"]]
)

# %%
# Join the unannotated exon df with gencode exons
overlapping_exon_pu = partially_unannotated_pr.join(gencode_pr)
overlapping_exon_pu = overlapping_exon_pu[overlapping_exon_pu.Strand == overlapping_exon_pu.Strand_b]
overlapping_exon_pu = overlapping_exon_pu.df
overlapping_exon_pu = overlapping_exon_pu.rename(columns={
    "transcript_id": "HIT_transcript_id",
    "transcript_id_b": "gencode_transcript_id"
})

# %%
# Assign each exon as overlapping or non-overlapping
overlapping_coords_pu = set(
    tuple(row) for row in overlapping_exon_pu[["Chromosome", "Start", "End"]].values
)

partially_unannotated_df["is_overlapping"] = partially_unannotated_df.apply(
    lambda row: (row["Chromosome"], row["Start"], row["End"]) in overlapping_coords_pu,
    axis=1
)

# %%
import pickle

with open("partially_unannotated_df.pkl", "wb") as f:
    pickle.dump(partially_unannotated_df, f)

# %%
# Split up partially annotated tx into those with exon overlap and those not overlapping gencode exon
non_overlapping_ids_pu = set(
    partially_unannotated_df.loc[partially_unannotated_df["is_overlapping"] == False, "transcript_id"]
)
overlapping_ids_pu = set(partially_unannotated_df["transcript_id"]) - non_overlapping_ids_pu

nonoverlapping_partially_unannotated = {}
overlapping_partially_unannotated = {}

nonoverlapping_partially_unannotated = {
    tid: val for tid, val in partially_unannotated_transcripts.items()
    if tid in non_overlapping_ids_pu
}

overlapping_partially_unannotated = {
    tid: val for tid, val in partially_unannotated_transcripts.items()
    if tid in overlapping_ids_pu
}

# %% [markdown]
# ### Split up fully unannotated tx into overlapping & non-overlapping

# %%
# Now do the same for the fully unannotated tx
rows = []
for tid, info in fully_unannotated_transcripts.items():
    for exon in info["exons"]:
        start, end = exon
        rows.append({
            "Chromosome": info["chr"],
            "Start": start,
            "End": end,
            "transcript_id": tid
        })

fully_unannotated_df = pd.DataFrame(rows)

# Merge with strand info
fully_unannotated_df = fully_unannotated_df.merge(
    strand_info,
    on='transcript_id',
    how='left'
)
fully_unannotated_pr = pr.PyRanges(fully_unannotated_df)

# %%
# join the unannotated exon df with gencode exons
overlapping_exon_fu = fully_unannotated_pr.join(gencode_pr)
overlapping_exon_fu = overlapping_exon_fu[overlapping_exon_fu.Strand == overlapping_exon_fu.Strand_b]
overlapping_exon_fu = overlapping_exon_fu.df
overlapping_exon_fu = overlapping_exon_fu.rename(columns={
    "transcript_id": "HIT_transcript_id",
    "transcript_id_b": "gencode_transcript_id"
})

# %%
overlapping_exon_fu["overlap_size"] = (
    overlapping_exon_fu[["Start", "End", "Start_b", "End_b"]]
    .apply(lambda row: max(0, min(row["End"], row["End_b"]) - max(row["Start"], row["Start_b"])), axis=1)
)

# %%
# Assign each exon as overlapping or non-overlapping
overlapping_coords_fu = set(
    tuple(row) for row in overlapping_exon_fu[["Chromosome", "Start", "End"]].values
)

fully_unannotated_df["is_overlapping"] = fully_unannotated_df.apply(
    lambda row: (row["Chromosome"], row["Start"], row["End"]) in overlapping_coords_fu,
    axis=1
)

# %%
# Compute total overlap size for each HIT-gencode transcript pair
tx_overlap = (
    overlapping_exon_fu
    .groupby(["HIT_transcript_id", "gencode_transcript_id"])["overlap_size"]
    .sum()
    .reset_index()
)

# Select the gencode transcript with the highest total overlap per HIT transcript
best_tx_overlap = (
    tx_overlap
    .sort_values(by=["overlap_size", "gencode_transcript_id"], ascending=[False, True])
    .drop_duplicates(subset=["HIT_transcript_id"])
    .rename(columns={
        "HIT_transcript_id": "transcript_id",
        "gencode_transcript_id": "largest_overlap_gencode_id"
    })[["transcript_id", "largest_overlap_gencode_id"]]
)

# Merge best transcript-level overlap into unannotated_df
fully_unannotated_df = fully_unannotated_df.merge(
    best_tx_overlap,
    on="transcript_id",
    how="left"
)

# %%
# Split up fully unannotated tx into those with exon overlap and those not overlapping gencode exon
overlapping_ids_fu = set(
    fully_unannotated_df.loc[fully_unannotated_df["is_overlapping"] == True, "transcript_id"]
)
non_overlapping_ids_fu = set(fully_unannotated_df["transcript_id"]) - overlapping_ids_fu


nonoverlapping_fully_unannotated = {}
overlapping_fully_unannotated = {}

nonoverlapping_fully_unannotated = {
    tid: val for tid, val in fully_unannotated_transcripts.items()
    if tid in non_overlapping_ids_fu
}

overlapping_fully_unannotated = {
    tid: val for tid, val in fully_unannotated_transcripts.items()
    if tid in overlapping_ids_fu
}

for tid in overlapping_fully_unannotated:
    # Get all gencode IDs with the largest overlaps for this transcript
    gencode_ids = fully_unannotated_df.loc[
        fully_unannotated_df["transcript_id"] == tid, "largest_overlap_gencode_id"
    ].dropna().values[0]

    # Add as a new key to the transcript entry
    overlapping_fully_unannotated[tid]["largest_overlap_gencode_id"] = gencode_ids

# %%
def dict_to_df(d, label):
    df = pd.DataFrame.from_dict(d, orient='index')
    df.reset_index(inplace=True)
    df.rename(columns={'index': 'transcript_id'}, inplace=True)
    df['category'] = label
    return df

# %%
# Convert dictionaries into df
df_nonoverlap_partial = dict_to_df(nonoverlapping_partially_unannotated, "Transcripts with annotated exons and non-overlapping unannotated exons")
df_overlap_partial = dict_to_df(overlapping_partially_unannotated, "Transcripts with annotated exons and only overlapping unannotated exons")
df_unannotated_overlap = dict_to_df(overlapping_fully_unannotated, "Fully unannotated transcripts with overlapping exons")
df_unannotated_nonoverlap = dict_to_df(nonoverlapping_fully_unannotated, "Fully unannotated transcripts without any overlapping exons")
df_combo = dict_to_df(new_combo_annotated_exons, "Unannotated transcripts composed entirely of annotated exons")
df_match = dict_to_df(matching_transcripts, "GENCODE-annotated transcripts")
df_subset = dict_to_df(subset_transcripts, "Unannotated transcripts fully contained within GENCODE transcripts")


combined_df = pd.concat([df_match, df_subset, df_nonoverlap_partial, df_overlap_partial, df_unannotated_overlap, df_unannotated_nonoverlap, df_combo], ignore_index=True)

# %%
# Add strand info
combined_df = combined_df.merge(
    strand_info[["transcript_id", "Strand"]],
    how='left',
    on='transcript_id',
)

# %%
combined_df["category"].value_counts()
# Out:
# category
# Transcripts with annotated exons and only overlapping unannotated exons    199109
# Transcripts with annotated exons and non-overlapping unannotated exons      63675
# GENCODE-annotated transcripts                                               38891
# Unannotated transcripts composed entirely of annotated exons                31022
# Unannotated transcripts fully contained within GENCODE transcripts          25891
# Fully unannotated transcripts with overlapping exons                        14464
# Fully unannotated transcripts without any overlapping exons                  3291
# Name: count, dtype: int64

# %%
def summarize_tx_category(df):
    tx_category = df['category']
    if tx_category == 'GENCODE-annotated transcripts':
        summarized_category = "GENCODE-annotated transcripts"
        ref_id = df['matched_ref_id']
        
    elif tx_category == "Unannotated transcripts fully contained within GENCODE transcripts":
        summarized_category = "Unannotated transcripts with all exons annotated"
        ref_id = df['matched_ref_id']
        
    elif tx_category == "Unannotated transcripts composed entirely of annotated exons":
        summarized_category = "Unannotated transcripts with all exons annotated"
        ref_id = df['best_match_ref_id']
        
    elif tx_category in ["Transcripts with annotated exons and only overlapping unannotated exons", "Transcripts with annotated exons and non-overlapping unannotated exons"]:
        summarized_category = "Unannotated transcripts with annotated and unannotated exons"
        ref_id = df['best_match_ref_id']
        
    elif tx_category == "Fully unannotated transcripts with overlapping exons":
        summarized_category = "Unannotated transcripts without any annotated exons"
        ref_id = df['largest_overlap_gencode_id']
        
    elif tx_category == "Fully unannotated transcripts without any overlapping exons":
        summarized_category = "Unannotated transcripts without any annotated exons"
        ref_id = 'None'
    
    else:
        summarized_category = 'None'
        ref_id = 'None'
        
    return summarized_category, ref_id

# %%
combined_df[['summarized_category', 'ref_id']] = combined_df.apply(summarize_tx_category, axis=1, result_type='expand')

# %% [markdown]
# ## Add gene name and type info

# %%
gene_names = pd.read_csv('mart_export.txt',
                           sep='\t')
gene_names.head()
# Out:
#     Gene stable ID Gene stable ID version Transcript stable ID  \
# 0  ENSG00000210049      ENSG00000210049.1      ENST00000387314
# 1  ENSG00000211459      ENSG00000211459.2      ENST00000389680
# 2  ENSG00000210077      ENSG00000210077.1      ENST00000387342
# 3  ENSG00000210082      ENSG00000210082.2      ENST00000387347
# 4  ENSG00000209082      ENSG00000209082.1      ENST00000386347
#
#   Transcript stable ID version Gene name Gene type
# 0            ENST00000387314.1     MT-TF   Mt_tRNA
# 1            ENST00000389680.2   MT-RNR1   Mt_rRNA
# 2            ENST00000387342.1     MT-TV   Mt_tRNA
# 3            ENST00000387347.2   MT-RNR2   Mt_rRNA
# 4            ENST00000386347.1    MT-TL1   Mt_tRNA

# %%
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id
# 0  ENST00000699992.1
# 1  ENST00000756371.1
# 2  ENST00000676153.1
# 3  ENST00000374619.2
# 4  ENST00000771587.1

# %%
combined_df['stripped_ref_id'] = combined_df['ref_id'].str.replace(r'\.\d+$', '', regex=True)


combined_df = combined_df.merge(
    gene_names[["Transcript stable ID", "Gene stable ID", "Gene name", "Gene type"]],
    how='left',
    left_on='stripped_ref_id',
    right_on='Transcript stable ID'
).drop(columns="Transcript stable ID")

# %%
combined_df["Gene type"].value_counts()
# Out:
# Gene type
# protein_coding                        330761
# lncRNA                                 41009
# transcribed_unprocessed_pseudogene       462
# processed_pseudogene                     366
# transcribed_unitary_pseudogene           133
# TEC                                       60
# transcribed_processed_pseudogene          50
# unprocessed_pseudogene                    46
# IG_V_gene                                 38
# snRNA                                     29
# misc_RNA                                  16
# miRNA                                     15
# snoRNA                                    14
# TR_C_gene                                  5
# scaRNA                                     5
# unitary_pseudogene                         5
# ribozyme                                   1
# Name: count, dtype: int64

# %%
combined_df["Gene name"].isna().sum()
# Out:
# np.int64(20207)

# %%
combined_df["Gene type"].isna().sum()
# Out:
# np.int64(3328)

# %%
combined_df[combined_df['Gene name'].isna()]
# Out:
#             transcript_id   chr  \
# 4       ENCT00000039204.1  chr1
# 121     ENST00000289779.3  chr1
# 516     ENST00000362058.2  chr1
# 1482    ENST00000412483.1  chr1
# 1504    ENST00000415019.1  chr1
# ...                   ...   ...
# 376237       STRT02276681  chrX
# 376270       STRT02285555  chrX
# 376305  ENCT00000484963.1  chrY
# 376330       STRT02292412  chrY
# 376332       STRT02293232  chrY
#
#                                                     exons  \
# 4        [(233319835, 233321155), (233327229, 233327357)]
# 121     [(160997957, 160998906), (160999043, 160999091...
# 516     [(16629670, 16631109), (16631530, 16631613), (...
# 1482     [(234212606, 234214107), (234214868, 234215088)]
# 1504     [(158197922, 158199835), (158203793, 158203877)]
# ...                                                   ...
# 376237  [(136909443, 136909780), (136922445, 136922776...
# 376270  [(102599494, 102599847), (102601464, 102601509...
# 376305  [(11161704, 11163137), (11212744, 11212802), (...
# 376330  [(12406182, 12406500), (12406796, 12406937), (...
# 376332  [(11167047, 11167217), (11212744, 11212802), (...
#
#                                                matched_to  \
# 4        [(233319834, 233321155), (233327229, 233327455)]
# 121     [(160997957, 160998906), (160999043, 160999091...
# 516     [(16629670, 16631109), (16631530, 16631613), (...
# 1482     [(234212606, 234214107), (234214868, 234215088)]
# 1504     [(158197922, 158199835), (158203793, 158203877)]
# ...                                                   ...
# 376237                                                NaN
# 376270                                                NaN
# 376305                                                NaN
# 376330                                                NaN
# 376332                                                NaN
#
#                                            matched_ref_id  \
# 4                                       ENST00000771587.1
# 121                                     ENST00000289779.7
# 516                                     ENST00000362058.2
# 1482                                    ENST00000412483.1
# 1504                                    ENST00000415019.1
# ...                                                   ...
# 376237  [ENST00000685550.1, ENST00000759417.1, ENST000...
# 376270  [ENST00000602366.5, ENST00000332262.10, ENST00...
# 376305  [ENST00000796802.1, ENST00000796805.1, ENST000...
# 376330  [ENST00000357871.6, ENST00000689264.2, ENST000...
# 376332  [ENST00000796802.1, ENST00000796805.1, ENST000...
#
#                                                  category unannotated_exons  \
# 4                           GENCODE-annotated transcripts               NaN
# 121                         GENCODE-annotated transcripts               NaN
# 516                         GENCODE-annotated transcripts               NaN
# 1482                        GENCODE-annotated transcripts               NaN
# 1504                        GENCODE-annotated transcripts               NaN
# ...                                                   ...               ...
# 376237  Unannotated transcripts composed entirely of a...               NaN
# 376270  Unannotated transcripts composed entirely of a...               NaN
# 376305  Unannotated transcripts composed entirely of a...               NaN
# 376330  Unannotated transcripts composed entirely of a...               NaN
# 376332  Unannotated transcripts composed entirely of a...               NaN
#
#         best_match_ref_id largest_overlap_gencode_id Strand  \
# 4                     NaN                        NaN      -
# 121                   NaN                        NaN      -
# 516                   NaN                        NaN      -
# 1482                  NaN                        NaN      -
# 1504                  NaN                        NaN      -
# ...                   ...                        ...    ...
# 376237  ENST00000759400.1                        NaN      +
# 376270  ENST00000466616.6                        NaN      +
# 376305  ENST00000796795.1                        NaN      -
# 376330  ENST00000737339.1                        NaN      -
# 376332  ENST00000796810.1                        NaN      -
#
#                                      summarized_category             ref_id  \
# 4                          GENCODE-annotated transcripts  ENST00000771587.1
# 121                        GENCODE-annotated transcripts  ENST00000289779.7
# 516                        GENCODE-annotated transcripts  ENST00000362058.2
# 1482                       GENCODE-annotated transcripts  ENST00000412483.1
# 1504                       GENCODE-annotated transcripts  ENST00000415019.1
# ...                                                  ...                ...
# 376237  Unannotated transcripts with all exons annotated  ENST00000759400.1
# 376270  Unannotated transcripts with all exons annotated  ENST00000466616.6
# 376305  Unannotated transcripts with all exons annotated  ENST00000796795.1
# 376330  Unannotated transcripts with all exons annotated  ENST00000737339.1
# 376332  Unannotated transcripts with all exons annotated  ENST00000796810.1
#
#         stripped_ref_id   Gene stable ID Gene name       Gene type
# 4       ENST00000771587  ENSG00000300424       NaN          lncRNA
# 121     ENST00000289779  ENSG00000270149       NaN  protein_coding
# 516     ENST00000362058  ENSG00000291072       NaN          lncRNA
# 1482    ENST00000412483  ENSG00000233332       NaN          lncRNA
# 1504    ENST00000415019  ENSG00000176320       NaN          lncRNA
# ...                 ...              ...       ...             ...
# 376237  ENST00000759400  ENSG00000291054       NaN          lncRNA
# 376270  ENST00000466616  ENSG00000271147       NaN          lncRNA
# 376305  ENST00000796795  ENSG00000291032       NaN          lncRNA
# 376330  ENST00000737339  ENSG00000291034       NaN          lncRNA
# 376332  ENST00000796810  ENSG00000291032       NaN          lncRNA
#
# [20207 rows x 16 columns]

# %%
combined_df["category"].unique()
# Out:
# array(['GENCODE-annotated transcripts',
#        'Unannotated transcripts fully contained within GENCODE transcripts',
#        'Transcripts with annotated exons and non-overlapping unannotated exons',
#        'Transcripts with annotated exons and only overlapping unannotated exons',
#        'Fully unannotated transcripts with overlapping exons',
#        'Fully unannotated transcripts without any overlapping exons',
#        'Unannotated transcripts composed entirely of annotated exons'],
#       dtype=object)

# %%
combined_df[(combined_df["Gene type"].isna()) & (combined_df["category"] != "Fully unannotated transcripts without any overlapping exons")]["stripped_ref_id"].unique()
# Out:
# array(['ENST00000351839', 'ENST00000391947', 'ENST00000543133',
#        'ENST00000636394', 'ENST00000334318', 'ENST00000418951',
#        'ENST00000617484', 'ENST00000612355', 'ENST00000458258',
#        'ENST00000756245', 'ENST00000797550'], dtype=object)

# %%
manual_gene_info = {
    "ENST00000351839": {"Gene stable ID": "ENSG00000165119", "Gene name": "HNRNPK", "Gene type": "protein_coding"},
    "ENST00000636394": {"Gene stable ID": "ENSG00000279170", "Gene name": "TSTD3", "Gene type": "protein_coding"},
    "ENST00000617484": {"Gene stable ID": "ENSG00000109819", "Gene name": "PPARGC1A", "Gene type": "protein_coding"},
    "ENST00000756245": {"Gene stable ID": "ENSG00000298529", "Gene name": "ENSG00000298529", "Gene type": "lncRNA"},

    "ENST00000391947": {"Gene stable ID": "ENSG00000198625", "Gene name": "MDM4", "Gene type": "protein_coding"},
    "ENST00000334318": {"Gene stable ID": "ENSG00000119314", "Gene name": "PTBP3", "Gene type": "protein_coding"},
    "ENST00000612355": {"Gene stable ID": "ENSG00000109819", "Gene name": "PPARGC1A", "Gene type": "protein_coding"},
    "ENST00000797550": {"Gene stable ID": "ENSG00000303858", "Gene name": "ENSG00000303858", "Gene type": "lncRNA"},

    "ENST00000543133": {"Gene stable ID": "ENSG00000099968", "Gene name": "BCL2L13", "Gene type": "protein_coding"},
    "ENST00000418951": {"Gene stable ID": "ENSG00000099968", "Gene name": "BCL2L13", "Gene type": "protein_coding"},
    "ENST00000458258": {"Gene stable ID": "ENSG00000119314", "Gene name": "PTBP3", "Gene type": "protein_coding"} 
}

for ref_id, gene_info in manual_gene_info.items():
    mask = combined_df["stripped_ref_id"] == ref_id
    for col, value in gene_info.items():
        combined_df.loc[mask, col] = value

# %%
combined_df[(combined_df["Gene type"].isna()) & (combined_df["category"] != "Fully unannotated transcripts with non-overlapping exons")]["stripped_ref_id"].unique()
# Out:
# array(['None'], dtype=object)

# %%
gene_type_map = {
    'protein_coding': 'protein_coding',
    'lncRNA': 'lncRNA'
}

# Apply the mapping to make a new category column
combined_df['gene_category'] = combined_df['Gene type'].map(gene_type_map)

# Fill the rest: NaN --> 'unmapped', others --> 'other_noncoding'
combined_df['gene_category'] = combined_df['gene_category'].fillna(
    combined_df['Gene type'].apply(lambda x: 'unmapped' if pd.isna(x) else 'other_noncoding')
)
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599      NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606  DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019     CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546     HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424       NaN
#
#         Gene type   gene_category
# 0  protein_coding  protein_coding
# 1          lncRNA          lncRNA
# 2  protein_coding  protein_coding
# 3  protein_coding  protein_coding
# 4          lncRNA          lncRNA

# %% [markdown]
# ## Add transcript expression info

# %%
tpm_df = pd.read_csv( 'TSS_info_w_lift.tsv', sep='\t')
tpm_df.head()
# Out:
#   chromosome  tx_start  tx_end strand      transcript_id          gene_id  \
# 0       chr1     14362   29370      -  ENST00000423562.1  ENSG00000227232
# 1       chr1     14359   29350      -        PBT00037199  ENSG00000227232
# 2       chr1     14359   29350      -        PBT00037200  ENSG00000227232
# 3       chr1     14360   29364      -        PBT00037201  ENSG00000227232
# 4       chr1     14362   29346      -        PBT00037202  ENSG00000227232
#
#   gene_name Gene class   gene_type transcript_type  ...    low_tpm    peak  \
# 0    WASH7P   misc RNA  pseudogene  new_transcript  ...  17.856425  Robust
# 1    WASH7P   misc RNA  pseudogene  new_transcript  ...  17.856425  Robust
# 2    WASH7P   misc RNA  pseudogene  new_transcript  ...  17.856425  Robust
# 3    WASH7P   misc RNA  pseudogene  new_transcript  ...  17.856425  Robust
# 4    WASH7P   misc RNA  pseudogene  new_transcript  ...  17.856425  Robust
#
#    TSS expression high glucose (Salmon, TPM)  Relative TSS usage    TSS_type  \
# 0                                  27.348529                 1.0  unique TSS
# 1                                  27.348529                 1.0  unique TSS
# 2                                  27.348529                 1.0  unique TSS
# 3                                  27.348529                 1.0  unique TSS
# 4                                  27.348529                 1.0  unique TSS
#
#   distance_to_closest_TSS  Distance to closest Gencode TSS  \
# 0                     211                           >100bp
# 1                     211                           >100bp
# 2                     211                           >100bp
# 3                     211                           >100bp
# 4                     211                           >100bp
#
#                       name  new_1st_exon                 new_name
# 0  chr1:29336-29359_Peak_1           yes  chr1:29336-29359_Peak_1
# 1  chr1:29336-29359_Peak_1           yes  chr1:29336-29359_Peak_1
# 2  chr1:29336-29359_Peak_1           yes  chr1:29336-29359_Peak_1
# 3  chr1:29336-29359_Peak_1           yes  chr1:29336-29359_Peak_1
# 4  chr1:29336-29359_Peak_1           yes  chr1:29336-29359_Peak_1
#
# [5 rows x 29 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
# Add back the TPMs per transcript 
tpm_df['mean_TPM_ref'] = tpm_df['relative_tx_exp'] * tpm_df['gene_exp_ref']

# %%
# Remove rows with no expression and log transform
tpm_df = tpm_df[tpm_df['mean_TPM_ref'] != 0].copy()
tpm_df['log2_tx_exp'] = np.log2(tpm_df['mean_TPM_ref'])
tpm_df.head()
# Out:
#   chromosome  tx_start  tx_end strand      transcript_id          gene_id  \
# 0       chr1     14362   29370      -  ENST00000423562.1  ENSG00000227232
# 1       chr1     14359   29350      -        PBT00037199  ENSG00000227232
# 2       chr1     14359   29350      -        PBT00037200  ENSG00000227232
# 3       chr1     14360   29364      -        PBT00037201  ENSG00000227232
# 4       chr1     14362   29346      -        PBT00037202  ENSG00000227232
#
#   gene_name Gene class   gene_type transcript_type  \
# 0    WASH7P   misc RNA  pseudogene  new_transcript
# 1    WASH7P   misc RNA  pseudogene  new_transcript
# 2    WASH7P   misc RNA  pseudogene  new_transcript
# 3    WASH7P   misc RNA  pseudogene  new_transcript
# 4    WASH7P   misc RNA  pseudogene  new_transcript
#
#                               protein_id_orf_summary  \
# 0                                   UniProtKB=B3KS13
# 1                                                NaN
# 2  Closest_UniProtKB=A9QQ17, percentage_UniProtKB...
# 3                                                NaN
# 4                                                NaN
#
#                            transcript_classification  \
# 0                               Known Protein coding
# 1  Novel Protein coding not overlapping annotated...
# 2  Novel Protein coding not overlapping annotated...
# 3                                         Non coding
# 4                                         Non coding
#
#    Transcript expression high glucose (TPM)  gene_exp_ref  relative_tx_exp  \
# 0                                  0.219906     27.348529         0.008041
# 1                                  3.422413     27.348529         0.125141
# 2                                  0.172042     27.348529         0.006291
# 3                                  0.071035     27.348529         0.002597
# 4                                  0.322260     27.348529         0.011783
#
#               CAGE_ID  TSS_start  TSS_end  high_tpm    low_tpm    peak  \
# 0  chr1:29336-29359:-      29336    29359  17.58083  17.856425  Robust
# 1  chr1:29336-29359:-      29336    29359  17.58083  17.856425  Robust
# 2  chr1:29336-29359:-      29336    29359  17.58083  17.856425  Robust
# 3  chr1:29336-29359:-      29336    29359  17.58083  17.856425  Robust
# 4  chr1:29336-29359:-      29336    29359  17.58083  17.856425  Robust
#
#    TSS expression high glucose (Salmon, TPM)  Relative TSS usage    TSS_type  \
# 0                                  27.348529                 1.0  unique TSS
# 1                                  27.348529                 1.0  unique TSS
# 2                                  27.348529                 1.0  unique TSS
# 3                                  27.348529                 1.0  unique TSS
# 4                                  27.348529                 1.0  unique TSS
#
#    distance_to_closest_TSS Distance to closest Gencode TSS  \
# 0                      211                          >100bp
# 1                      211                          >100bp
# 2                      211                          >100bp
# 3                      211                          >100bp
# 4                      211                          >100bp
#
#                       name new_1st_exon                 new_name  \
# 0  chr1:29336-29359_Peak_1          yes  chr1:29336-29359_Peak_1
# 1  chr1:29336-29359_Peak_1          yes  chr1:29336-29359_Peak_1
# 2  chr1:29336-29359_Peak_1          yes  chr1:29336-29359_Peak_1
# 3  chr1:29336-29359_Peak_1          yes  chr1:29336-29359_Peak_1
# 4  chr1:29336-29359_Peak_1          yes  chr1:29336-29359_Peak_1
#
#    mean_TPM_ref  log2_tx_exp
# 0      0.219906    -2.185038
# 1      3.422413     1.775014
# 2      0.172042    -2.539164
# 3      0.071035    -3.815321
# 4      0.322260    -1.633703

# %%
combined_df = combined_df.drop(columns=["log2_tx_exp", "Relative TSS usage"])

# %%
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category                           peak_name  \
# 0  protein_coding  protein_coding    chr1:61077221-61077380_Peak_3111
# 1          lncRNA          lncRNA  chr1:160261726-160261763_Peak_5604
# 2  protein_coding  protein_coding  chr1:239386576-239386587_Peak_7900
# 3  protein_coding  protein_coding    chr1:23217498-23217499_Peak_1212
# 4          lncRNA          lncRNA  chr1:233327323-233327461_Peak_7654
#
#     peak_type       og_gene_id  mean_TPM_ref  log2_tx_exp  gene_exp_ref  \
# 0  Permissive  ENSG00000162599      0.178215    -2.488310      4.820350
# 1  Permissive  ENSG00000228606      0.358414    -1.480300      0.743874
# 2      Robust  ENSG00000133019      0.468766    -1.093061      3.127170
# 3  Permissive  ENSG00000179546      0.064644    -3.951339      0.116743
# 4  Permissive       FTMG005195      0.616169    -0.698603      2.291033
#
#    relative_tx_exp  TSS_TPM_per_gene  Relative TSS usage    TSS_type
# 0         0.036971          0.213765            0.044346   minor TSS
# 1         0.481821          0.743874            1.000000  unique TSS
# 2         0.149901          1.421490            0.454561    main TSS
# 3         0.553728          0.116743            1.000000  unique TSS
# 4         0.268948          2.093885            0.913948    main TSS

# %%
# Merge tx tpm info with comparison results
combined_df = combined_df.merge(
    tpm_df[['transcript_id', 'mean_TPM_ref', 'log2_tx_exp']].rename(columns={'transcript_id': 'merge_key'}),
    how='left',
    left_on='transcript_id',
    right_on='merge_key'
).drop(columns='merge_key')

# %%
len(combined_df)
# Out:
# 376342

# %%
# Add the gene expression (sum of all the transcripts from the same gene) 
f = lambda x: x.sum()
combined_df['gene_exp_ref'] = combined_df.groupby('Gene stable ID')['mean_TPM_ref'].transform(f)

# %%
# get the transcript relative expression 
combined_df['relative_tx_exp'] = combined_df['mean_TPM_ref'] / combined_df['gene_exp_ref']

# %%
# add the sum of TPM expression of all the transcripts from one gene starting from the same TSS
f = lambda x: x.sum()
combined_df['TSS_TPM_per_gene'] = combined_df.groupby(['Gene stable ID','peak_name'])['mean_TPM_ref'].transform(f)

# %%
combined_df['Relative TSS usage'] = combined_df['TSS_TPM_per_gene']/combined_df['gene_exp_ref']

# %%
# control that no gene has an total relative expression above 1
combined_df[(combined_df['Relative TSS usage'] > 1)]
# Out:
# Empty DataFrame
# Columns: [transcript_id, chr, exons, matched_to, matched_ref_id, category, unannotated_exons, best_match_ref_id, largest_overlap_gencode_id, Strand, summarized_category, ref_id, stripped_ref_id, Gene stable ID, Gene name, Gene type, gene_category, peak_name, peak_type, og_gene_id, mean_TPM_ref, log2_tx_exp, gene_exp_ref, relative_tx_exp, TSS_TPM_per_gene, Relative TSS usage]
# Index: []

# %%
TSS_gene_max = combined_df.groupby('Gene stable ID')['Relative TSS usage'].max()

# %%
def get_TSS_type(df):
    if df['Relative TSS usage'] == 1:
        TSS_type = 'unique TSS'
    elif df['Relative TSS usage'] == TSS_gene_max.loc[df['Gene stable ID']]:
        TSS_type = 'main TSS'
    elif df['Relative TSS usage'] < 0.2:
        TSS_type = 'minor TSS'
    else:
        TSS_type = 'secondary TSS'
    return TSS_type


# Add if the TSS is unique for the gene or the main / secondary / minor(less than 20%)
combined_df['TSS_type'] = combined_df.apply(get_TSS_type, axis=1)

# %%
# Merge tpm info with comparison results
combined_df = combined_df.merge(
    tpm_df[['transcript_id', 'log2_tx_exp', 'Relative TSS usage', 'new_name', 'peak']].rename(columns={'transcript_id': 'merge_key'}),
    how='left',
    left_on='transcript_id',
    right_on='merge_key'
).drop(columns='merge_key')

combined_df.rename(columns={"new_name": "peak_name"}, inplace=True)
combined_df.rename(columns={"peak": "peak_type"}, inplace=True)
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand  ...             ref_id  stripped_ref_id  \
# 0                        NaN      +  ...  ENST00000699992.1  ENST00000699992
# 1                        NaN      +  ...  ENST00000756371.1  ENST00000756371
# 2                        NaN      +  ...  ENST00000676153.1  ENST00000676153
# 3                        NaN      -  ...  ENST00000374619.2  ENST00000374619
# 4                        NaN      -  ...  ENST00000771587.1  ENST00000771587
#
#     Gene stable ID Gene name       Gene type   gene_category log2_tx_exp  \
# 0  ENSG00000162599      NFIA  protein_coding  protein_coding   -2.488310
# 1  ENSG00000228606  DCAF8-DT          lncRNA          lncRNA   -1.480300
# 2  ENSG00000133019     CHRM3  protein_coding  protein_coding   -1.093061
# 3  ENSG00000179546     HTR1D  protein_coding  protein_coding   -3.951339
# 4  ENSG00000300424       NaN          lncRNA          lncRNA   -0.698603
#
#    Relative TSS usage                           peak_name   peak_type
# 0            0.044346    chr1:61077221-61077380_Peak_3111  Permissive
# 1            1.000000  chr1:160261726-160261763_Peak_5604  Permissive
# 2            0.454561  chr1:239386576-239386587_Peak_7900      Robust
# 3            1.000000    chr1:23217498-23217499_Peak_1212  Permissive
# 4            1.000000  chr1:233327323-233327461_Peak_7654  Permissive
#
# [5 rows x 21 columns]

# %%
perfect_matches = combined_df[combined_df['category'] == "GENCODE-annotated transcripts"]

# %%
# Find cases where multiple transcripts have same GENCODE perfect match (redundancy)
perfect_matches[(perfect_matches['ref_id'].duplicated(keep=False))].sort_values("ref_id")
# Out:
#            transcript_id    chr  \
# 11512  ENST00000204566.2  chr15
# 12724  MICT00000118180.1  chr15
#
#                                                    exons  \
# 11512  [(64963021, 64963736), (64965320, 64965460), (...
# 12724  [(64963022, 64963736), (64965320, 64965460), (...
#
#                                               matched_to     matched_ref_id  \
# 11512  [(64963022, 64963736), (64965320, 64965460), (...  ENST00000204566.7
# 12724  [(64963022, 64963736), (64965320, 64965460), (...  ENST00000204566.7
#
#                             category unannotated_exons best_match_ref_id  \
# 11512  GENCODE-annotated transcripts               NaN               NaN
# 12724  GENCODE-annotated transcripts               NaN               NaN
#
#       largest_overlap_gencode_id Strand  ...             ref_id  \
# 11512                        NaN      -  ...  ENST00000204566.7
# 12724                        NaN      -  ...  ENST00000204566.7
#
#        stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 11512  ENST00000204566  ENSG00000090487     SPG21  protein_coding
# 12724  ENST00000204566  ENSG00000090487     SPG21  protein_coding
#
#         gene_category log2_tx_exp  Relative TSS usage  \
# 11512  protein_coding    4.442431            0.710032
# 12724  protein_coding   -2.829940            0.710032
#
#                                 peak_name peak_type
# 11512  chr15:64989775-64989928_Peak_26056    Robust
# 12724  chr15:64989775-64989928_Peak_26056    Robust
#
# [2 rows x 21 columns]

# %%
# Drop the transcript with worse match to GENCODE ref
combined_df = combined_df[combined_df['transcript_id'] != 'ENST00000204566.2']

# %%
# Fill NA gene names with the gene ID
combined_df['Gene name'] = combined_df['Gene name'].fillna(combined_df['Gene stable ID'])

# %%
# Add back the orignal gene ID (Andrew's version)
hit_unique = HIT_hg38_df[['transcript_id', 'gene_id']].drop_duplicates(subset='transcript_id')
combined_df = combined_df.merge(hit_unique, on='transcript_id', how='left')
combined_df = combined_df.rename(columns={'gene_id': 'og_gene_id'})

# %%
# Assign new Gene ID/name to unmapped tx
mask = combined_df['Gene stable ID'].isna()

peak_ids = combined_df.loc[mask, 'peak_name'].str.extract(r'(Peak_\d+)', expand=False)
combined_df.loc[mask, 'Gene stable ID'] = peak_ids
combined_df.loc[mask, 'Gene name'] = peak_ids

# %%
combined_df[combined_df["gene_category"] == "unmapped"].sort_values("Gene name")
# Out:
#             transcript_id    chr  \
# 342378        PBT00056522  chr10
# 342442       STRT00252480  chr10
# 342450       STRT00260558  chr10
# 342465       STRT00270734  chr10
# 342512       STRT00312163  chr10
# ...                   ...    ...
# 342392        PBT00058606  chr10
# 342078  HBMT00000006198.1   chr1
# 342032  ENCT00000002302.1   chr1
# 342394        PBT00058610  chr10
# 342363  FTMT23800004525.1  chr10
#
#                                                     exons matched_to  \
# 342378                             [(87691030, 87699809)]        NaN
# 342442       [(88254372, 88254547), (88259789, 88261003)]        NaN
# 342450       [(88254385, 88254547), (88365733, 88365827)]        NaN
# 342465       [(88254334, 88254547), (88278950, 88279099)]        NaN
# 342512       [(88254421, 88254547), (88316020, 88316785)]        NaN
# ...                                                   ...        ...
# 342392  [(78431851, 78434440), (78437405, 78437611), (...        NaN
# 342078       [(19485741, 19486944), (19490178, 19492914)]        NaN
# 342032                             [(19485741, 19489397)]        NaN
# 342394                             [(79977809, 79982054)]        NaN
# 342363                             [(80453339, 80453941)]        NaN
#
#        matched_ref_id                                           category  \
# 342378            NaN  Fully unannotated transcripts without any over...
# 342442            NaN  Fully unannotated transcripts without any over...
# 342450            NaN  Fully unannotated transcripts without any over...
# 342465            NaN  Fully unannotated transcripts without any over...
# 342512            NaN  Fully unannotated transcripts without any over...
# ...               ...                                                ...
# 342392            NaN  Fully unannotated transcripts without any over...
# 342078            NaN  Fully unannotated transcripts without any over...
# 342032            NaN  Fully unannotated transcripts without any over...
# 342394            NaN  Fully unannotated transcripts without any over...
# 342363            NaN  Fully unannotated transcripts without any over...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 342378               NaN               NaN                        NaN      +
# 342442               NaN               NaN                        NaN      +
# 342450               NaN               NaN                        NaN      +
# 342465               NaN               NaN                        NaN      +
# 342512               NaN               NaN                        NaN      +
# ...                  ...               ...                        ...    ...
# 342392               NaN               NaN                        NaN      -
# 342078               NaN               NaN                        NaN      +
# 342032               NaN               NaN                        NaN      +
# 342394               NaN               NaN                        NaN      -
# 342363               NaN               NaN                        NaN      -
#
#         ... stripped_ref_id Gene stable ID   Gene name Gene type  \
# 342378  ...            None     Peak_10119  Peak_10119       NaN
# 342442  ...            None     Peak_10177  Peak_10177       NaN
# 342450  ...            None     Peak_10177  Peak_10177       NaN
# 342465  ...            None     Peak_10177  Peak_10177       NaN
# 342512  ...            None     Peak_10177  Peak_10177       NaN
# ...     ...             ...            ...         ...       ...
# 342392  ...            None      Peak_9894   Peak_9894       NaN
# 342078  ...            None       Peak_996    Peak_996       NaN
# 342032  ...            None       Peak_996    Peak_996       NaN
# 342394  ...            None      Peak_9964   Peak_9964       NaN
# 342363  ...            None      Peak_9999   Peak_9999       NaN
#
#        gene_category log2_tx_exp Relative TSS usage  \
# 342378      unmapped   -1.353093           1.000000
# 342442      unmapped   -3.250237           1.000000
# 342450      unmapped   -6.209846           1.000000
# 342465      unmapped   -5.259763           0.042094
# 342512      unmapped   -4.843592           1.000000
# ...              ...         ...                ...
# 342392      unmapped   -4.491659           1.000000
# 342078      unmapped   -4.207605           0.196512
# 342032      unmapped   -3.132117           0.196512
# 342394      unmapped   -3.456994           1.000000
# 342363      unmapped   -4.368962           1.000000
#
#                                  peak_name   peak_type  og_gene_id
# 342378  chr10:87691007-87691017_Peak_10119  Permissive   PBG006147
# 342442  chr10:88254381-88254385_Peak_10177  Permissive  STRG028391
# 342450  chr10:88254381-88254385_Peak_10177  Permissive  STRG028391
# 342465  chr10:88254381-88254385_Peak_10177  Permissive   PBG006152
# 342512  chr10:88254381-88254385_Peak_10177  Permissive  STRG028391
# ...                                    ...         ...         ...
# 342392   chr10:78458139-78458287_Peak_9894  Permissive   PBG007271
# 342078     chr1:19485730-19485780_Peak_996  Permissive  FTMG000306
# 342032     chr1:19485730-19485780_Peak_996  Permissive  FTMG000306
# 342394   chr10:79982070-79982071_Peak_9964  Permissive   PBG007290
# 342363   chr10:80453936-80453983_Peak_9999  Permissive  FTMG007301
#
# [3291 rows x 22 columns]

# %%
combined_df["Gene stable ID"].nunique()
# Out:
# 22068

# %%
combined_df["og_gene_id"].nunique()
# Out:
# 22119

# %%
#combined_df.to_csv('jessies_gffcompare.tsv', sep='\t', index=False)

# %%
len(combined_df)
# Out:
# 376342

# %%
# not a perfect match but old transcript ID is from GENCODE
combined_df[(combined_df['category'] != "GENCODE-annotated transcripts") & (combined_df['transcript_id'].str.startswith("ENS"))]
# Out:
#             transcript_id   chr  \
# 38927   ENST00000235329.5  chr1
# 38928   ENST00000236914.3  chr1
# 38929   ENST00000239457.5  chr1
# 38930   ENST00000253251.8  chr1
# 38931   ENST00000261443.5  chr1
# ...                   ...   ...
# 375496  ENST00000543642.1  chrX
# 375497  ENST00000545566.1  chrX
# 375498  ENST00000545618.1  chrX
# 375499  ENST00000602791.1  chrX
# 376306  ENST00000538878.1  chrY
#
#                                                     exons  \
# 38927   [(11980197, 11980484), (11981970, 11982114), (...
# 38928   [(200027634, 200027911), (200043774, 200043892...
# 38929   [(173824659, 173825356), (173826687, 173826786...
# 38930   [(10032959, 10033694), (10072028, 10072214), (...
# 38931   [(114716920, 114718216), (114718613, 114718745...
# ...                                                   ...
# 375496  [(37349330, 37349469), (37406209, 37406259), (...
# 375497  [(13653123, 13653188), (13655289, 13655373), (...
# 375498  [(64916370, 64917896), (64919042, 64919204), (...
# 375499       [(77910631, 77910835), (77962623, 77964890)]
# 376306  [(13323047, 13323368), (13323555, 13323760), (...
#
#                                                matched_to  \
# 38927   [(11980209, 11980484), (11981970, 11982114), (...
# 38928   [(200027710, 200027911), (200039658, 200039795...
# 38929   [(173824673, 173825356), (173826687, 173826786...
# 38930   [(10032958, 10033694), (10072028, 10072214), (...
# 38931   [(114716913, 114718216), (114718613, 114718745...
# ...                                                   ...
# 375496                                                NaN
# 375497                                                NaN
# 375498                                                NaN
# 375499                                                NaN
# 376306                                                NaN
#
#                                            matched_ref_id  \
# 38927                                   ENST00000675817.1
# 38928                                   ENST00000367362.8
# 38929                                   ENST00000649689.2
# 38930                                  ENST00000343090.11
# 38931                                  ENST00000339438.10
# ...                                                   ...
# 375496  [ENST00000850645.1, ENST00000465127.1, ENST000...
# 375497  [ENST00000490617.1, ENST00000544987.3, ENST000...
# 375498  [ENST00000337990.2, ENST00000492653.6, ENST000...
# 375499  [ENST00000686515.1, ENST00000685264.1, ENST000...
# 376306  [ENST00000382896.9, ENST00000624098.3, ENST000...
#
#                                                  category unannotated_exons  \
# 38927   Unannotated transcripts fully contained within...               NaN
# 38928   Unannotated transcripts fully contained within...               NaN
# 38929   Unannotated transcripts fully contained within...               NaN
# 38930   Unannotated transcripts fully contained within...               NaN
# 38931   Unannotated transcripts fully contained within...               NaN
# ...                                                   ...               ...
# 375496  Unannotated transcripts composed entirely of a...               NaN
# 375497  Unannotated transcripts composed entirely of a...               NaN
# 375498  Unannotated transcripts composed entirely of a...               NaN
# 375499  Unannotated transcripts composed entirely of a...               NaN
# 376306  Unannotated transcripts composed entirely of a...               NaN
#
#         best_match_ref_id largest_overlap_gencode_id Strand  ...  \
# 38927                 NaN                        NaN      +  ...
# 38928                 NaN                        NaN      +  ...
# 38929                 NaN                        NaN      +  ...
# 38930                 NaN                        NaN      +  ...
# 38931                 NaN                        NaN      -  ...
# ...                   ...                        ...    ...  ...
# 375496  ENST00000378628.9                        NaN      +  ...
# 375497  ENST00000696128.1                        NaN      +  ...
# 375498  ENST00000703136.1                        NaN      -  ...
# 375499  ENST00000602791.2                        NaN      +  ...
# 376306  ENST00000329134.9                        NaN      -  ...
#
#         stripped_ref_id   Gene stable ID        Gene name       Gene type  \
# 38927   ENST00000675817  ENSG00000116688             MFN2  protein_coding
# 38928   ENST00000367362  ENSG00000116833            NR5A2  protein_coding
# 38929   ENST00000649689  ENSG00000117593            DARS2  protein_coding
# 38930   ENST00000343090  ENSG00000130939            UBE4B  protein_coding
# 38931   ENST00000339438  ENSG00000009307            CSDE1  protein_coding
# ...                 ...              ...              ...             ...
# 375496  ENST00000378628  ENSG00000130962            PRRG1  protein_coding
# 375497  ENST00000696128  ENSG00000176896           TCEANC  protein_coding
# 375498  ENST00000703136  ENSG00000126970            ZC4H2  protein_coding
# 375499  ENST00000602791  ENSG00000293258  ENSG00000293258          lncRNA
# 376306  ENST00000329134  ENSG00000183878              UTY  protein_coding
#
#          gene_category log2_tx_exp Relative TSS usage  \
# 38927   protein_coding    1.842377           0.849730
# 38928   protein_coding    2.091592           0.573290
# 38929   protein_coding   -1.795171           0.930435
# 38930   protein_coding    2.490205           0.997981
# 38931   protein_coding    1.739073           0.712407
# ...                ...         ...                ...
# 375496  protein_coding   -0.986525           1.000000
# 375497  protein_coding   -3.353878           1.000000
# 375498  protein_coding   -3.809740           0.531402
# 375499          lncRNA   -1.288001           1.000000
# 376306  protein_coding   -5.110419           0.071192
#
#                                  peak_name   peak_type       og_gene_id
# 38927      chr1:11980204-11980451_Peak_666      Robust  ENSG00000116688
# 38928   chr1:200027537-200027864_Peak_6480      Robust  ENSG00000116833
# 38929   chr1:173824474-173824687_Peak_6035      Robust  ENSG00000117593
# 38930      chr1:10032954-10033166_Peak_545      Robust  ENSG00000130939
# 38931   chr1:114757960-114757994_Peak_4265      Robust  ENSG00000009307
# ...                                    ...         ...              ...
# 375496   chrX:37349326-37349369_Peak_78599      Robust  ENSG00000130962
# 375497   chrX:13653136-13653193_Peak_78335      Robust  ENSG00000176896
# 375498   chrX:64976443-64976455_Peak_79235      Robust  ENSG00000126970
# 375499   chrX:77910639-77910745_Peak_79619      Robust  ENSG00000248503
# 376306   chrY:13479608-13479629_Peak_80736  Permissive  ENSG00000183878
#
# [14846 rows x 22 columns]

# %%
# perfect match but doesn't have GENCODE ID
combined_df[(combined_df['category'] == "GENCODE-annotated transcripts") & (~combined_df['transcript_id'].str.startswith("ENS"))]
# Out:
#            transcript_id   chr  \
# 0      ENCT00000006334.1  chr1
# 1      ENCT00000013056.1  chr1
# 2      ENCT00000019620.1  chr1
# 3      ENCT00000022754.1  chr1
# 4      ENCT00000039204.1  chr1
# ...                  ...   ...
# 38885       STRT02291998  chrY
# 38886       STRT02292325  chrY
# 38887       STRT02292507  chrY
# 38888       STRT02292969  chrY
# 38889       STRT02293736  chrY
#
#                                                    exons  \
# 0           [(61077274, 61077628), (61077916, 61079203)]
# 1       [(160261734, 160261922), (160281430, 160281892)]
# 2      [(239386568, 239387227), (239492709, 239492807...
# 3           [(23191893, 23195001), (23217291, 23217499)]
# 4       [(233319835, 233321155), (233327229, 233327357)]
# ...                                                  ...
# 38885  [(3002941, 3003217), (3058657, 3058784), (3079...
# 38886  [(19567359, 19567482), (19587210, 19587507), (...
# 38887  [(18932730, 18932841), (19041370, 19041586), (...
# 38888  [(19555472, 19555554), (19558024, 19558140), (...
# 38889  [(18872584, 18872834), (18877068, 18877205), (...
#
#                                               matched_to     matched_ref_id  \
# 0           [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1       [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2      [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3           [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4       [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
# ...                                                  ...                ...
# 38885  [(3002901, 3003217), (3058657, 3058784), (3079...  ENST00000803197.1
# 38886  [(19567372, 19567482), (19587210, 19587507), (...  ENST00000789733.1
# 38887  [(18932699, 18932841), (19041370, 19041586), (...  ENST00000850219.1
# 38888  [(19555390, 19555554), (19558024, 19558140), (...  ENST00000761024.1
# 38889  [(18872501, 18872834), (18877068, 18877205), (...  ENST00000670243.2
#
#                             category unannotated_exons best_match_ref_id  \
# 0      GENCODE-annotated transcripts               NaN               NaN
# 1      GENCODE-annotated transcripts               NaN               NaN
# 2      GENCODE-annotated transcripts               NaN               NaN
# 3      GENCODE-annotated transcripts               NaN               NaN
# 4      GENCODE-annotated transcripts               NaN               NaN
# ...                              ...               ...               ...
# 38885  GENCODE-annotated transcripts               NaN               NaN
# 38886  GENCODE-annotated transcripts               NaN               NaN
# 38887  GENCODE-annotated transcripts               NaN               NaN
# 38888  GENCODE-annotated transcripts               NaN               NaN
# 38889  GENCODE-annotated transcripts               NaN               NaN
#
#       largest_overlap_gencode_id Strand  ...  stripped_ref_id  \
# 0                            NaN      +  ...  ENST00000699992
# 1                            NaN      +  ...  ENST00000756371
# 2                            NaN      +  ...  ENST00000676153
# 3                            NaN      -  ...  ENST00000374619
# 4                            NaN      -  ...  ENST00000771587
# ...                          ...    ...  ...              ...
# 38885                        NaN      +  ...  ENST00000803197
# 38886                        NaN      +  ...  ENST00000789733
# 38887                        NaN      -  ...  ENST00000850219
# 38888                        NaN      -  ...  ENST00000761024
# 38889                        NaN      -  ...  ENST00000670243
#
#         Gene stable ID        Gene name       Gene type   gene_category  \
# 0      ENSG00000162599             NFIA  protein_coding  protein_coding
# 1      ENSG00000228606         DCAF8-DT          lncRNA          lncRNA
# 2      ENSG00000133019            CHRM3  protein_coding  protein_coding
# 3      ENSG00000179546            HTR1D  protein_coding  protein_coding
# 4      ENSG00000300424  ENSG00000300424          lncRNA          lncRNA
# ...                ...              ...             ...             ...
# 38885  ENSG00000231535        LINC00278          lncRNA          lncRNA
# 38886  ENSG00000291033           TXLNGY          lncRNA          lncRNA
# 38887  ENSG00000176728           TTTY14          lncRNA          lncRNA
# 38888  ENSG00000291031           BCORP1          lncRNA          lncRNA
# 38889  ENSG00000176728           TTTY14          lncRNA          lncRNA
#
#       log2_tx_exp Relative TSS usage                           peak_name  \
# 0       -2.488310           0.044346    chr1:61077221-61077380_Peak_3111
# 1       -1.480300           1.000000  chr1:160261726-160261763_Peak_5604
# 2       -1.093061           0.454561  chr1:239386576-239386587_Peak_7900
# 3       -3.951339           1.000000    chr1:23217498-23217499_Peak_1212
# 4       -0.698603           1.000000  chr1:233327323-233327461_Peak_7654
# ...           ...                ...                                 ...
# 38885   -3.564880           1.000000     chrY:3002898-3002997_Peak_80710
# 38886   -2.102465           0.730209   chrY:19567328-19567382_Peak_80767
# 38887   -5.536436           0.484843   chrY:19075997-19076094_Peak_80763
# 38888   -4.122080           1.000000   chrY:19567006-19567035_Peak_80766
# 38889   -1.905551           0.484843   chrY:19075997-19076094_Peak_80763
#
#         peak_type       og_gene_id
# 0      Permissive  ENSG00000162599
# 1      Permissive  ENSG00000228606
# 2          Robust  ENSG00000133019
# 3      Permissive  ENSG00000179546
# 4      Permissive       FTMG005195
# ...           ...              ...
# 38885  Permissive  ENSG00000231535
# 38886      Robust  ENSG00000131002
# 38887  Permissive  ENSG00000176728
# 38888      Robust       FTMG057573
# 38889  Permissive  ENSG00000176728
#
# [3411 rows x 22 columns]

# %% [markdown]
# ## Filter for de novo lncRNA (for differential expression analysis)

# %%
lncRNA = combined_df[(combined_df["gene_category"] == "lncRNA")]
lncRNA["de_novo_tx"] = lncRNA["summarized_category"] == "Unannotated transcripts without any annotated exons"
lncRNA["de_novo_gene"] = lncRNA.groupby("Gene stable ID")["de_novo_tx"].transform("all")
# Out:
# /tmp/15604285/ipykernel_3370150/414197163.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lncRNA["de_novo_tx"] = lncRNA["summarized_category"] == "Unannotated transcripts without any annotated exons"
# /tmp/15604285/ipykernel_3370150/414197163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lncRNA["de_novo_gene"] = lncRNA.groupby("Gene stable ID")["de_novo_tx"].transform("all")

# %%
lncRNA = lncRNA.drop(columns=["exons", "matched_to", "unannotated_exons", "best_match_ref_id", "largest_overlap_gencode_id",
                              "Gene type", "Relative TSS usage", "peak_name", "peak_type"])

# %%
lncRNA.head()
# Out:
#          transcript_id   chr     matched_ref_id  \
# 1    ENCT00000013056.1  chr1  ENST00000756371.1
# 4    ENCT00000039204.1  chr1  ENST00000771587.1
# 6    ENCT00000039586.1  chr1  ENST00000649127.1
# 151  ENST00000295012.5  chr1  ENST00000295012.5
# 408  ENST00000356684.3  chr1  ENST00000356684.9
#
#                           category Strand            summarized_category  \
# 1    GENCODE-annotated transcripts      +  GENCODE-annotated transcripts
# 4    GENCODE-annotated transcripts      -  GENCODE-annotated transcripts
# 6    GENCODE-annotated transcripts      -  GENCODE-annotated transcripts
# 151  GENCODE-annotated transcripts      -  GENCODE-annotated transcripts
# 408  GENCODE-annotated transcripts      -  GENCODE-annotated transcripts
#
#                 ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 1    ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 4    ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
# 6    ENST00000649127.1  ENST00000649127  ENSG00000215808        LINC01139
# 151  ENST00000295012.5  ENST00000295012  ENSG00000162913        OBSCN-AS1
# 408  ENST00000356684.9  ENST00000356684  ENSG00000198468        FLVCR1-DT
#
#     gene_category  log2_tx_exp       og_gene_id  de_novo_tx  de_novo_gene
# 1          lncRNA    -1.480300  ENSG00000228606       False         False
# 4          lncRNA    -0.698603       FTMG005195       False         False
# 6          lncRNA    -5.028075  ENSG00000215808       False         False
# 151        lncRNA    -7.066893  ENSG00000162913       False         False
# 408        lncRNA    -1.751037  ENSG00000198468       False         False

# %%
lncRNA["Gene stable ID"].nunique()
# Out:
# 4823

# %%
lncRNA["Gene name"].isna().sum()
# Out:
# np.int64(0)

# %%
#lncRNA.to_csv('lncrna.tsv', sep='\t', index=False)

# %%
lncRNA.groupby("Gene stable ID")["de_novo_gene"].first().value_counts()
# Out:
# de_novo_gene
# False    3681
# True     1142
# Name: count, dtype: int64

# %% [markdown]
# ## Compare gene assignment now vs in HIT_hg38

# %%
combined_df[combined_df["Gene stable ID"] != combined_df["og_gene_id"]]
# Out:
#             transcript_id   chr  \
# 4       ENCT00000039204.1  chr1
# 183     ENST00000309092.7  chr1
# 202     ENST00000314835.5  chr1
# 240     ENST00000323397.4  chr1
# 259     ENST00000330165.8  chr1
# ...                   ...   ...
# 376329       STRT02292412  chrY
# 376330       STRT02292484  chrY
# 376331       STRT02293232  chrY
# 376333       STRT02294005  chrY
# 376334       STRT02294201  chrY
#
#                                                     exons  \
# 4        [(233319835, 233321155), (233327229, 233327357)]
# 183     [(150293861, 150293898), (150294335, 150294449...
# 202     [(155745829, 155745912), (155746005, 155746140...
# 240     [(145959442, 145961879), (145962421, 145962968...
# 259     [(145921556, 145925927), (145926041, 145926177...
# ...                                                   ...
# 376329  [(12406182, 12406500), (12406796, 12406937), (...
# 376330  [(19567329, 19567570), (19587210, 19587507), (...
# 376331  [(11167047, 11167217), (11212744, 11212802), (...
# 376333  [(19567414, 19567951), (19587210, 19587507), (...
# 376334  [(19567405, 19567482), (19576705, 19576822), (...
#
#                                                matched_to  \
# 4        [(233319834, 233321155), (233327229, 233327455)]
# 183     [(150293861, 150293898), (150294335, 150294449...
# 202     [(155745829, 155745912), (155746005, 155746140...
# 240     [(145959441, 145961879), (145962421, 145962968...
# 259     [(145921556, 145925927), (145926041, 145926177...
# ...                                                   ...
# 376329                                                NaN
# 376330                                                NaN
# 376331                                                NaN
# 376333                                                NaN
# 376334                                                NaN
#
#                                            matched_ref_id  \
# 4                                       ENST00000771587.1
# 183                                     ENST00000614145.5
# 202                                     ENST00000314835.5
# 240                                     ENST00000606888.3
# 259                                     ENST00000583313.7
# ...                                                   ...
# 376329  [ENST00000357871.6, ENST00000689264.2, ENST000...
# 376330  [ENST00000789723.1, ENST00000789733.1, ENST000...
# 376331  [ENST00000796802.1, ENST00000796805.1, ENST000...
# 376333  [ENST00000789733.1, ENST00000789728.1, ENST000...
# 376334  [ENST00000789723.1, ENST00000789733.1, ENST000...
#
#                                                  category unannotated_exons  \
# 4                           GENCODE-annotated transcripts               NaN
# 183                         GENCODE-annotated transcripts               NaN
# 202                         GENCODE-annotated transcripts               NaN
# 240                         GENCODE-annotated transcripts               NaN
# 259                         GENCODE-annotated transcripts               NaN
# ...                                                   ...               ...
# 376329  Unannotated transcripts composed entirely of a...               NaN
# 376330  Unannotated transcripts composed entirely of a...               NaN
# 376331  Unannotated transcripts composed entirely of a...               NaN
# 376333  Unannotated transcripts composed entirely of a...               NaN
# 376334  Unannotated transcripts composed entirely of a...               NaN
#
#         best_match_ref_id largest_overlap_gencode_id Strand  ...  \
# 4                     NaN                        NaN      -  ...
# 183                   NaN                        NaN      +  ...
# 202                   NaN                        NaN      +  ...
# 240                   NaN                        NaN      -  ...
# 259                   NaN                        NaN      -  ...
# ...                   ...                        ...    ...  ...
# 376329  ENST00000737339.1                        NaN      -  ...
# 376330  ENST00000589075.6                        NaN      +  ...
# 376331  ENST00000796810.1                        NaN      -  ...
# 376333  ENST00000693214.2                        NaN      +  ...
# 376334  ENST00000789732.1                        NaN      +  ...
#
#         stripped_ref_id   Gene stable ID        Gene name  \
# 4       ENST00000771587  ENSG00000300424  ENSG00000300424
# 183     ENST00000614145  ENSG00000266472           MRPS21
# 202     ENST00000314835  ENSG00000203761           MSTO2P
# 240     ENST00000606888  ENSG00000272031         ANKRD34A
# 259     ENST00000583313  ENSG00000265241            RBM8A
# ...                 ...              ...              ...
# 376329  ENST00000737339  ENSG00000291034  ENSG00000291034
# 376330  ENST00000589075  ENSG00000291033           TXLNGY
# 376331  ENST00000796810  ENSG00000291032  ENSG00000291032
# 376333  ENST00000693214  ENSG00000291033           TXLNGY
# 376334  ENST00000789732  ENSG00000291033           TXLNGY
#
#                                  Gene type    gene_category log2_tx_exp  \
# 4                                   lncRNA           lncRNA   -0.698603
# 183                         protein_coding   protein_coding    2.847926
# 202     transcribed_unprocessed_pseudogene  other_noncoding   -2.947815
# 240                         protein_coding   protein_coding   -4.950279
# 259                         protein_coding   protein_coding    2.684561
# ...                                    ...              ...         ...
# 376329                              lncRNA           lncRNA   -4.580062
# 376330                              lncRNA           lncRNA   -4.409059
# 376331                              lncRNA           lncRNA   -4.380444
# 376333                              lncRNA           lncRNA   -5.310583
# 376334                              lncRNA           lncRNA   -2.787476
#
#        Relative TSS usage                           peak_name   peak_type  \
# 4                1.000000  chr1:233327323-233327461_Peak_7654  Permissive
# 183              1.000000  chr1:150293854-150293881_Peak_4722      Robust
# 202              0.122135  chr1:155745816-155745886_Peak_5359  Permissive
# 240              0.278635  chr1:145964595-145964603_Peak_4522  Permissive
# 259              0.874929  chr1:145927362-145927459_Peak_4533      Robust
# ...                   ...                                 ...         ...
# 376329           1.000000   chrY:12421569-12421599_Peak_80720      Robust
# 376330           0.730209   chrY:19567328-19567382_Peak_80767      Robust
# 376331           1.000000   chrY:11214982-11215027_Peak_80719  Permissive
# 376333           0.730209   chrY:19567328-19567382_Peak_80767      Robust
# 376334           0.730209   chrY:19567328-19567382_Peak_80767      Robust
#
#              og_gene_id
# 4            FTMG005195
# 183     ENSG00000187145
# 202     ENSG00000125459
# 240     ENSG00000181039
# 259     ENSG00000131795
# ...                 ...
# 376329  ENSG00000206159
# 376330  ENSG00000131002
# 376331       FTMG057506
# 376333  ENSG00000131002
# 376334  ENSG00000131002
#
# [33475 rows x 22 columns]

# %% [markdown]
# ## Renaming transcript IDs

# %%
pd.set_option('display.max_columns', None)
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category  log2_tx_exp  Relative TSS usage  \
# 0  protein_coding  protein_coding    -2.488310            0.044346
# 1          lncRNA          lncRNA    -1.480300            1.000000
# 2  protein_coding  protein_coding    -1.093061            0.454561
# 3  protein_coding  protein_coding    -3.951339            1.000000
# 4          lncRNA          lncRNA    -0.698603            1.000000
#
#                             peak_name   peak_type       og_gene_id
# 0    chr1:61077221-61077380_Peak_3111  Permissive  ENSG00000162599
# 1  chr1:160261726-160261763_Peak_5604  Permissive  ENSG00000228606
# 2  chr1:239386576-239386587_Peak_7900      Robust  ENSG00000133019
# 3    chr1:23217498-23217499_Peak_1212  Permissive  ENSG00000179546
# 4  chr1:233327323-233327461_Peak_7654  Permissive       FTMG005195

# %%
HIT_hg38 = pd.read_csv( 'HIT_hg38.tsv', sep='\t')
HIT_hg38.head()
# Out:
# /tmp/15848976/ipykernel_1970771/1486489535.py:1: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   HIT_hg38 = pd.read_csv( 'HIT_hg38.tsv', sep='\t')
#   seqname  source feature  start    end score strand frame          gene_id  \
# 0    chr1  PacBio    exon  14360  14829     .      -     .  ENSG00000227232
# 1    chr1  PacBio    exon  14970  15038     .      -     .  ENSG00000227232
# 2    chr1  PacBio    exon  15796  15947     .      -     .  ENSG00000227232
# 3    chr1  PacBio    exon  16607  16765     .      -     .  ENSG00000227232
# 4    chr1  PacBio    exon  16854  17055     .      -     .  ENSG00000227232
#
#   transcript_id gene_name   gene_type  \
# 0   PBT00037199    WASH7P  pseudogene
# 1   PBT00037199    WASH7P  pseudogene
# 2   PBT00037199    WASH7P  pseudogene
# 3   PBT00037199    WASH7P  pseudogene
# 4   PBT00037199    WASH7P  pseudogene
#
#                            transcript_classification protein_id_orf_summary  \
# 0  Novel Protein coding not overlapping annotated...                    NaN
# 1  Novel Protein coding not overlapping annotated...                    NaN
# 2  Novel Protein coding not overlapping annotated...                    NaN
# 3  Novel Protein coding not overlapping annotated...                    NaN
# 4  Novel Protein coding not overlapping annotated...                    NaN
#
#   Intron Exon 5prime 3prime closest
# 0    NaN  NaN    NaN    NaN     NaN
# 1    NaN  NaN    NaN    NaN     NaN
# 2    NaN  NaN    NaN    NaN     NaN
# 3    NaN  NaN    NaN    NaN     NaN
# 4    NaN  NaN    NaN    NaN     NaN

# %%
tx_source_map = HIT_hg38[['source', 'transcript_id']].drop_duplicates()
combined_df = combined_df.merge(tx_source_map, on='transcript_id', how='left')
combined_df.head()
# Out:
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand            summarized_category  \
# 0                        NaN      +  GENCODE-annotated transcripts
# 1                        NaN      +  GENCODE-annotated transcripts
# 2                        NaN      +  GENCODE-annotated transcripts
# 3                        NaN      -  GENCODE-annotated transcripts
# 4                        NaN      -  GENCODE-annotated transcripts
#
#               ref_id  stripped_ref_id   Gene stable ID        Gene name  \
# 0  ENST00000699992.1  ENST00000699992  ENSG00000162599             NFIA
# 1  ENST00000756371.1  ENST00000756371  ENSG00000228606         DCAF8-DT
# 2  ENST00000676153.1  ENST00000676153  ENSG00000133019            CHRM3
# 3  ENST00000374619.2  ENST00000374619  ENSG00000179546            HTR1D
# 4  ENST00000771587.1  ENST00000771587  ENSG00000300424  ENSG00000300424
#
#         Gene type   gene_category  log2_tx_exp  Relative TSS usage  \
# 0  protein_coding  protein_coding    -2.488310            0.044346
# 1          lncRNA          lncRNA    -1.480300            1.000000
# 2  protein_coding  protein_coding    -1.093061            0.454561
# 3  protein_coding  protein_coding    -3.951339            1.000000
# 4          lncRNA          lncRNA    -0.698603            1.000000
#
#                             peak_name   peak_type       og_gene_id      source
# 0    chr1:61077221-61077380_Peak_3111  Permissive  ENSG00000162599  FANTOM_cat
# 1  chr1:160261726-160261763_Peak_5604  Permissive  ENSG00000228606  FANTOM_cat
# 2  chr1:239386576-239386587_Peak_7900      Robust  ENSG00000133019  FANTOM_cat
# 3    chr1:23217498-23217499_Peak_1212  Permissive  ENSG00000179546  FANTOM_cat
# 4  chr1:233327323-233327461_Peak_7654  Permissive       FTMG005195  FANTOM_cat

# %%
prefix_map = {
    'FANTOM_cat': 'FTMT',
    'PacBio': 'PBT',
    'StringTie': 'STRT',
    'ENSEMBL': 'NCBIT',
}

combined_df["new_tx_id"] = None

# assign GENCODE-annotated transcripts
mask = combined_df["category"] == "GENCODE-annotated transcripts"
combined_df.loc[mask, "new_tx_id"] = combined_df.loc[mask, "matched_ref_id"]

# generate IDs based on source
remaining = combined_df.loc[~mask].copy()

for source_name, prefix in prefix_map.items():
    source_mask = remaining["source"] == source_name
    idx = remaining[source_mask].index
    for i, row_idx in enumerate(idx, start=1):
        combined_df.at[row_idx, "new_tx_id"] = f"{prefix}{str(i).zfill(7)}"

# %%
combined_df[combined_df["new_tx_id"].str.startswith("NCBIT")]
# Out:
#             transcript_id   chr  \
# 38927   ENST00000235329.5  chr1
# 38928   ENST00000236914.3  chr1
# 38929   ENST00000239457.5  chr1
# 38930   ENST00000253251.8  chr1
# 38931   ENST00000261443.5  chr1
# ...                   ...   ...
# 375496  ENST00000543642.1  chrX
# 375497  ENST00000545566.1  chrX
# 375498  ENST00000545618.1  chrX
# 375499  ENST00000602791.1  chrX
# 376306  ENST00000538878.1  chrY
#
#                                                     exons  \
# 38927   [(11980197, 11980484), (11981970, 11982114), (...
# 38928   [(200027634, 200027911), (200043774, 200043892...
# 38929   [(173824659, 173825356), (173826687, 173826786...
# 38930   [(10032959, 10033694), (10072028, 10072214), (...
# 38931   [(114716920, 114718216), (114718613, 114718745...
# ...                                                   ...
# 375496  [(37349330, 37349469), (37406209, 37406259), (...
# 375497  [(13653123, 13653188), (13655289, 13655373), (...
# 375498  [(64916370, 64917896), (64919042, 64919204), (...
# 375499       [(77910631, 77910835), (77962623, 77964890)]
# 376306  [(13323047, 13323368), (13323555, 13323760), (...
#
#                                                matched_to  \
# 38927   [(11980209, 11980484), (11981970, 11982114), (...
# 38928   [(200027710, 200027911), (200039658, 200039795...
# 38929   [(173824673, 173825356), (173826687, 173826786...
# 38930   [(10032958, 10033694), (10072028, 10072214), (...
# 38931   [(114716913, 114718216), (114718613, 114718745...
# ...                                                   ...
# 375496                                                NaN
# 375497                                                NaN
# 375498                                                NaN
# 375499                                                NaN
# 376306                                                NaN
#
#                                            matched_ref_id  \
# 38927                                   ENST00000675817.1
# 38928                                   ENST00000367362.8
# 38929                                   ENST00000649689.2
# 38930                                  ENST00000343090.11
# 38931                                  ENST00000339438.10
# ...                                                   ...
# 375496  ['ENST00000850645.1', 'ENST00000465127.1', 'EN...
# 375497  ['ENST00000490617.1', 'ENST00000544987.3', 'EN...
# 375498  ['ENST00000337990.2', 'ENST00000492653.6', 'EN...
# 375499  ['ENST00000686515.1', 'ENST00000685264.1', 'EN...
# 376306  ['ENST00000382896.9', 'ENST00000624098.3', 'EN...
#
#                                                  category unannotated_exons  \
# 38927   Unannotated transcripts fully contained within...               NaN
# 38928   Unannotated transcripts fully contained within...               NaN
# 38929   Unannotated transcripts fully contained within...               NaN
# 38930   Unannotated transcripts fully contained within...               NaN
# 38931   Unannotated transcripts fully contained within...               NaN
# ...                                                   ...               ...
# 375496  Unannotated transcripts composed entirely of a...               NaN
# 375497  Unannotated transcripts composed entirely of a...               NaN
# 375498  Unannotated transcripts composed entirely of a...               NaN
# 375499  Unannotated transcripts composed entirely of a...               NaN
# 376306  Unannotated transcripts composed entirely of a...               NaN
#
#         best_match_ref_id largest_overlap_gencode_id Strand  \
# 38927                 NaN                        NaN      +
# 38928                 NaN                        NaN      +
# 38929                 NaN                        NaN      +
# 38930                 NaN                        NaN      +
# 38931                 NaN                        NaN      -
# ...                   ...                        ...    ...
# 375496  ENST00000378628.9                        NaN      +
# 375497  ENST00000696128.1                        NaN      +
# 375498  ENST00000703136.1                        NaN      -
# 375499  ENST00000602791.2                        NaN      +
# 376306  ENST00000329134.9                        NaN      -
#
#                                      summarized_category              ref_id  \
# 38927   Unannotated transcripts with all exons annotated   ENST00000675817.1
# 38928   Unannotated transcripts with all exons annotated   ENST00000367362.8
# 38929   Unannotated transcripts with all exons annotated   ENST00000649689.2
# 38930   Unannotated transcripts with all exons annotated  ENST00000343090.11
# 38931   Unannotated transcripts with all exons annotated  ENST00000339438.10
# ...                                                  ...                 ...
# 375496  Unannotated transcripts with all exons annotated   ENST00000378628.9
# 375497  Unannotated transcripts with all exons annotated   ENST00000696128.1
# 375498  Unannotated transcripts with all exons annotated   ENST00000703136.1
# 375499  Unannotated transcripts with all exons annotated   ENST00000602791.2
# 376306  Unannotated transcripts with all exons annotated   ENST00000329134.9
#
#         stripped_ref_id   Gene stable ID        Gene name       Gene type  \
# 38927   ENST00000675817  ENSG00000116688             MFN2  protein_coding
# 38928   ENST00000367362  ENSG00000116833            NR5A2  protein_coding
# 38929   ENST00000649689  ENSG00000117593            DARS2  protein_coding
# 38930   ENST00000343090  ENSG00000130939            UBE4B  protein_coding
# 38931   ENST00000339438  ENSG00000009307            CSDE1  protein_coding
# ...                 ...              ...              ...             ...
# 375496  ENST00000378628  ENSG00000130962            PRRG1  protein_coding
# 375497  ENST00000696128  ENSG00000176896           TCEANC  protein_coding
# 375498  ENST00000703136  ENSG00000126970            ZC4H2  protein_coding
# 375499  ENST00000602791  ENSG00000293258  ENSG00000293258          lncRNA
# 376306  ENST00000329134  ENSG00000183878              UTY  protein_coding
#
#          gene_category  log2_tx_exp  Relative TSS usage  \
# 38927   protein_coding     1.842377            0.849730
# 38928   protein_coding     2.091592            0.573290
# 38929   protein_coding    -1.795171            0.930435
# 38930   protein_coding     2.490205            0.997981
# 38931   protein_coding     1.739073            0.712407
# ...                ...          ...                 ...
# 375496  protein_coding    -0.986525            1.000000
# 375497  protein_coding    -3.353878            1.000000
# 375498  protein_coding    -3.809740            0.531402
# 375499          lncRNA    -1.288001            1.000000
# 376306  protein_coding    -5.110419            0.071192
#
#                                  peak_name   peak_type       og_gene_id  \
# 38927      chr1:11980204-11980451_Peak_666      Robust  ENSG00000116688
# 38928   chr1:200027537-200027864_Peak_6480      Robust  ENSG00000116833
# 38929   chr1:173824474-173824687_Peak_6035      Robust  ENSG00000117593
# 38930      chr1:10032954-10033166_Peak_545      Robust  ENSG00000130939
# 38931   chr1:114757960-114757994_Peak_4265      Robust  ENSG00000009307
# ...                                    ...         ...              ...
# 375496   chrX:37349326-37349369_Peak_78599      Robust  ENSG00000130962
# 375497   chrX:13653136-13653193_Peak_78335      Robust  ENSG00000176896
# 375498   chrX:64976443-64976455_Peak_79235      Robust  ENSG00000126970
# 375499   chrX:77910639-77910745_Peak_79619      Robust  ENSG00000248503
# 376306   chrY:13479608-13479629_Peak_80736  Permissive  ENSG00000183878
#
#          source     new_tx_id
# 38927   ENSEMBL  NCBIT0000001
# 38928   ENSEMBL  NCBIT0000002
# 38929   ENSEMBL  NCBIT0000003
# 38930   ENSEMBL  NCBIT0000004
# 38931   ENSEMBL  NCBIT0000005
# ...         ...           ...
# 375496  ENSEMBL  NCBIT0014842
# 375497  ENSEMBL  NCBIT0014843
# 375498  ENSEMBL  NCBIT0014844
# 375499  ENSEMBL  NCBIT0014845
# 376306  ENSEMBL  NCBIT0014846
#
# [14846 rows x 24 columns]

# %% [markdown]
# ## Random filtering

# %%
combined_df = pd.read_csv( 'jessies_gffcompare.tsv', sep='\t')
combined_df.head()
# Out:
# /tmp/15940684/ipykernel_3610127/4294323767.py:1: DtypeWarning: Columns (3,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_df = pd.read_csv( 'jessies_gffcompare.tsv', sep='\t')
#        transcript_id   chr                                              exons  \
# 0  ENCT00000006334.1  chr1       [(61077274, 61077628), (61077916, 61079203)]
# 1  ENCT00000013056.1  chr1   [(160261734, 160261922), (160281430, 160281892)]
# 2  ENCT00000019620.1  chr1  [(239386568, 239387227), (239492709, 239492807...
# 3  ENCT00000022754.1  chr1       [(23191893, 23195001), (23217291, 23217499)]
# 4  ENCT00000039204.1  chr1   [(233319835, 233321155), (233327229, 233327357)]
#
#                                           matched_to     matched_ref_id  \
# 0       [(61077326, 61077628), (61077916, 61079231)]  ENST00000699992.1
# 1   [(160261682, 160261922), (160281430, 160281935)]  ENST00000756371.1
# 2  [(239386568, 239387227), (239492709, 239492807...  ENST00000676153.1
# 3       [(23191895, 23195001), (23217291, 23217502)]  ENST00000374619.2
# 4   [(233319834, 233321155), (233327229, 233327455)]  ENST00000771587.1
#
#                         category unannotated_exons best_match_ref_id  \
# 0  GENCODE-annotated transcripts               NaN               NaN
# 1  GENCODE-annotated transcripts               NaN               NaN
# 2  GENCODE-annotated transcripts               NaN               NaN
# 3  GENCODE-annotated transcripts               NaN               NaN
# 4  GENCODE-annotated transcripts               NaN               NaN
#
#   largest_overlap_gencode_id Strand  ...  stripped_ref_id   Gene stable ID  \
# 0                        NaN      +  ...  ENST00000699992  ENSG00000162599
# 1                        NaN      +  ...  ENST00000756371  ENSG00000228606
# 2                        NaN      +  ...  ENST00000676153  ENSG00000133019
# 3                        NaN      -  ...  ENST00000374619  ENSG00000179546
# 4                        NaN      -  ...  ENST00000771587  ENSG00000300424
#
#          Gene name       Gene type   gene_category log2_tx_exp  \
# 0             NFIA  protein_coding  protein_coding   -2.488310
# 1         DCAF8-DT          lncRNA          lncRNA   -1.480300
# 2            CHRM3  protein_coding  protein_coding   -1.093061
# 3            HTR1D  protein_coding  protein_coding   -3.951339
# 4  ENSG00000300424          lncRNA          lncRNA   -0.698603
#
#   Relative TSS usage                           peak_name   peak_type  \
# 0           0.044346    chr1:61077221-61077380_Peak_3111  Permissive
# 1           1.000000  chr1:160261726-160261763_Peak_5604  Permissive
# 2           0.454561  chr1:239386576-239386587_Peak_7900      Robust
# 3           1.000000    chr1:23217498-23217499_Peak_1212  Permissive
# 4           1.000000  chr1:233327323-233327461_Peak_7654  Permissive
#
#         og_gene_id
# 0  ENSG00000162599
# 1  ENSG00000228606
# 2  ENSG00000133019
# 3  ENSG00000179546
# 4       FTMG005195
#
# [5 rows x 22 columns]

# %%
combined_df[combined_df["peak_name"] == "chr9:76906093-76906284_Peak_76147"]
# Out:
#             transcript_id   chr  \
# 37057   ENST00000376713.3  chr9
# 37058   ENST00000376718.3  chr9
# 63701        STRT02184338  chr9
# 124338       STRT02135347  chr9
# 124395       STRT02138947  chr9
# 124523       STRT02143313  chr9
# 124803       STRT02152013  chr9
# 124891       STRT02155452  chr9
# 124926       STRT02157377  chr9
# 125401       STRT02171755  chr9
# 125586       STRT02177848  chr9
# 125661       STRT02180042  chr9
# 125734       STRT02183942  chr9
# 125779       STRT02185383  chr9
# 125817       STRT02186418  chr9
# 126273       STRT02207040  chr9
# 313671  FTMT23300029975.1  chr9
# 315132        PBT00426069  chr9
# 315133        PBT00426071  chr9
# 316061       STRT02128601  chr9
# 316625       STRT02138946  chr9
# 317865       STRT02162417  chr9
# 317929       STRT02163302  chr9
# 318057       STRT02165955  chr9
# 318620       STRT02178142  chr9
# 318777       STRT02179725  chr9
# 319141       STRT02184337  chr9
# 319199       STRT02184999  chr9
# 319261       STRT02185739  chr9
# 319362       STRT02186750  chr9
# 319740       STRT02190622  chr9
# 320224       STRT02194971  chr9
# 320779       STRT02206296  chr9
# 320869       STRT02207483  chr9
# 321069       STRT02209417  chr9
# 321098       STRT02209624  chr9
# 321239       STRT02211017  chr9
# 321532       STRT02214009  chr9
# 321533       STRT02214010  chr9
# 321534       STRT02214012  chr9
# 341327        PBT00426074  chr9
# 374377  ENST00000428286.1  chr9
# 374406  ENST00000492157.1  chr9
# 374428  FTMT23300029397.1  chr9
# 374956       STRT02137332  chr9
# 375223       STRT02179724  chr9
# 375292       STRT02192005  chr9
# 375303       STRT02193969  chr9
# 375337       STRT02203853  chr9
#
#                                                     exons  \
# 37057   [(76788344, 76788534), (76823632, 76823726), (...
# 37058   [(76611377, 76614600), (76619340, 76619387), (...
# 63701   [(76611481, 76614600), (76629192, 76629290), (...
# 124338  [(76772808, 76773009), (76823632, 76823726), (...
# 124395  [(76813818, 76823726), (76826580, 76826732), (...
# 124523  [(76766664, 76766741), (76823632, 76823726), (...
# 124803  [(76769497, 76769690), (76823632, 76823726), (...
# 124891  [(76769728, 76769779), (76823632, 76823726), (...
# 124926  [(76805850, 76805901), (76823632, 76823726), (...
# 125401  [(76879152, 76879205), (76886304, 76886395), (...
# 125586  [(76769742, 76769807), (76823632, 76823726), (...
# 125661  [(76611377, 76614600), (76619340, 76625058), (...
# 125734  [(76612691, 76614600), (76619340, 76619387), (...
# 125779  [(76608229, 76614600), (76629192, 76629290), (...
# 125817  [(76611376, 76614600), (76615191, 76615237), (...
# 126273  [(76610162, 76614600), (76629192, 76629290), (...
# 313671  [(76703315, 76703425), (76703883, 76704099), (...
# 315132  [(76704083, 76704099), (76704761, 76711358), (...
# 315133  [(76823267, 76826732), (76846515, 76846678), (...
# 316061  [(76611481, 76614600), (76629192, 76629290), (...
# 316625  [(76617054, 76625058), (76629192, 76629290), (...
# 317865  [(76608284, 76614600), (76629192, 76629290), (...
# 317929  [(76614289, 76614600), (76615097, 76615237), (...
# 318057  [(76614008, 76614600), (76619340, 76619387), (...
# 318620  [(76614008, 76619387), (76629192, 76629290), (...
# 318777  [(76614008, 76625058), (76629192, 76629290), (...
# 319141  [(76608284, 76614600), (76619340, 76619387), (...
# 319199  [(76610563, 76615237), (76629192, 76629290), (...
# 319261  [(76623404, 76624490), (76629192, 76629290), (...
# 319362  [(76611376, 76614600), (76629192, 76629290), (...
# 319740  [(76611376, 76614600), (76629192, 76629290), (...
# 320224  [(76807103, 76823726), (76826580, 76826732), (...
# 320779  [(76637975, 76638288), (76641972, 76641980), (...
# 320869  [(76636987, 76637549), (76638186, 76638288), (...
# 321069  [(76611377, 76629290), (76636471, 76636557), (...
# 321098  [(76614450, 76625058), (76629192, 76629290), (...
# 321239  [(76611481, 76629290), (76636471, 76636557), (...
# 321532  [(76609345, 76614600), (76625023, 76625058), (...
# 321533  [(76611481, 76614600), (76629192, 76629290), (...
# 321534  [(76641405, 76641980), (76644739, 76644909), (...
# 341327                             [(76901754, 76906107)]
# 374377  [(76611377, 76614600), (76619340, 76619387), (...
# 374406  [(76823267, 76823726), (76826580, 76826732), (...
# 374428  [(76644469, 76644912), (76652483, 76652683), (...
# 374956  [(76611376, 76614600), (76619340, 76619387), (...
# 375223  [(76611376, 76614600), (76619340, 76619387), (...
# 375292  [(76611481, 76614600), (76625023, 76625058), (...
# 375303  [(76614289, 76614600), (76624452, 76624490), (...
# 375337  [(76614450, 76614600), (76619340, 76619387), (...
#
#                                                matched_to  \
# 37057   [(76788344, 76788534), (76823632, 76823726), (...
# 37058   [(76611376, 76614600), (76619340, 76619387), (...
# 63701   [(76611481, 76614600), (76629192, 76629290), (...
# 124338                                                NaN
# 124395                                                NaN
# 124523                                                NaN
# 124803                                                NaN
# 124891                                                NaN
# 124926                                                NaN
# 125401                                                NaN
# 125586                                                NaN
# 125661                                                NaN
# 125734                                                NaN
# 125779                                                NaN
# 125817                                                NaN
# 126273                                                NaN
# 313671                                                NaN
# 315132                                                NaN
# 315133                                                NaN
# 316061                                                NaN
# 316625                                                NaN
# 317865                                                NaN
# 317929                                                NaN
# 318057                                                NaN
# 318620                                                NaN
# 318777                                                NaN
# 319141                                                NaN
# 319199                                                NaN
# 319261                                                NaN
# 319362                                                NaN
# 319740                                                NaN
# 320224                                                NaN
# 320779                                                NaN
# 320869                                                NaN
# 321069                                                NaN
# 321098                                                NaN
# 321239                                                NaN
# 321532                                                NaN
# 321533                                                NaN
# 321534                                                NaN
# 341327                                                NaN
# 374377                                                NaN
# 374406                                                NaN
# 374428                                                NaN
# 374956                                                NaN
# 375223                                                NaN
# 375292                                                NaN
# 375303                                                NaN
# 375337                                                NaN
#
#                                            matched_ref_id  \
# 37057                                   ENST00000376713.3
# 37058                                   ENST00000376718.8
# 63701                                   ENST00000443509.6
# 124338  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 124395  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 124523  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 124803  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 124891  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 124926  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 125401  ['ENST00000376718.8', 'ENST00000443509.6', 'EN...
# 125586  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 125661  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 125734  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 125779  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 125817  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 126273  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 313671  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 315132  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 315133  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 316061  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 316625  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 317865  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 317929  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 318057  ['ENST00000466266.6', 'ENST00000428286.5', 'EN...
# 318620  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 318777  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 319141  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 319199  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 319261  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 319362  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 319740  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 320224  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 320779  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 320869  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321069  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321098  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321239  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321532  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321533  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 321534  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 341327                                                NaN
# 374377  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 374406  ['ENST00000443509.6', 'ENST00000428286.5', 'EN...
# 374428  ['ENST00000466266.6', 'ENST00000443509.6', 'EN...
# 374956  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 375223  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 375292  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 375303  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
# 375337  ['ENST00000424866.1', 'ENST00000443509.6', 'EN...
#
#                                                  category  \
# 37057                       GENCODE-annotated transcripts
# 37058                       GENCODE-annotated transcripts
# 63701   Unannotated transcripts fully contained within...
# 124338  Transcripts with annotated exons and non-overl...
# 124395  Transcripts with annotated exons and non-overl...
# 124523  Transcripts with annotated exons and non-overl...
# 124803  Transcripts with annotated exons and non-overl...
# 124891  Transcripts with annotated exons and non-overl...
# 124926  Transcripts with annotated exons and non-overl...
# 125401  Transcripts with annotated exons and non-overl...
# 125586  Transcripts with annotated exons and non-overl...
# 125661  Transcripts with annotated exons and non-overl...
# 125734  Transcripts with annotated exons and non-overl...
# 125779  Transcripts with annotated exons and non-overl...
# 125817  Transcripts with annotated exons and non-overl...
# 126273  Transcripts with annotated exons and non-overl...
# 313671  Transcripts with annotated exons and only over...
# 315132  Transcripts with annotated exons and only over...
# 315133  Transcripts with annotated exons and only over...
# 316061  Transcripts with annotated exons and only over...
# 316625  Transcripts with annotated exons and only over...
# 317865  Transcripts with annotated exons and only over...
# 317929  Transcripts with annotated exons and only over...
# 318057  Transcripts with annotated exons and only over...
# 318620  Transcripts with annotated exons and only over...
# 318777  Transcripts with annotated exons and only over...
# 319141  Transcripts with annotated exons and only over...
# 319199  Transcripts with annotated exons and only over...
# 319261  Transcripts with annotated exons and only over...
# 319362  Transcripts with annotated exons and only over...
# 319740  Transcripts with annotated exons and only over...
# 320224  Transcripts with annotated exons and only over...
# 320779  Transcripts with annotated exons and only over...
# 320869  Transcripts with annotated exons and only over...
# 321069  Transcripts with annotated exons and only over...
# 321098  Transcripts with annotated exons and only over...
# 321239  Transcripts with annotated exons and only over...
# 321532  Transcripts with annotated exons and only over...
# 321533  Transcripts with annotated exons and only over...
# 321534  Transcripts with annotated exons and only over...
# 341327  Fully unannotated transcripts with overlapping...
# 374377  Unannotated transcripts composed entirely of a...
# 374406  Unannotated transcripts composed entirely of a...
# 374428  Unannotated transcripts composed entirely of a...
# 374956  Unannotated transcripts composed entirely of a...
# 375223  Unannotated transcripts composed entirely of a...
# 375292  Unannotated transcripts composed entirely of a...
# 375303  Unannotated transcripts composed entirely of a...
# 375337  Unannotated transcripts composed entirely of a...
#
#                                         unannotated_exons  best_match_ref_id  \
# 37057                                                 NaN                NaN
# 37058                                                 NaN                NaN
# 63701                                                 NaN                NaN
# 124338                             [(76772808, 76773009)]  ENST00000376713.3
# 124395       [(76813818, 76823726), (76886304, 76886395)]  ENST00000492157.5
# 124523                             [(76766664, 76766741)]  ENST00000376713.3
# 124803                             [(76769497, 76769690)]  ENST00000376713.3
# 124891                             [(76769728, 76769779)]  ENST00000376713.3
# 124926                             [(76805850, 76805901)]  ENST00000376713.3
# 125401       [(76879152, 76879205), (76886304, 76886395)]  ENST00000492157.5
# 125586                             [(76769742, 76769807)]  ENST00000376713.3
# 125661       [(76619340, 76625058), (76886304, 76886395)]  ENST00000376718.8
# 125734       [(76612691, 76614600), (76886304, 76886395)]  ENST00000376718.8
# 125779       [(76608229, 76614600), (76886304, 76886395)]  ENST00000376718.8
# 125817                             [(76615191, 76615237)]  ENST00000376718.8
# 126273       [(76610162, 76614600), (76901028, 76901194)]  ENST00000376718.8
# 313671       [(76703315, 76703425), (76703883, 76704099)]  ENST00000428286.5
# 315132                             [(76704083, 76704099)]  ENST00000376718.8
# 315133                             [(76823267, 76826732)]  ENST00000492157.5
# 316061                             [(76710812, 76711358)]  ENST00000428286.5
# 316625                             [(76617054, 76625058)]  ENST00000376718.8
# 317865                             [(76608284, 76614600)]  ENST00000376718.8
# 317929                             [(76615097, 76615237)]  ENST00000428286.5
# 318057                             [(76710812, 76711358)]  ENST00000443509.6
# 318620                             [(76614008, 76619387)]  ENST00000428286.5
# 318777                             [(76614008, 76625058)]  ENST00000428286.5
# 319141                             [(76608284, 76614600)]  ENST00000376718.8
# 319199                             [(76610563, 76615237)]  ENST00000428286.5
# 319261                             [(76623404, 76624490)]  ENST00000443509.6
# 319362                             [(76904794, 76906135)]  ENST00000376718.8
# 319740                             [(76905564, 76906146)]  ENST00000376718.8
# 320224       [(76807103, 76823726), (76905564, 76906159)]  ENST00000492157.5
# 320779       [(76637975, 76638288), (76905928, 76906279)]  ENST00000443509.6
# 320869                             [(76636987, 76637549)]  ENST00000443509.6
# 321069                             [(76611377, 76629290)]  ENST00000376718.8
# 321098                             [(76614450, 76625058)]  ENST00000443509.6
# 321239                             [(76611481, 76629290)]  ENST00000376718.8
# 321532  [(76609345, 76614600), (76850463, 76850660), (...  ENST00000428286.5
# 321533                             [(76904603, 76906159)]  ENST00000428286.5
# 321534                             [(76641405, 76641980)]  ENST00000443509.6
# 341327                                                NaN                NaN
# 374377                                                NaN  ENST00000376718.8
# 374406                                                NaN  ENST00000492157.5
# 374428                                                NaN  ENST00000443509.6
# 374956                                                NaN  ENST00000376718.8
# 375223                                                NaN  ENST00000376718.8
# 375292                                                NaN  ENST00000376718.8
# 375303                                                NaN  ENST00000376718.8
# 375337                                                NaN  ENST00000376718.8
#
#        largest_overlap_gencode_id Strand  ...  stripped_ref_id  \
# 37057                         NaN      -  ...  ENST00000376713
# 37058                         NaN      -  ...  ENST00000376718
# 63701                         NaN      -  ...  ENST00000443509
# 124338                        NaN      -  ...  ENST00000376713
# 124395                        NaN      -  ...  ENST00000492157
# 124523                        NaN      -  ...  ENST00000376713
# 124803                        NaN      -  ...  ENST00000376713
# 124891                        NaN      -  ...  ENST00000376713
# 124926                        NaN      -  ...  ENST00000376713
# 125401                        NaN      -  ...  ENST00000492157
# 125586                        NaN      -  ...  ENST00000376713
# 125661                        NaN      -  ...  ENST00000376718
# 125734                        NaN      -  ...  ENST00000376718
# 125779                        NaN      -  ...  ENST00000376718
# 125817                        NaN      -  ...  ENST00000376718
# 126273                        NaN      -  ...  ENST00000376718
# 313671                        NaN      -  ...  ENST00000428286
# 315132                        NaN      -  ...  ENST00000376718
# 315133                        NaN      -  ...  ENST00000492157
# 316061                        NaN      -  ...  ENST00000428286
# 316625                        NaN      -  ...  ENST00000376718
# 317865                        NaN      -  ...  ENST00000376718
# 317929                        NaN      -  ...  ENST00000428286
# 318057                        NaN      -  ...  ENST00000443509
# 318620                        NaN      -  ...  ENST00000428286
# 318777                        NaN      -  ...  ENST00000428286
# 319141                        NaN      -  ...  ENST00000376718
# 319199                        NaN      -  ...  ENST00000428286
# 319261                        NaN      -  ...  ENST00000443509
# 319362                        NaN      -  ...  ENST00000376718
# 319740                        NaN      -  ...  ENST00000376718
# 320224                        NaN      -  ...  ENST00000492157
# 320779                        NaN      -  ...  ENST00000443509
# 320869                        NaN      -  ...  ENST00000443509
# 321069                        NaN      -  ...  ENST00000376718
# 321098                        NaN      -  ...  ENST00000443509
# 321239                        NaN      -  ...  ENST00000376718
# 321532                        NaN      -  ...  ENST00000428286
# 321533                        NaN      -  ...  ENST00000428286
# 321534                        NaN      -  ...  ENST00000443509
# 341327          ENST00000376718.8      -  ...  ENST00000376718
# 374377                        NaN      -  ...  ENST00000376718
# 374406                        NaN      -  ...  ENST00000492157
# 374428                        NaN      -  ...  ENST00000443509
# 374956                        NaN      -  ...  ENST00000376718
# 375223                        NaN      -  ...  ENST00000376718
# 375292                        NaN      -  ...  ENST00000376718
# 375303                        NaN      -  ...  ENST00000376718
# 375337                        NaN      -  ...  ENST00000376718
#
#          Gene stable ID Gene name       Gene type   gene_category log2_tx_exp  \
# 37057   ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.134750
# 37058   ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.327080
# 63701   ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.640130
# 124338  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.057171
# 124395  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.531564
# 124523  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -0.115937
# 124803  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.218237
# 124891  ENSG00000106772    PRUNE2  protein_coding  protein_coding    1.011718
# 124926  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -0.009579
# 125401  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.039257
# 125586  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.965125
# 125661  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.557737
# 125734  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.476723
# 125779  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.029883
# 125817  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.788915
# 126273  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.763213
# 313671  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.941794
# 315132  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.985825
# 315133  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.953326
# 316061  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.152101
# 316625  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -6.243171
# 317865  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.852232
# 317929  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.940882
# 318057  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.824510
# 318620  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.508305
# 318777  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.562825
# 319141  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.335787
# 319199  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -6.516623
# 319261  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.076207
# 319362  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -5.540692
# 319740  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.382159
# 320224  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.826013
# 320779  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.632349
# 320869  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.611705
# 321069  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.310590
# 321098  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -3.392899
# 321239  ENSG00000106772    PRUNE2  protein_coding  protein_coding    0.904675
# 321532  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.752865
# 321533  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -6.345595
# 321534  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.012234
# 341327  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.432112
# 374377  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -2.872918
# 374406  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -0.678184
# 374428  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.416110
# 374956  ENSG00000106772    PRUNE2  protein_coding  protein_coding    2.075796
# 375223  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -1.283341
# 375292  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -0.894318
# 375303  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.228137
# 375337  ENSG00000106772    PRUNE2  protein_coding  protein_coding   -4.271074
#
#        Relative TSS usage                          peak_name  peak_type  \
# 37057            0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 37058            0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 63701            0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124338           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124395           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124523           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124803           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124891           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 124926           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125401           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125586           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125661           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125734           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125779           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 125817           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 126273           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 313671           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 315132           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 315133           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 316061           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 316625           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 317865           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 317929           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 318057           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 318620           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 318777           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 319141           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 319199           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 319261           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 319362           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 319740           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 320224           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 320779           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 320869           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321069           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321098           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321239           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321532           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321533           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 321534           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 341327           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 374377           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 374406           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 374428           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 374956           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 375223           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 375292           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 375303           0.361045  chr9:76906093-76906284_Peak_76147     Robust
# 375337           0.361045  chr9:76906093-76906284_Peak_76147     Robust
#
#              og_gene_id
# 37057   ENSG00000106772
# 37058   ENSG00000106772
# 63701   ENSG00000106772
# 124338  ENSG00000106772
# 124395  ENSG00000106772
# 124523  ENSG00000106772
# 124803  ENSG00000106772
# 124891  ENSG00000106772
# 124926  ENSG00000106772
# 125401  ENSG00000106772
# 125586  ENSG00000106772
# 125661  ENSG00000106772
# 125734  ENSG00000106772
# 125779  ENSG00000106772
# 125817  ENSG00000106772
# 126273  ENSG00000106772
# 313671  ENSG00000106772
# 315132  ENSG00000106772
# 315133  ENSG00000106772
# 316061  ENSG00000106772
# 316625  ENSG00000106772
# 317865  ENSG00000106772
# 317929  ENSG00000106772
# 318057  ENSG00000106772
# 318620  ENSG00000106772
# 318777  ENSG00000106772
# 319141  ENSG00000106772
# 319199  ENSG00000106772
# 319261  ENSG00000106772
# 319362  ENSG00000106772
# 319740  ENSG00000106772
# 320224  ENSG00000106772
# 320779  ENSG00000106772
# 320869  ENSG00000106772
# 321069  ENSG00000106772
# 321098  ENSG00000106772
# 321239  ENSG00000106772
# 321532  ENSG00000106772
# 321533  ENSG00000106772
# 321534  ENSG00000106772
# 341327  ENSG00000106772
# 374377  ENSG00000106772
# 374406  ENSG00000106772
# 374428  ENSG00000106772
# 374956  ENSG00000106772
# 375223  ENSG00000106772
# 375292  ENSG00000106772
# 375303  ENSG00000106772
# 375337  ENSG00000106772
#
# [49 rows x 22 columns]

# %%
combined_df[combined_df["transcript_id"] == "PBT00031884"]
# Out:
#        transcript_id   chr                                 exons matched_to  \
# 328077   PBT00031884  chr1  [(943393, 943453), (943698, 944574)]        NaN
#
#        matched_ref_id                                           category  \
# 328077            NaN  Fully unannotated transcripts with overlapping...
#
#        unannotated_exons best_match_ref_id largest_overlap_gencode_id Strand  \
# 328077               NaN               NaN          ENST00000341065.8      +
#
#         ...  stripped_ref_id   Gene stable ID Gene name       Gene type  \
# 328077  ...  ENST00000341065  ENSG00000187634    SAMD11  protein_coding
#
#          gene_category log2_tx_exp Relative TSS usage  \
# 328077  protein_coding    0.759239           0.296967
#
#                          peak_name  peak_type       og_gene_id
# 328077  chr1:943392-943773_Peak_73     Robust  ENSG00000187634
#
# [1 rows x 22 columns]

# %%
combined_df[combined_df["Gene name"] == "SYT16"]
# Out:
#             transcript_id    chr  \
# 81992         PBT00131765  chr14
# 81993         PBT00131766  chr14
# 81994         PBT00131767  chr14
# 81995         PBT00131769  chr14
# 81996         PBT00131770  chr14
# 81997         PBT00131771  chr14
# 82138        STRT00610923  chr14
# 82228        STRT00616169  chr14
# 82240        STRT00616988  chr14
# 82241        STRT00616989  chr14
# 82281        STRT00618618  chr14
# 82352        STRT00621499  chr14
# 82359        STRT00621777  chr14
# 82371        STRT00622240  chr14
# 82388        STRT00622725  chr14
# 82570        STRT00630377  chr14
# 82603        STRT00631684  chr14
# 82627        STRT00633209  chr14
# 82687        STRT00634743  chr14
# 82742        STRT00636109  chr14
# 82890        STRT00641356  chr14
# 82918        STRT00642149  chr14
# 83033        STRT00646277  chr14
# 83034        STRT00646279  chr14
# 83094        STRT00648002  chr14
# 83118        STRT00649690  chr14
# 83119        STRT00649691  chr14
# 83120        STRT00649692  chr14
# 83150        STRT00650571  chr14
# 83160        STRT00650986  chr14
# 83161        STRT00650987  chr14
# 83180        STRT00651470  chr14
# 83196        STRT00651770  chr14
# 83272        STRT00653899  chr14
# 83295        STRT00654436  chr14
# 83372        STRT00656558  chr14
# 83380        STRT00656980  chr14
# 83457        STRT00659335  chr14
# 83472        STRT00663261  chr14
# 83656        STRT00670730  chr14
# 83684        STRT00671343  chr14
# 83685        STRT00671344  chr14
# 182898  FTMT25500036294.1  chr14
# 183098  MICT00000105632.1  chr14
# 183099  MICT00000105633.1  chr14
# 188432       STRT00669217  chr14
# 331706        PBT00131759  chr14
# 331951       STRT00667431  chr14
#
#                                                     exons matched_to  \
# 81992   [(61884880, 61885249), (61897253, 61897355), (...        NaN
# 81993   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 81994   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 81995   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 81996   [(61884903, 61885249), (61970132, 61970311), (...        NaN
# 81997   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82138   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82228   [(61884814, 61884983), (61885077, 61885249), (...        NaN
# 82240   [(61884843, 61885249), (61897253, 61897355), (...        NaN
# 82241   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82281   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82352   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82359   [(61812742, 61812810), (61885077, 61885249), (...        NaN
# 82371   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82388   [(61884914, 61884983), (61885077, 61885249), (...        NaN
# 82570   [(61884795, 61884983), (61885077, 61885249), (...        NaN
# 82603   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82627   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82687   [(61885175, 61885249), (61897253, 61897355), (...        NaN
# 82742   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 82890   [(61884900, 61884983), (61885077, 61885249), (...        NaN
# 82918   [(61884894, 61884983), (61885077, 61885249), (...        NaN
# 83033   [(61884842, 61885249), (61908655, 61908734), (...        NaN
# 83034   [(61884841, 61885249), (61897253, 61897355), (...        NaN
# 83094   [(61884903, 61885249), (61908655, 61908734), (...        NaN
# 83118   [(61885175, 61885249), (61897253, 61897355), (...        NaN
# 83119   [(61884898, 61885249), (61908655, 61908734), (...        NaN
# 83120   [(61884813, 61885249), (61908655, 61908734), (...        NaN
# 83150   [(61812712, 61812810), (61885077, 61885249), (...        NaN
# 83160   [(61884903, 61884983), (61885077, 61885249), (...        NaN
# 83161   [(61884903, 61885249), (61970132, 61970311), (...        NaN
# 83180   [(61884829, 61885249), (61970132, 61970311), (...        NaN
# 83196   [(61884793, 61885249), (61908655, 61908734), (...        NaN
# 83272   [(61885175, 61885249), (61970132, 61985633), (...        NaN
# 83295   [(61884795, 61884983), (61885077, 61885249), (...        NaN
# 83372   [(61884843, 61885249), (61970132, 61970311), (...        NaN
# 83380   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 83457   [(61884880, 61885249), (61970132, 61970311), (...        NaN
# 83472   [(61885175, 61885249), (61970132, 61970311), (...        NaN
# 83656   [(61884903, 61884983), (61885077, 61885249), (...        NaN
# 83684   [(61884841, 61885249), (61970132, 61970311), (...        NaN
# 83685   [(61884841, 61885249), (61897253, 61897355), (...        NaN
# 182898  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 183098  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 183099  [(61812703, 61812810), (61970132, 61970311), (...        NaN
# 188432  [(61812760, 61812810), (61970132, 61970311), (...        NaN
# 331706       [(61884858, 61885249), (61970132, 61973542)]        NaN
# 331951  [(61884840, 61884983), (61885077, 61885249), (...        NaN
#
#                                            matched_ref_id  \
# 81992                               ['ENST00000554436.1']
# 81993   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 81994   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 81995   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 81996   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 81997   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82138   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82228   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82240                               ['ENST00000554436.1']
# 82241   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82281   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82352   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82359   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82371          ['ENST00000683842.1', 'ENST00000636133.1']
# 82388   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82570   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82603   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82627   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82687                               ['ENST00000554436.1']
# 82742   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82890   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 82918          ['ENST00000683842.1', 'ENST00000636133.1']
# 83033   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83034   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83094   ['ENST00000555409.1', 'ENST00000726296.1', 'EN...
# 83118                               ['ENST00000554436.1']
# 83119   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83120   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83150   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83160   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83161   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83180   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83196   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83272   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83295          ['ENST00000683842.1', 'ENST00000636133.1']
# 83372   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83380          ['ENST00000683842.1', 'ENST00000636133.1']
# 83457   ['ENST00000555409.1', 'ENST00000726296.1', 'EN...
# 83472   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83656   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83684   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 83685   ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 182898  ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 183098  ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 183099  ['ENST00000555409.1', 'ENST00000683842.1', 'EN...
# 188432         ['ENST00000683842.1', 'ENST00000636133.1']
# 331706                                                NaN
# 331951                                                NaN
#
#                                                  category  \
# 81992   Transcripts with annotated exons and non-overl...
# 81993   Transcripts with annotated exons and non-overl...
# 81994   Transcripts with annotated exons and non-overl...
# 81995   Transcripts with annotated exons and non-overl...
# 81996   Transcripts with annotated exons and non-overl...
# 81997   Transcripts with annotated exons and non-overl...
# 82138   Transcripts with annotated exons and non-overl...
# 82228   Transcripts with annotated exons and non-overl...
# 82240   Transcripts with annotated exons and non-overl...
# 82241   Transcripts with annotated exons and non-overl...
# 82281   Transcripts with annotated exons and non-overl...
# 82352   Transcripts with annotated exons and non-overl...
# 82359   Transcripts with annotated exons and non-overl...
# 82371   Transcripts with annotated exons and non-overl...
# 82388   Transcripts with annotated exons and non-overl...
# 82570   Transcripts with annotated exons and non-overl...
# 82603   Transcripts with annotated exons and non-overl...
# 82627   Transcripts with annotated exons and non-overl...
# 82687   Transcripts with annotated exons and non-overl...
# 82742   Transcripts with annotated exons and non-overl...
# 82890   Transcripts with annotated exons and non-overl...
# 82918   Transcripts with annotated exons and non-overl...
# 83033   Transcripts with annotated exons and non-overl...
# 83034   Transcripts with annotated exons and non-overl...
# 83094   Transcripts with annotated exons and non-overl...
# 83118   Transcripts with annotated exons and non-overl...
# 83119   Transcripts with annotated exons and non-overl...
# 83120   Transcripts with annotated exons and non-overl...
# 83150   Transcripts with annotated exons and non-overl...
# 83160   Transcripts with annotated exons and non-overl...
# 83161   Transcripts with annotated exons and non-overl...
# 83180   Transcripts with annotated exons and non-overl...
# 83196   Transcripts with annotated exons and non-overl...
# 83272   Transcripts with annotated exons and non-overl...
# 83295   Transcripts with annotated exons and non-overl...
# 83372   Transcripts with annotated exons and non-overl...
# 83380   Transcripts with annotated exons and non-overl...
# 83457   Transcripts with annotated exons and non-overl...
# 83472   Transcripts with annotated exons and non-overl...
# 83656   Transcripts with annotated exons and non-overl...
# 83684   Transcripts with annotated exons and non-overl...
# 83685   Transcripts with annotated exons and non-overl...
# 182898  Transcripts with annotated exons and only over...
# 183098  Transcripts with annotated exons and only over...
# 183099  Transcripts with annotated exons and only over...
# 188432  Transcripts with annotated exons and only over...
# 331706  Fully unannotated transcripts with overlapping...
# 331951  Fully unannotated transcripts with overlapping...
#
#                                         unannotated_exons  best_match_ref_id  \
# 81992        [(61884880, 61885249), (61903911, 61907364)]  ENST00000554436.1
# 81993        [(61884880, 61885249), (62075135, 62075604)]  ENST00000683842.1
# 81994        [(61884880, 61885249), (62084196, 62086479)]  ENST00000683842.1
# 81995                              [(61884880, 61885249)]  ENST00000683842.1
# 81996        [(61884903, 61885249), (62075135, 62075605)]  ENST00000636133.1
# 81997        [(61885175, 61885249), (62084196, 62086705)]  ENST00000683842.1
# 82138        [(61885175, 61885249), (62100563, 62101078)]  ENST00000683842.1
# 82228        [(61884814, 61884983), (61885077, 61885249)]  ENST00000683842.1
# 82240        [(61884843, 61885249), (61907437, 61907735)]  ENST00000554436.1
# 82241        [(61885175, 61885249), (62100563, 62107102)]  ENST00000683842.1
# 82281                              [(61885175, 61885249)]  ENST00000683842.1
# 82352        [(61885175, 61885249), (62076329, 62076481)]  ENST00000683842.1
# 82359        [(61885077, 61885249), (62100563, 62100707)]  ENST00000683842.1
# 82371        [(61885175, 61885249), (61973792, 61973864)]  ENST00000636133.1
# 82388   [(61884914, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 82570   [(61884795, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 82603   [(61885175, 61885249), (62100394, 62100707), (...  ENST00000683842.1
# 82627        [(61885175, 61885249), (62076329, 62076356)]  ENST00000683842.1
# 82687   [(61885175, 61885249), (61902304, 61902417), (...  ENST00000554436.1
# 82742        [(61885175, 61885249), (62079340, 62079417)]  ENST00000683842.1
# 82890   [(61884900, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 82918   [(61884894, 61884983), (61885077, 61885249), (...  ENST00000636133.1
# 83033   [(61884842, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83034        [(61884841, 61885249), (61908655, 61908734)]  ENST00000683842.1
# 83094   [(61884903, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83118        [(61885175, 61885249), (61970132, 61983478)]  ENST00000554436.1
# 83119   [(61884898, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83120        [(61884813, 61885249), (61908655, 61908734)]  ENST00000683842.1
# 83150                              [(61885077, 61885249)]  ENST00000683842.1
# 83160   [(61884903, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 83161   [(61884903, 61885249), (61985542, 61985633), (...  ENST00000683842.1
# 83180   [(61884829, 61885249), (61995953, 61996542), (...  ENST00000683842.1
# 83196   [(61884793, 61885249), (61908655, 61908734), (...  ENST00000683842.1
# 83272   [(61885175, 61885249), (61970132, 61985633), (...  ENST00000683842.1
# 83295   [(61884795, 61884983), (61885077, 61885249), (...  ENST00000636133.1
# 83372   [(61884843, 61885249), (61985542, 61985633), (...  ENST00000683842.1
# 83380        [(61885175, 61885249), (62075135, 62075753)]  ENST00000683842.1
# 83457        [(61884880, 61885249), (62100394, 62117588)]  ENST00000683842.1
# 83472   [(61885175, 61885249), (62074575, 62074693), (...  ENST00000683842.1
# 83656   [(61884903, 61884983), (61885077, 61885249), (...  ENST00000683842.1
# 83684        [(61884841, 61885249), (62080834, 62081326)]  ENST00000683842.1
# 83685                              [(61884841, 61885249)]  ENST00000683842.1
# 182898                             [(62100394, 62101078)]  ENST00000683842.1
# 183098                             [(62100394, 62103421)]  ENST00000683842.1
# 183099                             [(62100394, 62103421)]  ENST00000683842.1
# 188432                             [(61995953, 61997649)]  ENST00000636133.1
# 331706                                                NaN                NaN
# 331951                                                NaN                NaN
#
#        largest_overlap_gencode_id Strand  ...  stripped_ref_id  \
# 81992                         NaN      +  ...  ENST00000554436
# 81993                         NaN      +  ...  ENST00000683842
# 81994                         NaN      +  ...  ENST00000683842
# 81995                         NaN      +  ...  ENST00000683842
# 81996                         NaN      +  ...  ENST00000636133
# 81997                         NaN      +  ...  ENST00000683842
# 82138                         NaN      +  ...  ENST00000683842
# 82228                         NaN      +  ...  ENST00000683842
# 82240                         NaN      +  ...  ENST00000554436
# 82241                         NaN      +  ...  ENST00000683842
# 82281                         NaN      +  ...  ENST00000683842
# 82352                         NaN      +  ...  ENST00000683842
# 82359                         NaN      +  ...  ENST00000683842
# 82371                         NaN      +  ...  ENST00000636133
# 82388                         NaN      +  ...  ENST00000683842
# 82570                         NaN      +  ...  ENST00000683842
# 82603                         NaN      +  ...  ENST00000683842
# 82627                         NaN      +  ...  ENST00000683842
# 82687                         NaN      +  ...  ENST00000554436
# 82742                         NaN      +  ...  ENST00000683842
# 82890                         NaN      +  ...  ENST00000683842
# 82918                         NaN      +  ...  ENST00000636133
# 83033                         NaN      +  ...  ENST00000683842
# 83034                         NaN      +  ...  ENST00000683842
# 83094                         NaN      +  ...  ENST00000683842
# 83118                         NaN      +  ...  ENST00000554436
# 83119                         NaN      +  ...  ENST00000683842
# 83120                         NaN      +  ...  ENST00000683842
# 83150                         NaN      +  ...  ENST00000683842
# 83160                         NaN      +  ...  ENST00000683842
# 83161                         NaN      +  ...  ENST00000683842
# 83180                         NaN      +  ...  ENST00000683842
# 83196                         NaN      +  ...  ENST00000683842
# 83272                         NaN      +  ...  ENST00000683842
# 83295                         NaN      +  ...  ENST00000636133
# 83372                         NaN      +  ...  ENST00000683842
# 83380                         NaN      +  ...  ENST00000683842
# 83457                         NaN      +  ...  ENST00000683842
# 83472                         NaN      +  ...  ENST00000683842
# 83656                         NaN      +  ...  ENST00000683842
# 83684                         NaN      +  ...  ENST00000683842
# 83685                         NaN      +  ...  ENST00000683842
# 182898                        NaN      +  ...  ENST00000683842
# 183098                        NaN      +  ...  ENST00000683842
# 183099                        NaN      +  ...  ENST00000683842
# 188432                        NaN      +  ...  ENST00000636133
# 331706          ENST00000554138.1      +  ...  ENST00000554138
# 331951          ENST00000554138.1      +  ...  ENST00000554138
#
#          Gene stable ID Gene name       Gene type   gene_category log2_tx_exp  \
# 81992   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.314628
# 81993   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.216140
# 81994   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.791865
# 81995   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.093752
# 81996   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.410534
# 81997   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.722954
# 82138   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.374329
# 82228   ENSG00000139973     SYT16  protein_coding  protein_coding    0.853407
# 82240   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.257821
# 82241   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.967091
# 82281   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.275810
# 82352   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.217284
# 82359   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.747277
# 82371   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.813053
# 82388   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.563112
# 82570   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.986264
# 82603   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.395634
# 82627   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.357758
# 82687   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.207661
# 82742   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.725249
# 82890   ENSG00000139973     SYT16  protein_coding  protein_coding   -5.314217
# 82918   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.849762
# 83033   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.469073
# 83034   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.158440
# 83094   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.776327
# 83118   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.413955
# 83119   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.875100
# 83120   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.440259
# 83150   ENSG00000139973     SYT16  protein_coding  protein_coding    1.435367
# 83160   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.529547
# 83161   ENSG00000139973     SYT16  protein_coding  protein_coding   -3.619125
# 83180   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.673613
# 83196   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.718738
# 83272   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.356039
# 83295   ENSG00000139973     SYT16  protein_coding  protein_coding   -5.562532
# 83372   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.651575
# 83380   ENSG00000139973     SYT16  protein_coding  protein_coding   -0.921699
# 83457   ENSG00000139973     SYT16  protein_coding  protein_coding   -2.848188
# 83472   ENSG00000139973     SYT16  protein_coding  protein_coding   -1.840843
# 83656   ENSG00000139973     SYT16  protein_coding  protein_coding   -5.765457
# 83684   ENSG00000139973     SYT16  protein_coding  protein_coding   -4.739429
# 83685   ENSG00000139973     SYT16  protein_coding  protein_coding    0.128776
# 182898  ENSG00000139973     SYT16  protein_coding  protein_coding   -2.731717
# 183098  ENSG00000139973     SYT16  protein_coding  protein_coding   -5.604979
# 183099  ENSG00000139973     SYT16  protein_coding  protein_coding   -5.082823
# 188432  ENSG00000139973     SYT16  protein_coding  protein_coding   -1.579913
# 331706  ENSG00000139973     SYT16  protein_coding  protein_coding   -4.760310
# 331951  ENSG00000139973     SYT16  protein_coding  protein_coding   -4.900631
#
#        Relative TSS usage                           peak_name   peak_type  \
# 81992            1.000000  chr14:61884816-61884916_Peak_23082      Robust
# 81993            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 81994            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 81995            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 81996            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 81997            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82138            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82228            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 82240            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 82241            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82281            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82352            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82359            0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 82371            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82388            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 82570            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 82603            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82627            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82687            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82742            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 82890            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 82918            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83033            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83034            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83094            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83118            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 83119            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83120            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83150            0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 83160            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83161            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83180            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83196            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83272            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 83295            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83372            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83380            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 83457            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83472            0.224807  chr14:61885033-61885181_Peak_23083      Robust
# 83656            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83684            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 83685            0.507257  chr14:61884816-61884916_Peak_23082      Robust
# 182898           0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 183098           0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 183099           0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 188432           0.267936  chr14:61812709-61812726_Peak_23080  Permissive
# 331706           1.000000  chr14:61884816-61884916_Peak_23082      Robust
# 331951           0.507257  chr14:61884816-61884916_Peak_23082      Robust
#
#              og_gene_id
# 81992   ENSG00000258882
# 81993   ENSG00000139973
# 81994   ENSG00000139973
# 81995   ENSG00000139973
# 81996   ENSG00000139973
# 81997   ENSG00000139973
# 82138   ENSG00000139973
# 82228   ENSG00000139973
# 82240   ENSG00000139973
# 82241   ENSG00000139973
# 82281   ENSG00000139973
# 82352   ENSG00000139973
# 82359   ENSG00000139973
# 82371   ENSG00000139973
# 82388   ENSG00000139973
# 82570   ENSG00000139973
# 82603   ENSG00000139973
# 82627   ENSG00000139973
# 82687   ENSG00000139973
# 82742   ENSG00000139973
# 82890   ENSG00000139973
# 82918   ENSG00000139973
# 83033   ENSG00000139973
# 83034   ENSG00000139973
# 83094   ENSG00000139973
# 83118   ENSG00000139973
# 83119   ENSG00000139973
# 83120   ENSG00000139973
# 83150   ENSG00000139973
# 83160   ENSG00000139973
# 83161   ENSG00000139973
# 83180   ENSG00000139973
# 83196   ENSG00000139973
# 83272   ENSG00000139973
# 83295   ENSG00000139973
# 83372   ENSG00000139973
# 83380   ENSG00000139973
# 83457   ENSG00000139973
# 83472   ENSG00000139973
# 83656   ENSG00000139973
# 83684   ENSG00000139973
# 83685   ENSG00000139973
# 182898  ENSG00000139973
# 183098  ENSG00000139973
# 183099  ENSG00000139973
# 188432  ENSG00000139973
# 331706  ENSG00000258882
# 331951  ENSG00000139973
#
# [48 rows x 22 columns]

# %%
combined_df[combined_df["Gene name"] == "PRUNE2"]["category"].value_counts()
# Out:
# category
# Transcripts with annotated exons and only overlapping unannotated exons    51
# Transcripts with annotated exons and non-overlapping unannotated exons     19
# Unannotated transcripts composed entirely of annotated exons               18
# Unannotated transcripts fully contained within GENCODE transcripts          8
# GENCODE-annotated transcripts                                               3
# Fully unannotated transcripts with overlapping exons                        3
# Name: count, dtype: int64

# %%
alpha_peak_ids = [
    "ENST00000223609.6", "ENST00000488346.1", "HBMT00001485712.1", "HBMT00001485831.1",
    "PBT00426042", "PBT00426044", "PBT00426045", "PBT00426046", "PBT00426047", "PBT00426048",
    "PBT00426049", "PBT00426050", "PBT00426051", "PBT00426065",
    "STRT02140348", "STRT02141127", "STRT02154998", "STRT02171970",
    "STRT02184791", "STRT02189297", "STRT02194130"
]

beta_peak_ids = [
    "ENST00000376713.3", "ENST00000376718.3", "ENST00000428286.1", "ENST00000492157.1",
    "FTMT23300029397.1", "FTMT23300029975.1", "PBT00426069", "PBT00426071", "PBT00426074",
    "STRT02128601", "STRT02135347", "STRT02137332", "STRT02138946", "STRT02138947",
    "STRT02143313", "STRT02152013", "STRT02155452", "STRT02157377", "STRT02162417",
    "STRT02163302", "STRT02165955", "STRT02171755", "STRT02177848", "STRT02178142",
    "STRT02179724", "STRT02179725", "STRT02180042", "STRT02183942", "STRT02184337",
    "STRT02184338", "STRT02184999", "STRT02185383", "STRT02185739", "STRT02186418",
    "STRT02186750", "STRT02190622", "STRT02192005", "STRT02193969", "STRT02194971",
    "STRT02203853", "STRT02206296", "STRT02207040", "STRT02207483", "STRT02209417",
    "STRT02209624", "STRT02211017", "STRT02214009", "STRT02214010", "STRT02214012"
]

# %%
combined_df[combined_df["transcript_id"].isin(alpha_peak_ids)]["category"].value_counts()
# Out:
# category
# Unannotated transcripts composed entirely of annotated exons               10
# Transcripts with annotated exons and only overlapping unannotated exons     6
# Unannotated transcripts fully contained within GENCODE transcripts          3
# GENCODE-annotated transcripts                                               1
# Fully unannotated transcripts with overlapping exons                        1
# Name: count, dtype: int64

# %%
combined_df[combined_df["transcript_id"].isin(beta_peak_ids)]["category"].value_counts()
# Out:
# category
# Transcripts with annotated exons and only overlapping unannotated exons    24
# Transcripts with annotated exons and non-overlapping unannotated exons     13
# Unannotated transcripts composed entirely of annotated exons                8
# GENCODE-annotated transcripts                                               2
# Unannotated transcripts fully contained within GENCODE transcripts          1
# Fully unannotated transcripts with overlapping exons                        1
# Name: count, dtype: int64
