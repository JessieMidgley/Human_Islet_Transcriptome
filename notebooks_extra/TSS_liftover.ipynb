# %% [markdown]
# # Add liftover of TSS coordinates to Anthony's df of TSS info

# %% [markdown]
# ## Load Anthony's TSS data

# %%
.libPaths("/no_backup/jferrer/jmidgley/R_libs")
library(readr)
library(dplyr)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Load table with TSS info - NOTE: uses hg19 positions
TSS_df <- read_tsv('/users/jferrer/public-docs/tracksDirectory/mplanas/HI_transcriptome_v2.2.tsv.gz', show_col_types = FALSE)
head(TSS_df)
# Out:
#   chromosome tx_start tx_end strand transcript_id     gene_id         gene_name
# 1 chr1       14362    29370  -      ENST00000423562.1 ENSG00000227232 WASH7P
# 2 chr1       14359    29350  -      PBT00037199       ENSG00000227232 WASH7P
# 3 chr1       14359    29350  -      PBT00037200       ENSG00000227232 WASH7P
# 4 chr1       14360    29364  -      PBT00037201       ENSG00000227232 WASH7P
# 5 chr1       14362    29346  -      PBT00037202       ENSG00000227232 WASH7P
# 6 chr1       14365    29347  -      PBT00037205       ENSG00000227232 WASH7P
#   Gene class gene_type  transcript_type ⋯ high_tpm low_tpm  peak
# 1 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
# 2 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
# 3 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
# 4 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
# 5 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
# 6 misc RNA   pseudogene new_transcript  ⋯ 17.58083 17.85643 Robust
#   TSS expression high glucose (Salmon, TPM) Relative TSS usage TSS_type
# 1 27.34853                                  1                  unique TSS
# 2 27.34853                                  1                  unique TSS
# 3 27.34853                                  1                  unique TSS
# 4 27.34853                                  1                  unique TSS
# 5 27.34853                                  1                  unique TSS
# 6 27.34853                                  1                  unique TSS
#   distance_to_closest_TSS Distance to closest Gencode TSS
# 1 211                     >100bp
# 2 211                     >100bp
# 3 211                     >100bp
# 4 211                     >100bp
# 5 211                     >100bp
# 6 211                     >100bp
#   name                    new_1st_exon
# 1 chr1:29336-29359_Peak_1 yes
# 2 chr1:29336-29359_Peak_1 yes
# 3 chr1:29336-29359_Peak_1 yes
# 4 chr1:29336-29359_Peak_1 yes
# 5 chr1:29336-29359_Peak_1 yes
# 6 chr1:29336-29359_Peak_1 yes

# %% [markdown]
# ### Load LiftOver TSS coordinates and add to TSS data

# %% [markdown]
# Used UCSC Liftover tool to create BED file of new start and end positions

# %%
liftover_tss <- read_tsv("./HumanIsletTranscriptome/data_raw/tss_liftover.bed", col_names = FALSE, show_col_types = FALSE) %>%
  setNames(c("chr", "new_start", "new_end", "old_coords", "score", "strand")) %>%
  mutate(
    old_base = str_extract(old_coords, "^chr[\\w]+:[0-9]+-[0-9]+"),
    new_coords = paste0(chr, ":", new_start + 1, "-", new_end)
  ) %>%
  distinct(old_base, .keep_all = TRUE)
head(liftover_tss)
# Out:
#   chr  new_start new_end old_coords           score strand old_base
# 1 chr1  29335     29359  chr1:29336-29359:.   1     -      chr1:29336-29359
# 2 chr1 629079    629136  chr1:564460-564516:. 1     +      chr1:564460-564516
# 3 chr1 629638    629739  chr1:565019-565119:. 1     +      chr1:565019-565119
# 4 chr1 631069    631078  chr1:566450-566458:. 1     +      chr1:566450-566458
# 5 chr1 632535    632616  chr1:567916-567996:. 1     -      chr1:567916-567996
# 6 chr1 632597    632876  chr1:567978-568256:. 1     +      chr1:567978-568256
#   new_coords
# 1 chr1:29336-29359
# 2 chr1:629080-629136
# 3 chr1:629639-629739
# 4 chr1:631070-631078
# 5 chr1:632536-632616
# 6 chr1:632598-632876

# %%
# Add hg38 coordinates to original df
TSS_df <- TSS_df %>%
  mutate(
    old_base = str_extract(name, "^chr[\\w]+:[0-9]+-[0-9]+"),
    peak_suffix = str_extract(name, "Peak_\\d+$")
  ) %>%
  left_join(liftover_tss %>% dplyr::select(old_base, new_coords), by = "old_base") %>%
  mutate(
    new_name = if_else(
      is.na(new_coords),
      paste0("conversion_failed_", peak_suffix),
      paste0(new_coords, "_", peak_suffix)
    )
  ) %>% dplyr::select(-old_base, -peak_suffix, -new_coords)
head(TSS_df)
# Out:
#   chromosome tx_start tx_end strand transcript_id     gene_id         gene_name
# 1 chr1       14362    29370  -      ENST00000423562.1 ENSG00000227232 WASH7P
# 2 chr1       14359    29350  -      PBT00037199       ENSG00000227232 WASH7P
# 3 chr1       14359    29350  -      PBT00037200       ENSG00000227232 WASH7P
# 4 chr1       14360    29364  -      PBT00037201       ENSG00000227232 WASH7P
# 5 chr1       14362    29346  -      PBT00037202       ENSG00000227232 WASH7P
# 6 chr1       14365    29347  -      PBT00037205       ENSG00000227232 WASH7P
#   Gene class gene_type  transcript_type ⋯ low_tpm  peak
# 1 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
# 2 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
# 3 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
# 4 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
# 5 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
# 6 misc RNA   pseudogene new_transcript  ⋯ 17.85643 Robust
#   TSS expression high glucose (Salmon, TPM) Relative TSS usage TSS_type
# 1 27.34853                                  1                  unique TSS
# 2 27.34853                                  1                  unique TSS
# 3 27.34853                                  1                  unique TSS
# 4 27.34853                                  1                  unique TSS
# 5 27.34853                                  1                  unique TSS
# 6 27.34853                                  1                  unique TSS
#   distance_to_closest_TSS Distance to closest Gencode TSS
# 1 211                     >100bp
# 2 211                     >100bp
# 3 211                     >100bp
# 4 211                     >100bp
# 5 211                     >100bp
# 6 211                     >100bp
#   name                    new_1st_exon new_name
# 1 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1
# 2 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1
# 3 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1
# 4 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1
# 5 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1
# 6 chr1:29336-29359_Peak_1 yes          chr1:29336-29359_Peak_1

# %%
write.table(TSS_df, file = "./HumanIsletTranscriptome/data_processed/TSS_info_w_lift.tsv", sep = "\t", quote = FALSE, row.names = FALSE)
